# %%
# metaheuristica procurar ponto mais proximo de 2 pontos e colocar ele ali no meio

import math
import copy
def solucaoFinal(vRota, vItens, matriz, itens, vMin, vMax, v, maxTime, w):
    vRota = [0] + vRota + [len(matriz)-1]
    peso = 0
    valor=0
    itensCid=[]
    for x in matriz:
        itensCid.append([])
    for x in vItens:        
        #print(x)
        itensCid[int(itens[x][3])].append(itens[x])
        peso += itens[x][2]
        valor += itens[x][1]
    
    t = 0
    pesoAtual = 0
    for index, x in enumerate(vRota):
        #print(index,x , len(vRota))
        if(index < len(vRota)-1):
            for y in itensCid[x]:
                #print('cidade', x-1, 'peso', pesoAtual)
                pesoAtual +=y[2]
            #print(matriz[x-1][vRota[index+1]-1], vMax , v*pesoAtual, vMin)
            t += matriz[x][vRota[index+1]]/max(vMax - v*pesoAtual, vMin)
    tempoAtual = (t/maxTime) * (pesoAtual/w)
    #print('tempo', t,maxTime, pesoAtual, w, 'peso:', tempoAtual, valor)
    #print(t,maxTime , peso,w)
    if(t<=maxTime and pesoAtual<=w):
        return valor
    else:
        return -1
    return 0
def solucaoFinal2(vRota, vItens, matriz, itens, vMin, vMax, v, maxTime, w):
    vRota = [0] + vRota + [len(matriz)-1]
    peso = 0
    valor=0
    itensCid=[]
    for x in matriz:
        itensCid.append([])
    for x in vItens:        
        #print(x)
        itensCid[int(itens[x][3])].append(itens[x])
        peso += itens[x][2]
        valor += itens[x][1]
    
    t = 0
    pesoAtual = 0
    for index, x in enumerate(vRota):
        #print(index,x , len(vRota))
        if(index < len(vRota)-1):
            for y in itensCid[x]:
                #print('cidade', x-1, 'peso', pesoAtual)
                pesoAtual +=y[2]
            #print(matriz[x-1][vRota[index+1]-1], vMax , v*pesoAtual, vMin)
            t += matriz[x][vRota[index+1]]/max(vMax - v*pesoAtual, vMin)
    tempoAtual = (t/maxTime) * (pesoAtual/w)
    #print('tempo', t,maxTime, pesoAtual, w, 'peso:', tempoAtual)
    #print(t,maxTime , peso,w)
    if(t<=maxTime and pesoAtual<=w):
        return valor, tempoAtual
    else:
        return -1, tempoAtual
    return 0
def dist(a, b):
    #print(a)
    #print(b)
    t = math.sqrt((a[1]-b[1])*(a[1]-b[1])+(a[2]-b[2])*(a[2]-b[2]))
    if int(t)==t:
        n = int(t)
    else:
        n = int(t)+1
    return n

def solucao(vRota, cidadeItens, matriz):
    vRota = [0] + vRota + [len(matriz)-1]
    peso = 0
    valor=0
    v = (maxSpeed - minSpeed)/capacity
    t = 0
    pesoAtual = 0
    for index, x in enumerate(vRota):
        #print(index,x , len(vRota))
        if(index < len(vRota)-1):
            valor+=cidadeItens[x]['valor']    
            pesoAtual +=cidadeItens[x]['peso']            
            t += matriz[x][vRota[index+1]]/max(maxSpeed - v*pesoAtual, minSpeed)
    if(t<=maxTime and pesoAtual<=capacity):
        return valor
    else:
        return -1
    return 0


def proximaCidade(matriz, dadosCidade, cidadeAtual, cidadeVisitada):
    maxi = -1
    ind = -1
    for index, x in enumerate(dadosCidade):
        #if  matriz[cidadeAtual][index]==0 and cidadeAtual!=index:
            #print(cidadeAtual, index, matriz[cidadeAtual][index])
            #continue
        value = (x/(matriz[cidadeAtual][index]+1))
        if (cidadeAtual!=index and maxi<value and not cidadeVisitada[index]):            
            maxi = value
            ind = index            
            
    return ind


def adicionaMaximoItens(rota, cidadeItens, cidadeAtual, itens, matriz, todosItens):
    rotaCopia = copy.deepcopy(rota)
    rotaCopia.append(cidadeAtual)
    lastResult = -1
    for x in itens:       
        cidadeItens[cidadeAtual]['valor']+=x[1]
        cidadeItens[cidadeAtual]['peso']+=x[2]         
        cidadeItens[cidadeAtual]['qtdItens']+=1
        todosItens.append(x[0])
        result = solucao(rotaCopia, cidadeItens, matriz)
        #print(rotaCopia, cidadeItens[cidadeAtual])
        if result==-1:            
            cidadeItens[cidadeAtual]['valor']-=x[1]
            cidadeItens[cidadeAtual]['peso']-=x[2]
            cidadeItens[cidadeAtual]['qtdItens']-=1
            todosItens.remove(x[0])
            break
        else:
            lastResult = result
            if(cidadeAtual not in rota):
                rota.append(cidadeAtual)
            
    return lastResult

# %%
import numpy as np
resultados = []
import csv
arquivo='xxx'
podeEntrar=False
with open('file.csv', "rt") as f:
    reader = csv.reader(f)
    for row in reader:
        if (row[0] == 'dsj1000_n998_uncorr-similar-weights_10_02.thop'):
            podeEntrar=True
        if podeEntrar==False:
            continue
        print ('thop/instances/'+row[0].split('_')[0] +'-thop/'+row[0])
        pontos = []
        itens = []


        with open('thop/instances/'+row[0].split('_')[0] +'-thop/'+row[0], 'r') as file:    
            name = file.readline().strip().replace(' ','').split(':')[1]    
            knapsack = file.readline().strip().replace(' ','').split(':')[1]    
            dimension = int(file.readline().strip().replace(' ','').split(':')[1])
            nItens = int(file.readline().strip().replace(' ','').split(':')[1])
            capacity = int(file.readline().strip().replace(' ','').split(':')[1])
            maxTime = int(file.readline().strip().replace(' ','').split(':')[1])
            minSpeed = float(file.readline().strip().replace(' ','').split(':')[1])
            maxSpeed = float(file.readline().strip().replace(' ','').split(':')[1])
            edgeType = file.readline().strip().replace(' ','').split(':')[1]
            pontosSection = True

            for x in file:
                if 'NODE_COORD_SECTION' in x: 
                    print(x)
                elif 'ITEMS SECTION' in x: 
                    pontosSection = False
                    print(x)
                else:
                    if(pontosSection):
                        pontos.append([float(i) for i in x.split()])
                    else:                
                        itens.append([float(i) if index!=0 and index!=3 else int(i)-1 for index, i in enumerate(x.split())]+[float(x.split()[1])/float(x.split()[2])]+[False])

        #print(pontos)
        #print(itens)



        matrizAdjacencia = []
        vetorCidadeProxima = {}
        itensCidade=[]
        dadosCidade = []
        cidadeVisitada = []

        for x in pontos:    
            itensCidade.append([])      
            dadosCidade.append(0) 
            cidadeVisitada.append(False)
            aux = []
            menor = 100000000000
            for y in pontos:
                d = dist(x,y)
                if(d<menor):
                    menor=d
                    ponto = y
                aux.append(d)

            vetorCidadeProxima[x[0]]=ponto[0]
            matrizAdjacencia.append(aux)

        for x in itens:
            itensCidade[int(x[3])].append(x)
            dadosCidade[int(x[3])]+=x[4]
        itensOrdenados = []
        #print(itensCidade)

        for index, x in enumerate(itensCidade):
            itensCidade[index]= sorted(x, key=lambda y: y[5], reverse=True)
            #print(itensOrdenados[index])
        #for x in itensOrdenados:
            #print (x)




    ################################
    
        
        if(arquivo!=row[0].split('_')[0]):
            arquivo=row[0].split('_')[0]
            print('entrou')



            #rota, cidadeItens
            matrizCidadeProxima = []
            for x in matrizAdjacencia:    
                matrizCidadeProxima.append([0]*len(matrizAdjacencia))
            ind = -1
            for x in range(len(matrizCidadeProxima)):
                for y in range(len(matrizCidadeProxima)):
                    soma = 10000000000000000        
                    for z in range(len(matrizCidadeProxima)):
                        if(x!=y and y!=z and z!=x):
                            valor = matrizAdjacencia[x][z] + matrizAdjacencia[z][y]
                            #print(valor)
                            if(soma > valor):
                                ind = z
                                soma = valor
                    matrizCidadeProxima[x][y] = ind
            matrizCidadeProxima[0]


        ##################################
        solucoes = []
        for nSolucoes in range(20):
            minS = minSpeed
            maxS = maxSpeed
            cap = capacity
            maxT = maxTime
            todosItens = []  
            for index, x in enumerate(cidadeVisitada):
                cidadeVisitada[index]=False
            cidadeVisitada[0]=True
            cidadeVisitada[len(cidadeVisitada)-1]=True

            cidadeItens=[]
            for x in range(len(matrizAdjacencia)):
                cidadeItens.append(copy.deepcopy({'peso':0, 'valor':0, 'qtdItens':0}))


            rota = []
            while(len(rota)==0):
                cidadeInicial = np.random.randint(1, len(pontos)-1)
                #rota.append(cidadeInicial)
                cidadeAtual = cidadeInicial
                cidadeVisitada[cidadeInicial]=True


                adicionaMaximoItens(rota, cidadeItens, cidadeInicial, itensCidade[cidadeAtual], matrizAdjacencia, todosItens)
            #print('saiu')
            #print('sol', solucaoFinal(rota, todosItens.copy(), matrizAdjacencia.copy(), itens.copy(), minS, maxS, (maxS-minS)/cap, maxT, cap))
            #cidadeAtual = cidadeInicial
            for x in range(len(matrizAdjacencia)):  
                cidadeProxima = proximaCidade(matrizAdjacencia, dadosCidade, cidadeAtual, cidadeVisitada)
                #print(cidadeProxima)
                if(cidadeProxima ==-1):
                    continue
                cidadeVisitada[cidadeProxima]=True    
                adicionaMaximoItens(rota, cidadeItens, cidadeProxima, itensCidade[cidadeProxima], matrizAdjacencia, todosItens)
                #print(solution)
                cidadeAtual = cidadeProxima


            soma = 0
            for x in cidadeItens:
                soma += x['valor']
            #print(rota, todosItens, soma)



            #################################


            solAtual, tempoAtual = solucaoFinal2(rota, todosItens.copy(), matrizAdjacencia.copy(), itens.copy(), minS, maxS, (maxS-minS)/cap, maxT, cap)
            aux22= copy.deepcopy(rota)
            for x in range(5):
                rotaVazia=[]
                for x in range(len(rota)-1):
                    if (matrizCidadeProxima[rota[x]][rota[x+1]] in rota):
                        rotaCopia = copy.deepcopy(rota)        
                        rotaVazia=[]
                        for index, i in enumerate(rotaCopia):
                            if i == matrizCidadeProxima[rotaCopia[x]][rotaCopia[x+1]]:
                                pass
                            elif rota[index]!=rotaCopia[x]:
                                rotaVazia.append(rotaCopia[index])

                            elif rota[index]==rotaCopia[x]:                
                                rotaVazia.append(rotaCopia[index])

                                #print(len(rotaCopia), x)
                                rotaVazia.append(matrizCidadeProxima[rotaCopia[x]][rotaCopia[x+1]])



                        solu, tempo = solucaoFinal2(rotaVazia, todosItens.copy(), matrizAdjacencia.copy(), itens.copy(), minS, maxS, (maxS-minS)/cap, maxT, cap)
                        if(tempo<tempoAtual):
                            rota=rotaVazia
                            tempoAtual=tempo
                            solAtual = solu

                for index, x in enumerate(cidadeVisitada):
                    cidadeVisitada[index]=False
                cidadeVisitada[0]=True
                cidadeVisitada[len(cidadeVisitada)-1]=True
                for x in rota:
                    cidadeVisitada[x]=True


                for x in range(len(matrizAdjacencia)): 

                    cidadeProxima = proximaCidade(matrizAdjacencia, dadosCidade, rota[len(rota)-1], cidadeVisitada)
                    #print(cidadeProxima)
                    if(cidadeProxima ==-1):
                        continue
                    cidadeVisitada[cidadeProxima]=True    
                    adicionaMaximoItens(rota, cidadeItens, cidadeProxima, itensCidade[cidadeProxima], matrizAdjacencia, todosItens)
                    #print(solution)
                    cidadeAtual = cidadeProxima
            solucoes.append(solucaoFinal(rota, todosItens.copy(), matrizAdjacencia.copy(), itens.copy(), minS, maxS, (maxS-minS)/cap, maxT, cap))
        print(max(solucoes))   
        resultados.append(max(solucoes))
        #print(rota, aux22)
        #soma=0
        #for x in range(len(rota)):
        #    if rota[x]!=aux22[x]:
        #        soma+=1
        #print(soma)
# Out:
# thop/instances/dsj1000-thop/dsj1000_n2994_bounded-strongly-corr_05_02.thop
# NODE_COORD_SECTION  (INDEX, X, Y):
#
# ITEMS SECTION    (INDEX, PROFIT, WEIGHT, ASSIGNED NODE NUMBER):
#
# 1517087.0
# thop/instances/dsj1000-thop/dsj1000_n2994_bounded-strongly-corr_05_03.thop
# NODE_COORD_SECTION  (INDEX, X, Y):
#
# ITEMS SECTION    (INDEX, PROFIT, WEIGHT, ASSIGNED NODE NUMBER):
#
# 1570649.0
# thop/instances/dsj1000-thop/dsj1000_n2994_bounded-strongly-corr_10_01.thop
# NODE_COORD_SECTION  (INDEX, X, Y):
#
# ITEMS SECTION    (INDEX, PROFIT, WEIGHT, ASSIGNED NODE NUMBER):
#
# 1721606.0
# thop/instances/dsj1000-thop/dsj1000_n2994_bounded-strongly-corr_10_02.thop
# NODE_COORD_SECTION  (INDEX, X, Y):
#
# ITEMS SECTION    (INDEX, PROFIT, WEIGHT, ASSIGNED NODE NUMBER):
#
# 2088769.0
# thop/instances/dsj1000-thop/dsj1000_n2994_bounded-strongly-corr_10_03.thop
# NODE_COORD_SECTION  (INDEX, X, Y):
#
# ITEMS SECTION    (INDEX, PROFIT, WEIGHT, ASSIGNED NODE NUMBER):
#
# 2450110.0
# thop/instances/dsj1000-thop/dsj1000_n2994_uncorr_01_01.thop
# NODE_COORD_SECTION  (INDEX, X, Y):
#
# ITEMS SECTION    (INDEX, PROFIT, WEIGHT, ASSIGNED NODE NUMBER):
#
# 185357.0
# thop/instances/dsj1000-thop/dsj1000_n2994_uncorr_01_02.thop
# NODE_COORD_SECTION  (INDEX, X, Y):
#
# ITEMS SECTION    (INDEX, PROFIT, WEIGHT, ASSIGNED NODE NUMBER):
#
# 205678.0
# thop/instances/dsj1000-thop/dsj1000_n2994_uncorr_01_03.thop
# NODE_COORD_SECTION  (INDEX, X, Y):
#
# ITEMS SECTION    (INDEX, PROFIT, WEIGHT, ASSIGNED NODE NUMBER):
#
# 206618.0
# thop/instances/dsj1000-thop/dsj1000_n2994_uncorr_05_01.thop
# NODE_COORD_SECTION  (INDEX, X, Y):
#
# ITEMS SECTION    (INDEX, PROFIT, WEIGHT, ASSIGNED NODE NUMBER):
#
# 448547.0
# thop/instances/dsj1000-thop/dsj1000_n2994_uncorr_05_02.thop
# NODE_COORD_SECTION  (INDEX, X, Y):
#
# ITEMS SECTION    (INDEX, PROFIT, WEIGHT, ASSIGNED NODE NUMBER):
#
# 653332.0
# thop/instances/dsj1000-thop/dsj1000_n2994_uncorr_05_03.thop
# NODE_COORD_SECTION  (INDEX, X, Y):
#
# ITEMS SECTION    (INDEX, PROFIT, WEIGHT, ASSIGNED NODE NUMBER):
#
# 737425.0
# thop/instances/dsj1000-thop/dsj1000_n2994_uncorr_10_01.thop
# NODE_COORD_SECTION  (INDEX, X, Y):
#
# ITEMS SECTION    (INDEX, PROFIT, WEIGHT, ASSIGNED NODE NUMBER):
#
# 609817.0
# thop/instances/dsj1000-thop/dsj1000_n2994_uncorr_10_02.thop
# NODE_COORD_SECTION  (INDEX, X, Y):
#
# ITEMS SECTION    (INDEX, PROFIT, WEIGHT, ASSIGNED NODE NUMBER):
#
# 809666.0
# thop/instances/dsj1000-thop/dsj1000_n2994_uncorr_10_03.thop
# NODE_COORD_SECTION  (INDEX, X, Y):
#
# ITEMS SECTION    (INDEX, PROFIT, WEIGHT, ASSIGNED NODE NUMBER):
#
# 997279.0
# thop/instances/dsj1000-thop/dsj1000_n2994_uncorr-similar-weights_01_01.thop
# NODE_COORD_SECTION  (INDEX, X, Y):
#
# ITEMS SECTION    (INDEX, PROFIT, WEIGHT, ASSIGNED NODE NUMBER):
#
# 150906.0
# thop/instances/dsj1000-thop/dsj1000_n2994_uncorr-similar-weights_01_02.thop
# NODE_COORD_SECTION  (INDEX, X, Y):
#
# ITEMS SECTION    (INDEX, PROFIT, WEIGHT, ASSIGNED NODE NUMBER):
#
# 153285.0
# thop/instances/dsj1000-thop/dsj1000_n2994_uncorr-similar-weights_01_03.thop
# NODE_COORD_SECTION  (INDEX, X, Y):
#
# ITEMS SECTION    (INDEX, PROFIT, WEIGHT, ASSIGNED NODE NUMBER):
#
# 154242.0
# thop/instances/dsj1000-thop/dsj1000_n2994_uncorr-similar-weights_05_01.thop
# NODE_COORD_SECTION  (INDEX, X, Y):
#
# ITEMS SECTION    (INDEX, PROFIT, WEIGHT, ASSIGNED NODE NUMBER):
#
# 689374.0
# thop/instances/dsj1000-thop/dsj1000_n2994_uncorr-similar-weights_05_02.thop
# NODE_COORD_SECTION  (INDEX, X, Y):
#
# ITEMS SECTION    (INDEX, PROFIT, WEIGHT, ASSIGNED NODE NUMBER):
#
# 744479.0
# thop/instances/dsj1000-thop/dsj1000_n2994_uncorr-similar-weights_05_03.thop
# NODE_COORD_SECTION  (INDEX, X, Y):
#
# ITEMS SECTION    (INDEX, PROFIT, WEIGHT, ASSIGNED NODE NUMBER):
#
# 745766.0
# thop/instances/dsj1000-thop/dsj1000_n2994_uncorr-similar-weights_10_01.thop
# NODE_COORD_SECTION  (INDEX, X, Y):
#
# ITEMS SECTION    (INDEX, PROFIT, WEIGHT, ASSIGNED NODE NUMBER):
#
# 872399.0
# thop/instances/dsj1000-thop/dsj1000_n2994_uncorr-similar-weights_10_02.thop
# NODE_COORD_SECTION  (INDEX, X, Y):
#
# ITEMS SECTION    (INDEX, PROFIT, WEIGHT, ASSIGNED NODE NUMBER):
#
# 1037106.0
# thop/instances/dsj1000-thop/dsj1000_n2994_uncorr-similar-weights_10_03.thop
# NODE_COORD_SECTION  (INDEX, X, Y):
#
# ITEMS SECTION    (INDEX, PROFIT, WEIGHT, ASSIGNED NODE NUMBER):
#
# 1229450.0
# thop/instances/dsj1000-thop/dsj1000_n4990_bounded-strongly-corr_01_01.thop
# NODE_COORD_SECTION  (INDEX, X, Y):
#
# ITEMS SECTION    (INDEX, PROFIT, WEIGHT, ASSIGNED NODE NUMBER):
#
# 525900.0
# thop/instances/dsj1000-thop/dsj1000_n4990_bounded-strongly-corr_01_02.thop
# NODE_COORD_SECTION  (INDEX, X, Y):
#
# ITEMS SECTION    (INDEX, PROFIT, WEIGHT, ASSIGNED NODE NUMBER):
#
# 530731.0
# thop/instances/dsj1000-thop/dsj1000_n4990_bounded-strongly-corr_01_03.thop
# NODE_COORD_SECTION  (INDEX, X, Y):
#
# ITEMS SECTION    (INDEX, PROFIT, WEIGHT, ASSIGNED NODE NUMBER):
#
# 530833.0
# thop/instances/dsj1000-thop/dsj1000_n4990_bounded-strongly-corr_05_01.thop
# NODE_COORD_SECTION  (INDEX, X, Y):
#
# ITEMS SECTION    (INDEX, PROFIT, WEIGHT, ASSIGNED NODE NUMBER):
#
# 2043539.0
# thop/instances/dsj1000-thop/dsj1000_n4990_bounded-strongly-corr_05_02.thop
# NODE_COORD_SECTION  (INDEX, X, Y):
#
# ITEMS SECTION    (INDEX, PROFIT, WEIGHT, ASSIGNED NODE NUMBER):
#
# 2526093.0
# thop/instances/dsj1000-thop/dsj1000_n4990_bounded-strongly-corr_05_03.thop
# NODE_COORD_SECTION  (INDEX, X, Y):
#
# ITEMS SECTION    (INDEX, PROFIT, WEIGHT, ASSIGNED NODE NUMBER):
#
# 2617494.0
# thop/instances/dsj1000-thop/dsj1000_n4990_bounded-strongly-corr_10_01.thop
# NODE_COORD_SECTION  (INDEX, X, Y):
#
# ITEMS SECTION    (INDEX, PROFIT, WEIGHT, ASSIGNED NODE NUMBER):
#
# 2774048.0
# thop/instances/dsj1000-thop/dsj1000_n4990_bounded-strongly-corr_10_02.thop
# NODE_COORD_SECTION  (INDEX, X, Y):
#
# ITEMS SECTION    (INDEX, PROFIT, WEIGHT, ASSIGNED NODE NUMBER):
#
# 3676106.0
# thop/instances/dsj1000-thop/dsj1000_n4990_bounded-strongly-corr_10_03.thop
# NODE_COORD_SECTION  (INDEX, X, Y):
#
# ITEMS SECTION    (INDEX, PROFIT, WEIGHT, ASSIGNED NODE NUMBER):
#
# 4285254.0
# thop/instances/dsj1000-thop/dsj1000_n4990_uncorr_01_01.thop
# NODE_COORD_SECTION  (INDEX, X, Y):
#
# ITEMS SECTION    (INDEX, PROFIT, WEIGHT, ASSIGNED NODE NUMBER):
#
# 273598.0
# thop/instances/dsj1000-thop/dsj1000_n4990_uncorr_01_02.thop
# NODE_COORD_SECTION  (INDEX, X, Y):
#
# ITEMS SECTION    (INDEX, PROFIT, WEIGHT, ASSIGNED NODE NUMBER):
#
# 280228.0
# thop/instances/dsj1000-thop/dsj1000_n4990_uncorr_01_03.thop
# NODE_COORD_SECTION  (INDEX, X, Y):
#
# ITEMS SECTION    (INDEX, PROFIT, WEIGHT, ASSIGNED NODE NUMBER):
#
# 285023.0
# thop/instances/dsj1000-thop/dsj1000_n4990_uncorr_05_01.thop
# NODE_COORD_SECTION  (INDEX, X, Y):
#
# ITEMS SECTION    (INDEX, PROFIT, WEIGHT, ASSIGNED NODE NUMBER):
#
# 675164.0
# thop/instances/dsj1000-thop/dsj1000_n4990_uncorr_05_02.thop
# NODE_COORD_SECTION  (INDEX, X, Y):
#
# ITEMS SECTION    (INDEX, PROFIT, WEIGHT, ASSIGNED NODE NUMBER):
#
# 963082.0
# thop/instances/dsj1000-thop/dsj1000_n4990_uncorr_05_03.thop
# NODE_COORD_SECTION  (INDEX, X, Y):
#
# ITEMS SECTION    (INDEX, PROFIT, WEIGHT, ASSIGNED NODE NUMBER):
#
# 1113048.0
# thop/instances/dsj1000-thop/dsj1000_n4990_uncorr_10_01.thop
# NODE_COORD_SECTION  (INDEX, X, Y):
#
# ITEMS SECTION    (INDEX, PROFIT, WEIGHT, ASSIGNED NODE NUMBER):
#
# 833905.0
# thop/instances/dsj1000-thop/dsj1000_n4990_uncorr_10_02.thop
# NODE_COORD_SECTION  (INDEX, X, Y):
#
# ITEMS SECTION    (INDEX, PROFIT, WEIGHT, ASSIGNED NODE NUMBER):
#
# 1234388.0
# thop/instances/dsj1000-thop/dsj1000_n4990_uncorr_10_03.thop
# NODE_COORD_SECTION  (INDEX, X, Y):
#
# ITEMS SECTION    (INDEX, PROFIT, WEIGHT, ASSIGNED NODE NUMBER):
#
# 1640430.0
# thop/instances/dsj1000-thop/dsj1000_n4990_uncorr-similar-weights_01_01.thop
# NODE_COORD_SECTION  (INDEX, X, Y):
#
# ITEMS SECTION    (INDEX, PROFIT, WEIGHT, ASSIGNED NODE NUMBER):
#
# 242174.0
# thop/instances/dsj1000-thop/dsj1000_n4990_uncorr-similar-weights_01_02.thop
# NODE_COORD_SECTION  (INDEX, X, Y):
#
# ITEMS SECTION    (INDEX, PROFIT, WEIGHT, ASSIGNED NODE NUMBER):
#
# 250359.0
# thop/instances/dsj1000-thop/dsj1000_n4990_uncorr-similar-weights_01_03.thop
# NODE_COORD_SECTION  (INDEX, X, Y):
#
# ITEMS SECTION    (INDEX, PROFIT, WEIGHT, ASSIGNED NODE NUMBER):
#
# 248067.0
# thop/instances/dsj1000-thop/dsj1000_n4990_uncorr-similar-weights_05_01.thop
# NODE_COORD_SECTION  (INDEX, X, Y):
#
# ITEMS SECTION    (INDEX, PROFIT, WEIGHT, ASSIGNED NODE NUMBER):
#
# 1094805.0
# thop/instances/dsj1000-thop/dsj1000_n4990_uncorr-similar-weights_05_02.thop
# NODE_COORD_SECTION  (INDEX, X, Y):
#
# ITEMS SECTION    (INDEX, PROFIT, WEIGHT, ASSIGNED NODE NUMBER):
# 1183408.0
# thop/instances/dsj1000-thop/dsj1000_n4990_uncorr-similar-weights_05_03.thop
# NODE_COORD_SECTION  (INDEX, X, Y):
#
# ITEMS SECTION    (INDEX, PROFIT, WEIGHT, ASSIGNED NODE NUMBER):
#
# 1192111.0
# thop/instances/dsj1000-thop/dsj1000_n4990_uncorr-similar-weights_10_01.thop
# NODE_COORD_SECTION  (INDEX, X, Y):
#
# ITEMS SECTION    (INDEX, PROFIT, WEIGHT, ASSIGNED NODE NUMBER):
#
# 1424285.0
# thop/instances/dsj1000-thop/dsj1000_n4990_uncorr-similar-weights_10_02.thop
# NODE_COORD_SECTION  (INDEX, X, Y):
#
# ITEMS SECTION    (INDEX, PROFIT, WEIGHT, ASSIGNED NODE NUMBER):
#
# 1718074.0
# thop/instances/dsj1000-thop/dsj1000_n4990_uncorr-similar-weights_10_03.thop
# NODE_COORD_SECTION  (INDEX, X, Y):
#
# ITEMS SECTION    (INDEX, PROFIT, WEIGHT, ASSIGNED NODE NUMBER):
#
# 1959515.0
# thop/instances/dsj1000-thop/dsj1000_n998_bounded-strongly-corr_01_01.thop
# NODE_COORD_SECTION  (INDEX, X, Y):
#
# ITEMS SECTION    (INDEX, PROFIT, WEIGHT, ASSIGNED NODE NUMBER):
#
# 110725.0
# thop/instances/dsj1000-thop/dsj1000_n998_bounded-strongly-corr_01_02.thop
# NODE_COORD_SECTION  (INDEX, X, Y):
#
# ITEMS SECTION    (INDEX, PROFIT, WEIGHT, ASSIGNED NODE NUMBER):
#
# 110716.0
# thop/instances/dsj1000-thop/dsj1000_n998_bounded-strongly-corr_01_03.thop
# NODE_COORD_SECTION  (INDEX, X, Y):
#
# ITEMS SECTION    (INDEX, PROFIT, WEIGHT, ASSIGNED NODE NUMBER):
#
# 110419.0
# thop/instances/dsj1000-thop/dsj1000_n998_bounded-strongly-corr_05_01.thop
# NODE_COORD_SECTION  (INDEX, X, Y):
#
# ITEMS SECTION    (INDEX, PROFIT, WEIGHT, ASSIGNED NODE NUMBER):
#
# 346949.0
# thop/instances/dsj1000-thop/dsj1000_n998_bounded-strongly-corr_05_02.thop
# NODE_COORD_SECTION  (INDEX, X, Y):
#
# ITEMS SECTION    (INDEX, PROFIT, WEIGHT, ASSIGNED NODE NUMBER):
#
# 456219.0
# thop/instances/dsj1000-thop/dsj1000_n998_bounded-strongly-corr_05_03.thop
# NODE_COORD_SECTION  (INDEX, X, Y):
#
# ITEMS SECTION    (INDEX, PROFIT, WEIGHT, ASSIGNED NODE NUMBER):
#
# 508467.0
# thop/instances/dsj1000-thop/dsj1000_n998_bounded-strongly-corr_10_01.thop
# NODE_COORD_SECTION  (INDEX, X, Y):
#
# ITEMS SECTION    (INDEX, PROFIT, WEIGHT, ASSIGNED NODE NUMBER):
#
# 511541.0
# thop/instances/dsj1000-thop/dsj1000_n998_bounded-strongly-corr_10_02.thop
# NODE_COORD_SECTION  (INDEX, X, Y):
#
# ITEMS SECTION    (INDEX, PROFIT, WEIGHT, ASSIGNED NODE NUMBER):
#
# 696299.0
# thop/instances/dsj1000-thop/dsj1000_n998_bounded-strongly-corr_10_03.thop
# NODE_COORD_SECTION  (INDEX, X, Y):
#
# ITEMS SECTION    (INDEX, PROFIT, WEIGHT, ASSIGNED NODE NUMBER):
#
# 845913.0
# thop/instances/dsj1000-thop/dsj1000_n998_uncorr_01_01.thop
# NODE_COORD_SECTION  (INDEX, X, Y):
#
# ITEMS SECTION    (INDEX, PROFIT, WEIGHT, ASSIGNED NODE NUMBER):
#
# 123870.0
# thop/instances/dsj1000-thop/dsj1000_n998_uncorr_01_02.thop
# NODE_COORD_SECTION  (INDEX, X, Y):
#
# ITEMS SECTION    (INDEX, PROFIT, WEIGHT, ASSIGNED NODE NUMBER):
#
# 124529.0
# thop/instances/dsj1000-thop/dsj1000_n998_uncorr_01_03.thop
# NODE_COORD_SECTION  (INDEX, X, Y):
#
# ITEMS SECTION    (INDEX, PROFIT, WEIGHT, ASSIGNED NODE NUMBER):
#
# 125033.0
# thop/instances/dsj1000-thop/dsj1000_n998_uncorr_05_01.thop
# NODE_COORD_SECTION  (INDEX, X, Y):
#
# ITEMS SECTION    (INDEX, PROFIT, WEIGHT, ASSIGNED NODE NUMBER):
#
# 112596.0
# thop/instances/dsj1000-thop/dsj1000_n998_uncorr_05_02.thop
# NODE_COORD_SECTION  (INDEX, X, Y):
#
# ITEMS SECTION    (INDEX, PROFIT, WEIGHT, ASSIGNED NODE NUMBER):
#
# 179603.0
# thop/instances/dsj1000-thop/dsj1000_n998_uncorr_05_03.thop
# NODE_COORD_SECTION  (INDEX, X, Y):
#
# ITEMS SECTION    (INDEX, PROFIT, WEIGHT, ASSIGNED NODE NUMBER):
#
# 246461.0
# thop/instances/dsj1000-thop/dsj1000_n998_uncorr_10_01.thop
# NODE_COORD_SECTION  (INDEX, X, Y):
#
# ITEMS SECTION    (INDEX, PROFIT, WEIGHT, ASSIGNED NODE NUMBER):
#
# 157310.0
# thop/instances/dsj1000-thop/dsj1000_n998_uncorr_10_02.thop
# NODE_COORD_SECTION  (INDEX, X, Y):
#
# ITEMS SECTION    (INDEX, PROFIT, WEIGHT, ASSIGNED NODE NUMBER):
#
# 252265.0
# thop/instances/dsj1000-thop/dsj1000_n998_uncorr_10_03.thop
# NODE_COORD_SECTION  (INDEX, X, Y):
#
# ITEMS SECTION    (INDEX, PROFIT, WEIGHT, ASSIGNED NODE NUMBER):
#
# 333684.0
# thop/instances/dsj1000-thop/dsj1000_n998_uncorr-similar-weights_01_01.thop
# NODE_COORD_SECTION  (INDEX, X, Y):
#
# ITEMS SECTION    (INDEX, PROFIT, WEIGHT, ASSIGNED NODE NUMBER):
#
# 69700.0
# thop/instances/dsj1000-thop/dsj1000_n998_uncorr-similar-weights_01_02.thop
# NODE_COORD_SECTION  (INDEX, X, Y):
#
# ITEMS SECTION    (INDEX, PROFIT, WEIGHT, ASSIGNED NODE NUMBER):
#
# 68135.0
# thop/instances/dsj1000-thop/dsj1000_n998_uncorr-similar-weights_01_03.thop
# NODE_COORD_SECTION  (INDEX, X, Y):
#
# ITEMS SECTION    (INDEX, PROFIT, WEIGHT, ASSIGNED NODE NUMBER):
#
# 69276.0
# thop/instances/dsj1000-thop/dsj1000_n998_uncorr-similar-weights_05_01.thop
# NODE_COORD_SECTION  (INDEX, X, Y):
#
# ITEMS SECTION    (INDEX, PROFIT, WEIGHT, ASSIGNED NODE NUMBER):
#
# 197104.0
# thop/instances/dsj1000-thop/dsj1000_n998_uncorr-similar-weights_05_02.thop
# NODE_COORD_SECTION  (INDEX, X, Y):
#
# ITEMS SECTION    (INDEX, PROFIT, WEIGHT, ASSIGNED NODE NUMBER):
#
# 245857.0
# thop/instances/dsj1000-thop/dsj1000_n998_uncorr-similar-weights_05_03.thop
# NODE_COORD_SECTION  (INDEX, X, Y):
#
# ITEMS SECTION    (INDEX, PROFIT, WEIGHT, ASSIGNED NODE NUMBER):
#
# 269308.0
# thop/instances/dsj1000-thop/dsj1000_n998_uncorr-similar-weights_10_01.thop
# NODE_COORD_SECTION  (INDEX, X, Y):
#
# ITEMS SECTION    (INDEX, PROFIT, WEIGHT, ASSIGNED NODE NUMBER):
#
# 277397.0
# thop/instances/dsj1000-thop/dsj1000_n998_uncorr-similar-weights_10_02.thop
# NODE_COORD_SECTION  (INDEX, X, Y):
#
# ITEMS SECTION    (INDEX, PROFIT, WEIGHT, ASSIGNED NODE NUMBER):

# %%
import csv
with open('some.csv', 'rb') as f:
    reader = csv.reader(f)
    for row in reader:
        print row

# %%
for numero in resultados:
    print(int(numero))
