# %%
# metaheuristica procurar ponto mais proximo de 2 pontos e colocar ele ali no meio

import math
import copy
def solucaoFinal(vRota, vItens, matriz, itens, vMin, vMax, v, maxTime, w):
    vRota = [0] + vRota + [len(matriz)-1]
    peso = 0
    valor=0
    itensCid=[]
    for x in matriz:
        itensCid.append([])
    for x in vItens:        
        #print(x)
        itensCid[int(itens[x][3])].append(itens[x])
        peso += itens[x][2]
        valor += itens[x][1]
    
    t = 0
    pesoAtual = 0
    for index, x in enumerate(vRota):
        #print(index,x , len(vRota))
        if(index < len(vRota)-1):
            for y in itensCid[x]:
                #print('cidade', x-1, 'peso', pesoAtual)
                pesoAtual +=y[2]
            #print(matriz[x-1][vRota[index+1]-1], vMax , v*pesoAtual, vMin)
            t += matriz[x][vRota[index+1]]/max(vMax - v*pesoAtual, vMin)
    tempoAtual = (t/maxTime) * (pesoAtual/w)
    #print('tempo', t,maxTime, pesoAtual, w, 'peso:', tempoAtual, valor)
    #print(t,maxTime , peso,w)
    if(t<=maxTime and pesoAtual<=w):
        return valor
    else:
        return -1
    return 0
def solucaoFinal2(vRota, vItens, matriz, itens, vMin, vMax, v, maxTime, w):
    vRota = [0] + vRota + [len(matriz)-1]
    peso = 0
    valor=0
    itensCid=[]
    for x in matriz:
        itensCid.append([])
    for x in vItens:        
        #print(x)
        itensCid[int(itens[x][3])].append(itens[x])
        peso += itens[x][2]
        valor += itens[x][1]
    
    t = 0
    pesoAtual = 0
    for index, x in enumerate(vRota):
        #print(index,x , len(vRota))
        if(index < len(vRota)-1):
            for y in itensCid[x]:
                #print('cidade', x-1, 'peso', pesoAtual)
                pesoAtual +=y[2]
            #print(matriz[x-1][vRota[index+1]-1], vMax , v*pesoAtual, vMin)
            t += matriz[x][vRota[index+1]]/max(vMax - v*pesoAtual, vMin)
    tempoAtual = (t/maxTime) * (pesoAtual/w)
    #print('tempo', t,maxTime, pesoAtual, w, 'peso:', tempoAtual)
    #print(t,maxTime , peso,w)
    if(t<=maxTime and pesoAtual<=w):
        return valor, tempoAtual
    else:
        return -1, tempoAtual
    return 0
def dist(a, b):
    #print(a)
    #print(b)
    t = math.sqrt((a[1]-b[1])*(a[1]-b[1])+(a[2]-b[2])*(a[2]-b[2]))
    if int(t)==t:
        n = int(t)
    else:
        n = int(t)+1
    return n

def solucao(vRota, cidadeItens, matriz):
    vRota = [0] + vRota + [len(matriz)-1]
    peso = 0
    valor=0
    v = (maxSpeed - minSpeed)/capacity
    t = 0
    pesoAtual = 0
    for index, x in enumerate(vRota):
        #print(index,x , len(vRota))
        if(index < len(vRota)-1):
            valor+=cidadeItens[x]['valor']    
            pesoAtual +=cidadeItens[x]['peso']            
            t += matriz[x][vRota[index+1]]/max(maxSpeed - v*pesoAtual, minSpeed)
    if(t<=maxTime and pesoAtual<=capacity):
        return valor
    else:
        return -1
    return 0


def proximaCidade(matriz, dadosCidade, cidadeAtual, cidadeVisitada):
    maxi = -1
    ind = -1
    for index, x in enumerate(dadosCidade):
        #if  matriz[cidadeAtual][index]==0 and cidadeAtual!=index:
            #print(cidadeAtual, index, matriz[cidadeAtual][index])
            #continue
        value = (x/(matriz[cidadeAtual][index]+1))
        if (cidadeAtual!=index and maxi<value and not cidadeVisitada[index]):            
            maxi = value
            ind = index            
            
    return ind


def adicionaMaximoItens(rota, cidadeItens, cidadeAtual, itens, matriz, todosItens):
    rotaCopia = copy.deepcopy(rota)
    rotaCopia.append(cidadeAtual)
    lastResult = -1
    for x in itens:       
        cidadeItens[cidadeAtual]['valor']+=x[1]
        cidadeItens[cidadeAtual]['peso']+=x[2]         
        cidadeItens[cidadeAtual]['qtdItens']+=1
        todosItens.append(x[0])
        result = solucao(rotaCopia, cidadeItens, matriz)
        #print(rotaCopia, cidadeItens[cidadeAtual])
        if result==-1:            
            cidadeItens[cidadeAtual]['valor']-=x[1]
            cidadeItens[cidadeAtual]['peso']-=x[2]
            cidadeItens[cidadeAtual]['qtdItens']-=1
            todosItens.remove(x[0])
            break
        else:
            lastResult = result
            if(cidadeAtual not in rota):
                rota.append(cidadeAtual)
            
    return lastResult

def melhoraVelocidade(rota):
    
    solAtual, tempoAtual = solucaoFinal2(rota, todosItens.copy(), matrizAdjacencia.copy(), itens.copy(), minS, maxS, (maxS-minS)/cap, maxT, cap)
    print(solAtual, tempoAtual)
    aux22= copy.deepcopy(rota)
    for x in range(5):
        rotaVazia=[]
        for x in range(len(rota)-2):
            if (matrizCidadeProxima[rota[x]][rota[x+1]] in rota):
                rotaCopia = copy.deepcopy(rota)        
                rotaVazia=[]
                for index, i in enumerate(rotaCopia):
                    if i == matrizCidadeProxima[rotaCopia[x]][rotaCopia[x+1]]:
                        pass
                    elif rota[index]!=rotaCopia[x]:
                        rotaVazia.append(rotaCopia[index])

                    elif rota[index]==rotaCopia[x]:                
                        rotaVazia.append(rotaCopia[index])
                        rotaVazia.append(matrizCidadeProxima[rotaCopia[x]][rotaCopia[x+1]])                              

                        #print(len(rotaCopia), x)



                solu, tempo = solucaoFinal2(rotaVazia, todosItens.copy(), matrizAdjacencia.copy(), itens.copy(), minS, maxS, (maxS-minS)/cap, maxT, cap)
                if(tempo<tempoAtual):
                    rota=rotaVazia
                    tempoAtual=tempo
                    solAtual = solu

        retornoa,b = solucaoFinal2(rota, todosItens.copy(), matrizAdjacencia.copy(), itens.copy(), minS, maxS, (maxS-minS)/cap, maxT, cap)
        print(retornoa, b)
        for index, x in enumerate(cidadeVisitada):
            cidadeVisitada[index]=False
        cidadeVisitada[0]=True
        cidadeVisitada[len(cidadeVisitada)-1]=True
        for x in rota:
            cidadeVisitada[x]=True


        for x in range(len(matrizAdjacencia)): 
            cidadeProxima = proximaCidade(matrizAdjacencia, dadosCidade, rota[len(rota)-1], cidadeVisitada)
            #print(cidadeProxima)
            if(cidadeProxima ==-1):
                continue
            cidadeVisitada[cidadeProxima]=True    
            adicionaMaximoItens(rota, cidadeItens, cidadeProxima, itensCidade[cidadeProxima], matrizAdjacencia, todosItens)
            #print(solution)
            cidadeAtual = cidadeProxima
    retornoa,b = solucaoFinal2(rota, todosItens.copy(), matrizAdjacencia.copy(), itens.copy(), minS, maxS, (maxS-minS)/cap, maxT, cap)
    print(retornoa, b)
    return retornoa, b

# %%
import numpy as np
import json
import random
resultados = []
import csv
arquivo='xxx'
podeEntrar=False
with open('file.csv', "rt") as f:
    reader = csv.reader(f)
    for row in reader:
        
        if (row[0] == 'dsj1000_n2994_uncorr-similar-weights_05_02.thop'):
            #break
            podeEntrar=True
        if podeEntrar==False:
            continue
        print ('thop/instances/'+row[0].split('_')[0] +'-thop/'+row[0])
        pontos = []
        itens = []


        with open('thop/instances/'+row[0].split('_')[0] +'-thop/'+row[0], 'r') as file:    
            name = file.readline().strip().replace(' ','').split(':')[1]    
            knapsack = file.readline().strip().replace(' ','').split(':')[1]    
            dimension = int(file.readline().strip().replace(' ','').split(':')[1])
            nItens = int(file.readline().strip().replace(' ','').split(':')[1])
            capacity = int(file.readline().strip().replace(' ','').split(':')[1])
            maxTime = int(file.readline().strip().replace(' ','').split(':')[1])
            minSpeed = float(file.readline().strip().replace(' ','').split(':')[1])
            maxSpeed = float(file.readline().strip().replace(' ','').split(':')[1])
            edgeType = file.readline().strip().replace(' ','').split(':')[1]
            pontosSection = True

            for x in file:
                if 'NODE_COORD_SECTION' in x: 
                    print(x)
                elif 'ITEMS SECTION' in x: 
                    pontosSection = False
                    print(x)
                else:
                    if(pontosSection):
                        pontos.append([float(i) for i in x.split()])
                    else:                
                        itens.append([float(i) if index!=0 and index!=3 else int(i)-1 for index, i in enumerate(x.split())]+[float(x.split()[1])/float(x.split()[2])]+[False])

        #print(pontos)
        #print(itens)



        matrizAdjacencia = []
        vetorCidadeProxima = {}
        itensCidade=[]
        dadosCidade = []
        cidadeVisitada = []

        for x in pontos:    
            itensCidade.append([])      
            dadosCidade.append(0) 
            cidadeVisitada.append(False)
            aux = []
            menor = 100000000000
            for y in pontos:
                d = dist(x,y)
                if(d<menor):
                    menor=d
                    ponto = y
                aux.append(d)

            vetorCidadeProxima[x[0]]=ponto[0]
            matrizAdjacencia.append(aux)

        for x in itens:
            itensCidade[int(x[3])].append(x)
            dadosCidade[int(x[3])]+=x[4]
        itensOrdenados = []
        #print(itensCidade)

        for index, x in enumerate(itensCidade):
            itensCidade[index]= sorted(x, key=lambda y: y[5], reverse=True)
            #print(itensOrdenados[index])
        #for x in itensOrdenados:
            #print (x)




    ################################
    
        
        if(arquivo!=row[0].split('_')[0]):
            arquivo=row[0].split('_')[0]
            print('entrou')



            #rota, cidadeItens
            matrizCidadeProxima = []
            for x in matrizAdjacencia:    
                matrizCidadeProxima.append([0]*len(matrizAdjacencia))
            ind = -1
            for x in range(len(matrizCidadeProxima)):
                for y in range(len(matrizCidadeProxima)):
                    soma = 10000000000000000        
                    for z in range(len(matrizCidadeProxima)):
                        if(x!=y and y!=z and z!=x):
                            valor = matrizAdjacencia[x][z] + matrizAdjacencia[z][y]
                            #print(valor)
                            if(soma > valor):
                                ind = z
                                soma = valor
                    matrizCidadeProxima[x][y] = ind
            matrizCidadeProxima[0]

            print("saiu")
        ##################################
        solucoes = []
        for nSolucoes in range(20):
            minS = minSpeed
            maxS = maxSpeed
            cap = capacity
            maxT = maxTime
            todosItens = []  
            for index, x in enumerate(cidadeVisitada):
                cidadeVisitada[index]=False
            cidadeVisitada[0]=True
            cidadeVisitada[len(cidadeVisitada)-1]=True

            cidadeItens=[]
            for x in range(len(matrizAdjacencia)):
                cidadeItens.append(copy.deepcopy({'peso':0, 'valor':0, 'qtdItens':0}))


            rota = []
            while(len(rota)==0):
                cidadeInicial = np.random.randint(1, len(pontos)-1)
                #rota.append(cidadeInicial)
                cidadeAtual = cidadeInicial
                cidadeVisitada[cidadeInicial]=True


                adicionaMaximoItens(rota, cidadeItens, cidadeInicial, itensCidade[cidadeAtual], matrizAdjacencia, todosItens)
            #print('saiu')
            #print('sol', solucaoFinal(rota, todosItens.copy(), matrizAdjacencia.copy(), itens.copy(), minS, maxS, (maxS-minS)/cap, maxT, cap))
            #cidadeAtual = cidadeInicial
            for x in range(len(matrizAdjacencia)):  
                cidadeProxima = proximaCidade(matrizAdjacencia, dadosCidade, cidadeAtual, cidadeVisitada)
                #print(cidadeProxima)
                if(cidadeProxima ==-1):
                    continue
                cidadeVisitada[cidadeProxima]=True    
                adicionaMaximoItens(rota, cidadeItens, cidadeProxima, itensCidade[cidadeProxima], matrizAdjacencia, todosItens)
                #print(solution)
                cidadeAtual = cidadeProxima


            soma = 0
            for x in cidadeItens:
                soma += x['valor']
            #print(rota, todosItens, soma)



            #################################

            melhorSolucao = -1
            naoSei = 0
            while(naoSei < 50):
                solAtual, tempoAtual = solucaoFinal2(rota, todosItens.copy(), matrizAdjacencia.copy(), itens.copy(), minS, maxS, (maxS-minS)/cap, maxT, cap)
                #print(solAtual, tempoAtual)
                aux22= []
                while len(rota)!=len(aux22):#se não adicionar ninguem sai
                    #print("adicionou")
                    aux22= copy.deepcopy(rota)
                    aux33 = []
                    while rota!=aux33:#se não mudar ninguem de lugar sai
                        aux33 = copy.deepcopy(rota)
                        rotaVazia=[]
                        for x in range(len(rota)-1):
                            if (matrizCidadeProxima[rota[x]][rota[x+1]] in rota):
                                rotaCopia = copy.deepcopy(rota)        
                                rotaVazia=[]
                                for index, i in enumerate(rotaCopia):
                                    if i == matrizCidadeProxima[rotaCopia[x]][rotaCopia[x+1]]:
                                        pass
                                    elif rota[index]!=rotaCopia[x]:
                                        rotaVazia.append(rotaCopia[index])

                                    elif rota[index]==rotaCopia[x]:                
                                        rotaVazia.append(rotaCopia[index])
                                        rotaVazia.append(matrizCidadeProxima[rotaCopia[x]][rotaCopia[x+1]])



                                solu, tempo = solucaoFinal2(rotaVazia, todosItens.copy(), matrizAdjacencia.copy(), itens.copy(), minS, maxS, (maxS-minS)/cap, maxT, cap)
                                if(tempo<tempoAtual):
                                    rota=rotaVazia
                                    tempoAtual=tempo
                                    solAtual = solu
                        solu, tempo = solucaoFinal2(rota, todosItens.copy(), matrizAdjacencia.copy(), itens.copy(), minS, maxS, (maxS-minS)/cap, maxT, cap)
                        #print(solu, tempo)
                        '''
                        for index, x in enumerate(cidadeVisitada):
                            cidadeVisitada[index]=False
                        cidadeVisitada[0]=True
                        cidadeVisitada[len(cidadeVisitada)-1]=True
                        for x in rota:
                            cidadeVisitada[x]=True
                        '''


                    #print('antes trocar pos', solucaoFinal2(rota, todosItens.copy(), matrizAdjacencia.copy(), itens.copy(), minS, maxS, (maxS-minS)/cap, maxT, cap))                    
                    for x in range(len(matrizAdjacencia)): 
                        cidadeProxima = proximaCidade(matrizAdjacencia, dadosCidade, rota[len(rota)-1], cidadeVisitada)
                        #print(cidadeProxima)
                        if(cidadeProxima ==-1):
                            continue
                        cidadeVisitada[cidadeProxima]=True    
                        adicionaMaximoItens(rota, cidadeItens, cidadeProxima, itensCidade[cidadeProxima], matrizAdjacencia, todosItens)
                        #print(solution)
                        cidadeAtual = cidadeProxima

                    solucaoAux = solucaoFinal(rota, todosItens.copy(), matrizAdjacencia.copy(), itens.copy(), minS, maxS, (maxS-minS)/cap, maxT, cap)
                    #print(solucaoAux)
                    #print('depois de trocar', solucaoFinal2(rota, todosItens.copy(), matrizAdjacencia.copy(), itens.copy(), minS, maxS, (maxS-minS)/cap, maxT, cap))
                atualSolucao = solucaoFinal(rota, todosItens.copy(), matrizAdjacencia.copy(), itens.copy(), minS, maxS, (maxS-minS)/cap, maxT, cap)
                
                if atualSolucao > melhorSolucao:
                    melhorSolucao = atualSolucao
                    melhorRota = rota
                    melhorItens = todosItens
                    melhorCidadeItens = cidadeItens
                solucoes.append({'instancia':row[0],'solucao':melhorSolucao, 'rota':melhorRota, 'itens':melhorItens})
                #print('outra solução')
                #################################
                
                ###gera outra solução e repete###
                
                #################################

                #melhoraVelocidade(rota)
                #solucoes.append(solucaoAux)
                rotaInicial = copy.deepcopy(rota)
                if len(rotaInicial)>20:
                    percent = len(rotaInicial)/10
                elif len(rotaInicial)>=3:
                    percent = len(rotaInicial)/3     
                else:
                    percent = len(rotaInicial)

                itensIniciais = copy.deepcopy(todosItens)
                cidadeItensIniciais = copy.deepcopy(cidadeItens)

                
                #############################################################
                
                
                #melhorSolucao = solucaoFinal(rota, todosItens.copy(), matrizAdjacencia.copy(), itens.copy(), minS, maxS, (maxS-minS)/cap, maxT, cap)

                #print(percent)
                
                #print('antesde gerar ', solucaoFinal(rota, todosItens.copy(), matrizAdjacencia.copy(), itens.copy(), minS, maxS, (maxS-minS)/cap, maxT, cap))

                while True:
                    rotaCopia = copy.deepcopy(rota)
                    cidadeItensCopia = copy.deepcopy(cidadeItens)
                    todosItensCopia = copy.deepcopy(todosItens)
                    cidadeVisitadaCopia = copy.deepcopy(cidadeVisitada)
                    valorSolucaoCopia = solucaoFinal(rota, todosItens.copy(), matrizAdjacencia.copy(), itens.copy(), minS, maxS, (maxS-minS)/cap, maxT, cap)
                    for i in range(int(percent)):
                        element = random.choice (rota)
                        todosItens = [h for h in todosItens if itens[h][3] != element]
                        rota.remove(element)                
                        cidadeItens[element]['valor']=0
                        cidadeItens[element]['peso']=0
                        cidadeItens[element]['qtdItens']=0
                        #print(len(rotaInicial))

                    cidadeVisitada = [True if x in rota else False for x in range(len(pontos))]
                    if len(rota)==0:
                        cidadeInicial = np.random.randint(1, len(pontos)-1)
                        #rota.append(cidadeInicial)
                        cidadeAtual = cidadeInicial
                        cidadeVisitada[cidadeInicial]=True
                        adicionaMaximoItens(rota, cidadeItens, cidadeInicial, itensCidade[cidadeAtual], matrizAdjacencia, todosItens)
                    else:
                        cidadeAtual = rota[len(rota)-1]
                    for x in range(len(matrizAdjacencia)):
                        cidadeProxima = proximaCidade(matrizAdjacencia, dadosCidade, cidadeAtual, cidadeVisitada)
                        #print(cidadeProxima)
                        if(cidadeProxima ==-1):
                            break
                        cidadeVisitada[cidadeProxima]=True    
                        adicionaMaximoItens(rota, cidadeItens, cidadeProxima, itensCidade[cidadeProxima], matrizAdjacencia, todosItens)
                        #print(solution)
                        cidadeAtual = cidadeProxima
                    valorSolucao = solucaoFinal(rota, todosItens.copy(), matrizAdjacencia.copy(), itens.copy(), minS, maxS, (maxS-minS)/cap, maxT, cap)
                    
                    if valorSolucao == -1 or valorSolucao <= valorSolucaoCopia:
                        rota = copy.deepcopy(rotaCopia)
                        cidadeItens = copy.deepcopy(cidadeItensCopia)
                        todosItens = copy.deepcopy(todosItensCopia)
                        cidadeVisitada = copy.deepcopy(cidadeVisitadaCopia)  
                    
                    if((valorSolucao!=-1 and valorSolucao > valorSolucaoCopia) or naoSei == 50):
                        #print('gerouSolucao aqui ', solucaoFinal(rota, todosItens.copy(), matrizAdjacencia.copy(), itens.copy(), minS, maxS, (maxS-minS)/cap, maxT, cap))
                        naoSei+=1
                        break
                        
                    naoSei+=1
                    
              
                #print('sol', solucaoAux, atualSolucao)  

            #solucoes.append(melhorSolucao)
                    
                    
            solucoes.append({'instancia':row[0],'solucao':melhorSolucao, 'rota':melhorRota, 'itens':melhorItens})
        maior=-1
        for x in solucoes:
            if x['solucao']>maior:
                maior=x['solucao']
                salvaInd=x
        with open('solucao.json','a') as ar:
            json.dump(salvaInd, ar)
        
        print(maior)
        #resultados.append(max(solucoes))
       
        #print(rota, aux22)
        #soma=0
        #for x in range(len(rota)):
        #    if rota[x]!=aux22[x]:
        #        soma+=1
        #print(soma)
# Out:
# thop/instances/eil51-thop/eil51_n147_bounded-strongly-corr_01_01.thop
# NODE_COORD_SECTION  (INDEX, X, Y):
#
# ITEMS SECTION    (INDEX, PROFIT, WEIGHT, ASSIGNED NODE NUMBER):
#
# entrou
# saiu
# 16059.0
# thop/instances/eil51-thop/eil51_n147_bounded-strongly-corr_01_02.thop
# NODE_COORD_SECTION  (INDEX, X, Y):
#
# ITEMS SECTION    (INDEX, PROFIT, WEIGHT, ASSIGNED NODE NUMBER):
#
# 16653.0
# thop/instances/eil51-thop/eil51_n147_bounded-strongly-corr_01_03.thop
# NODE_COORD_SECTION  (INDEX, X, Y):
#
# ITEMS SECTION    (INDEX, PROFIT, WEIGHT, ASSIGNED NODE NUMBER):
#
# 17310.0
# thop/instances/eil51-thop/eil51_n147_bounded-strongly-corr_05_01.thop
# NODE_COORD_SECTION  (INDEX, X, Y):
#
# ITEMS SECTION    (INDEX, PROFIT, WEIGHT, ASSIGNED NODE NUMBER):
#
# 57866.0
# thop/instances/eil51-thop/eil51_n147_bounded-strongly-corr_05_02.thop
# NODE_COORD_SECTION  (INDEX, X, Y):
#
# ITEMS SECTION    (INDEX, PROFIT, WEIGHT, ASSIGNED NODE NUMBER):
#
# 68962.0
# thop/instances/eil51-thop/eil51_n147_bounded-strongly-corr_05_03.thop
# NODE_COORD_SECTION  (INDEX, X, Y):
#
# ITEMS SECTION    (INDEX, PROFIT, WEIGHT, ASSIGNED NODE NUMBER):
#
# 74772.0
# thop/instances/eil51-thop/eil51_n147_bounded-strongly-corr_10_01.thop
# NODE_COORD_SECTION  (INDEX, X, Y):
#
# ITEMS SECTION    (INDEX, PROFIT, WEIGHT, ASSIGNED NODE NUMBER):
#
# 84611.0
# thop/instances/eil51-thop/eil51_n147_bounded-strongly-corr_10_02.thop
# NODE_COORD_SECTION  (INDEX, X, Y):
#
# ITEMS SECTION    (INDEX, PROFIT, WEIGHT, ASSIGNED NODE NUMBER):
#
# 106218.0
# thop/instances/eil51-thop/eil51_n147_bounded-strongly-corr_10_03.thop
# NODE_COORD_SECTION  (INDEX, X, Y):
#
# ITEMS SECTION    (INDEX, PROFIT, WEIGHT, ASSIGNED NODE NUMBER):
#
# 121700.0
# thop/instances/eil51-thop/eil51_n147_uncorr_01_01.thop
# NODE_COORD_SECTION  (INDEX, X, Y):
#
# ITEMS SECTION    (INDEX, PROFIT, WEIGHT, ASSIGNED NODE NUMBER):
#
# 11262.0
# thop/instances/eil51-thop/eil51_n147_uncorr_01_02.thop
# NODE_COORD_SECTION  (INDEX, X, Y):
#
# ITEMS SECTION    (INDEX, PROFIT, WEIGHT, ASSIGNED NODE NUMBER):
#
# 12099.0
# thop/instances/eil51-thop/eil51_n147_uncorr_01_03.thop
# NODE_COORD_SECTION  (INDEX, X, Y):
#
# ITEMS SECTION    (INDEX, PROFIT, WEIGHT, ASSIGNED NODE NUMBER):
#
# 13446.0
# thop/instances/eil51-thop/eil51_n147_uncorr_05_01.thop
# NODE_COORD_SECTION  (INDEX, X, Y):
#
# ITEMS SECTION    (INDEX, PROFIT, WEIGHT, ASSIGNED NODE NUMBER):
#
# 25325.0
# thop/instances/eil51-thop/eil51_n147_uncorr_05_02.thop
# NODE_COORD_SECTION  (INDEX, X, Y):
#
# ITEMS SECTION    (INDEX, PROFIT, WEIGHT, ASSIGNED NODE NUMBER):
#
# 32244.0
# thop/instances/eil51-thop/eil51_n147_uncorr_05_03.thop
# NODE_COORD_SECTION  (INDEX, X, Y):
#
# ITEMS SECTION    (INDEX, PROFIT, WEIGHT, ASSIGNED NODE NUMBER):
#
# 37139.0
# thop/instances/eil51-thop/eil51_n147_uncorr_10_01.thop
# NODE_COORD_SECTION  (INDEX, X, Y):
#
# ITEMS SECTION    (INDEX, PROFIT, WEIGHT, ASSIGNED NODE NUMBER):
#
# 33404.0
# thop/instances/eil51-thop/eil51_n147_uncorr_10_02.thop
# NODE_COORD_SECTION  (INDEX, X, Y):
#
# ITEMS SECTION    (INDEX, PROFIT, WEIGHT, ASSIGNED NODE NUMBER):
#
# 44721.0
# thop/instances/eil51-thop/eil51_n147_uncorr_10_03.thop
# NODE_COORD_SECTION  (INDEX, X, Y):
#
# ITEMS SECTION    (INDEX, PROFIT, WEIGHT, ASSIGNED NODE NUMBER):
#
# 52419.0
# thop/instances/eil51-thop/eil51_n147_uncorr-similar-weights_01_01.thop
# NODE_COORD_SECTION  (INDEX, X, Y):
#
# ITEMS SECTION    (INDEX, PROFIT, WEIGHT, ASSIGNED NODE NUMBER):
#
# 8166.0
# thop/instances/eil51-thop/eil51_n147_uncorr-similar-weights_01_02.thop
# NODE_COORD_SECTION  (INDEX, X, Y):
#
# ITEMS SECTION    (INDEX, PROFIT, WEIGHT, ASSIGNED NODE NUMBER):
#
# 9262.0
# thop/instances/eil51-thop/eil51_n147_uncorr-similar-weights_01_03.thop
# NODE_COORD_SECTION  (INDEX, X, Y):
#
# ITEMS SECTION    (INDEX, PROFIT, WEIGHT, ASSIGNED NODE NUMBER):
#
# 8887.0
# thop/instances/eil51-thop/eil51_n147_uncorr-similar-weights_05_01.thop
# NODE_COORD_SECTION  (INDEX, X, Y):
#
# ITEMS SECTION    (INDEX, PROFIT, WEIGHT, ASSIGNED NODE NUMBER):
#
# 30503.0
# thop/instances/eil51-thop/eil51_n147_uncorr-similar-weights_05_02.thop
# NODE_COORD_SECTION  (INDEX, X, Y):
#
# ITEMS SECTION    (INDEX, PROFIT, WEIGHT, ASSIGNED NODE NUMBER):
#
# 35091.0
# thop/instances/eil51-thop/eil51_n147_uncorr-similar-weights_05_03.thop
# NODE_COORD_SECTION  (INDEX, X, Y):
#
# ITEMS SECTION    (INDEX, PROFIT, WEIGHT, ASSIGNED NODE NUMBER):
#
# 37921.0
# thop/instances/eil51-thop/eil51_n147_uncorr-similar-weights_10_01.thop
# NODE_COORD_SECTION  (INDEX, X, Y):
#
# ITEMS SECTION    (INDEX, PROFIT, WEIGHT, ASSIGNED NODE NUMBER):
#
# 40296.0
# thop/instances/eil51-thop/eil51_n147_uncorr-similar-weights_10_02.thop
# NODE_COORD_SECTION  (INDEX, X, Y):
#
# ITEMS SECTION    (INDEX, PROFIT, WEIGHT, ASSIGNED NODE NUMBER):
#
# 49823.0
# thop/instances/eil51-thop/eil51_n147_uncorr-similar-weights_10_03.thop
# NODE_COORD_SECTION  (INDEX, X, Y):
#
# ITEMS SECTION    (INDEX, PROFIT, WEIGHT, ASSIGNED NODE NUMBER):
#
# 57557.0
# thop/instances/eil51-thop/eil51_n245_bounded-strongly-corr_01_01.thop
# NODE_COORD_SECTION  (INDEX, X, Y):
#
# ITEMS SECTION    (INDEX, PROFIT, WEIGHT, ASSIGNED NODE NUMBER):
#
# 29418.0
# thop/instances/eil51-thop/eil51_n245_bounded-strongly-corr_01_02.thop
# NODE_COORD_SECTION  (INDEX, X, Y):
#
# ITEMS SECTION    (INDEX, PROFIT, WEIGHT, ASSIGNED NODE NUMBER):
#
# 29991.0
# thop/instances/eil51-thop/eil51_n245_bounded-strongly-corr_01_03.thop
# NODE_COORD_SECTION  (INDEX, X, Y):
#
# ITEMS SECTION    (INDEX, PROFIT, WEIGHT, ASSIGNED NODE NUMBER):
#
# 30486.0
# thop/instances/eil51-thop/eil51_n245_bounded-strongly-corr_05_01.thop
# NODE_COORD_SECTION  (INDEX, X, Y):
#
# ITEMS SECTION    (INDEX, PROFIT, WEIGHT, ASSIGNED NODE NUMBER):
#
# 97589.0
# thop/instances/eil51-thop/eil51_n245_bounded-strongly-corr_05_02.thop
# NODE_COORD_SECTION  (INDEX, X, Y):
#
# ITEMS SECTION    (INDEX, PROFIT, WEIGHT, ASSIGNED NODE NUMBER):
#
# 125934.0
# thop/instances/eil51-thop/eil51_n245_bounded-strongly-corr_05_03.thop
# NODE_COORD_SECTION  (INDEX, X, Y):
#
# ITEMS SECTION    (INDEX, PROFIT, WEIGHT, ASSIGNED NODE NUMBER):
#
# 137356.0
# thop/instances/eil51-thop/eil51_n245_bounded-strongly-corr_10_01.thop
# NODE_COORD_SECTION  (INDEX, X, Y):
#
# ITEMS SECTION    (INDEX, PROFIT, WEIGHT, ASSIGNED NODE NUMBER):
#
# 138985.0
# thop/instances/eil51-thop/eil51_n245_bounded-strongly-corr_10_02.thop
# NODE_COORD_SECTION  (INDEX, X, Y):
#
# ITEMS SECTION    (INDEX, PROFIT, WEIGHT, ASSIGNED NODE NUMBER):
#
# 181726.0
# thop/instances/eil51-thop/eil51_n245_bounded-strongly-corr_10_03.thop
# NODE_COORD_SECTION  (INDEX, X, Y):
#
# ITEMS SECTION    (INDEX, PROFIT, WEIGHT, ASSIGNED NODE NUMBER):
#
# 212235.0
# thop/instances/eil51-thop/eil51_n245_uncorr_01_01.thop
# NODE_COORD_SECTION  (INDEX, X, Y):
#
# ITEMS SECTION    (INDEX, PROFIT, WEIGHT, ASSIGNED NODE NUMBER):
#
# 16907.0
# thop/instances/eil51-thop/eil51_n245_uncorr_01_02.thop
# NODE_COORD_SECTION  (INDEX, X, Y):
#
# ITEMS SECTION    (INDEX, PROFIT, WEIGHT, ASSIGNED NODE NUMBER):
#
# 17389.0
# thop/instances/eil51-thop/eil51_n245_uncorr_01_03.thop
# NODE_COORD_SECTION  (INDEX, X, Y):
#
# ITEMS SECTION    (INDEX, PROFIT, WEIGHT, ASSIGNED NODE NUMBER):
#
# 18428.0
# thop/instances/eil51-thop/eil51_n245_uncorr_05_01.thop
# NODE_COORD_SECTION  (INDEX, X, Y):
#
# ITEMS SECTION    (INDEX, PROFIT, WEIGHT, ASSIGNED NODE NUMBER):
#
# 43572.0
# thop/instances/eil51-thop/eil51_n245_uncorr_05_02.thop
# NODE_COORD_SECTION  (INDEX, X, Y):
#
# ITEMS SECTION    (INDEX, PROFIT, WEIGHT, ASSIGNED NODE NUMBER):
#
# 49980.0
# thop/instances/eil51-thop/eil51_n245_uncorr_05_03.thop
# NODE_COORD_SECTION  (INDEX, X, Y):
#
# ITEMS SECTION    (INDEX, PROFIT, WEIGHT, ASSIGNED NODE NUMBER):
#
# 59050.0
# thop/instances/eil51-thop/eil51_n245_uncorr_10_01.thop
# NODE_COORD_SECTION  (INDEX, X, Y):
#
# ITEMS SECTION    (INDEX, PROFIT, WEIGHT, ASSIGNED NODE NUMBER):
#
# 52164.0
# thop/instances/eil51-thop/eil51_n245_uncorr_10_02.thop
# NODE_COORD_SECTION  (INDEX, X, Y):
#
# ITEMS SECTION    (INDEX, PROFIT, WEIGHT, ASSIGNED NODE NUMBER):
#
# 69625.0
# thop/instances/eil51-thop/eil51_n245_uncorr_10_03.thop
# NODE_COORD_SECTION  (INDEX, X, Y):
#
# ITEMS SECTION    (INDEX, PROFIT, WEIGHT, ASSIGNED NODE NUMBER):
#
# 82208.0
# thop/instances/eil51-thop/eil51_n245_uncorr-similar-weights_01_01.thop
# NODE_COORD_SECTION  (INDEX, X, Y):
#
# ITEMS SECTION    (INDEX, PROFIT, WEIGHT, ASSIGNED NODE NUMBER):
#
# 13093.0
# thop/instances/eil51-thop/eil51_n245_uncorr-similar-weights_01_02.thop
# NODE_COORD_SECTION  (INDEX, X, Y):
#
# ITEMS SECTION    (INDEX, PROFIT, WEIGHT, ASSIGNED NODE NUMBER):
#
# 13601.0
# thop/instances/eil51-thop/eil51_n245_uncorr-similar-weights_01_03.thop
# NODE_COORD_SECTION  (INDEX, X, Y):
#
# ITEMS SECTION    (INDEX, PROFIT, WEIGHT, ASSIGNED NODE NUMBER):
# 13786.0
# thop/instances/eil51-thop/eil51_n245_uncorr-similar-weights_05_01.thop
# NODE_COORD_SECTION  (INDEX, X, Y):
#
# ITEMS SECTION    (INDEX, PROFIT, WEIGHT, ASSIGNED NODE NUMBER):
#
# 47140.0
# thop/instances/eil51-thop/eil51_n245_uncorr-similar-weights_05_02.thop
# NODE_COORD_SECTION  (INDEX, X, Y):
#
# ITEMS SECTION    (INDEX, PROFIT, WEIGHT, ASSIGNED NODE NUMBER):
#
# 57451.0
# thop/instances/eil51-thop/eil51_n245_uncorr-similar-weights_05_03.thop
# NODE_COORD_SECTION  (INDEX, X, Y):
#
# ITEMS SECTION    (INDEX, PROFIT, WEIGHT, ASSIGNED NODE NUMBER):
#
# 60979.0
# thop/instances/eil51-thop/eil51_n245_uncorr-similar-weights_10_01.thop
# NODE_COORD_SECTION  (INDEX, X, Y):
#
# ITEMS SECTION    (INDEX, PROFIT, WEIGHT, ASSIGNED NODE NUMBER):
#
# 62921.0
# thop/instances/eil51-thop/eil51_n245_uncorr-similar-weights_10_02.thop
# NODE_COORD_SECTION  (INDEX, X, Y):
#
# ITEMS SECTION    (INDEX, PROFIT, WEIGHT, ASSIGNED NODE NUMBER):
#
# 83390.0
# thop/instances/eil51-thop/eil51_n245_uncorr-similar-weights_10_03.thop
# NODE_COORD_SECTION  (INDEX, X, Y):
#
# ITEMS SECTION    (INDEX, PROFIT, WEIGHT, ASSIGNED NODE NUMBER):
#
# 98183.0
# thop/instances/eil51-thop/eil51_n49_bounded-strongly-corr_01_01.thop
# NODE_COORD_SECTION  (INDEX, X, Y):
#
# ITEMS SECTION    (INDEX, PROFIT, WEIGHT, ASSIGNED NODE NUMBER):
#
# 5003.0
# thop/instances/eil51-thop/eil51_n49_bounded-strongly-corr_01_02.thop
# NODE_COORD_SECTION  (INDEX, X, Y):
#
# ITEMS SECTION    (INDEX, PROFIT, WEIGHT, ASSIGNED NODE NUMBER):
#
# 5667.0
# thop/instances/eil51-thop/eil51_n49_bounded-strongly-corr_01_03.thop
# NODE_COORD_SECTION  (INDEX, X, Y):
#
# ITEMS SECTION    (INDEX, PROFIT, WEIGHT, ASSIGNED NODE NUMBER):
#
# 6358.0
# thop/instances/eil51-thop/eil51_n49_bounded-strongly-corr_05_01.thop
# NODE_COORD_SECTION  (INDEX, X, Y):
#
# ITEMS SECTION    (INDEX, PROFIT, WEIGHT, ASSIGNED NODE NUMBER):
#
# 14372.0
# thop/instances/eil51-thop/eil51_n49_bounded-strongly-corr_05_02.thop
# NODE_COORD_SECTION  (INDEX, X, Y):
#
# ITEMS SECTION    (INDEX, PROFIT, WEIGHT, ASSIGNED NODE NUMBER):
#
# 20083.0
# thop/instances/eil51-thop/eil51_n49_bounded-strongly-corr_05_03.thop
# NODE_COORD_SECTION  (INDEX, X, Y):
#
# ITEMS SECTION    (INDEX, PROFIT, WEIGHT, ASSIGNED NODE NUMBER):
#
# 23361.0
# thop/instances/eil51-thop/eil51_n49_bounded-strongly-corr_10_01.thop
# NODE_COORD_SECTION  (INDEX, X, Y):
#
# ITEMS SECTION    (INDEX, PROFIT, WEIGHT, ASSIGNED NODE NUMBER):
#
# 24619.0
# thop/instances/eil51-thop/eil51_n49_bounded-strongly-corr_10_02.thop
# NODE_COORD_SECTION  (INDEX, X, Y):
#
# ITEMS SECTION    (INDEX, PROFIT, WEIGHT, ASSIGNED NODE NUMBER):
#
# 32149.0
# thop/instances/eil51-thop/eil51_n49_bounded-strongly-corr_10_03.thop
# NODE_COORD_SECTION  (INDEX, X, Y):
#
# ITEMS SECTION    (INDEX, PROFIT, WEIGHT, ASSIGNED NODE NUMBER):
#
# 37934.0
# thop/instances/eil51-thop/eil51_n49_uncorr_01_01.thop
# NODE_COORD_SECTION  (INDEX, X, Y):
#
# ITEMS SECTION    (INDEX, PROFIT, WEIGHT, ASSIGNED NODE NUMBER):
#
# 5658.0
# thop/instances/eil51-thop/eil51_n49_uncorr_01_02.thop
# NODE_COORD_SECTION  (INDEX, X, Y):
#
# ITEMS SECTION    (INDEX, PROFIT, WEIGHT, ASSIGNED NODE NUMBER):
#
# 7154.0
# thop/instances/eil51-thop/eil51_n49_uncorr_01_03.thop
# NODE_COORD_SECTION  (INDEX, X, Y):
#
# ITEMS SECTION    (INDEX, PROFIT, WEIGHT, ASSIGNED NODE NUMBER):
#
# 7347.0
# thop/instances/eil51-thop/eil51_n49_uncorr_05_01.thop
# NODE_COORD_SECTION  (INDEX, X, Y):
#
# ITEMS SECTION    (INDEX, PROFIT, WEIGHT, ASSIGNED NODE NUMBER):
#
# 8449.0
# thop/instances/eil51-thop/eil51_n49_uncorr_05_02.thop
# NODE_COORD_SECTION  (INDEX, X, Y):
#
# ITEMS SECTION    (INDEX, PROFIT, WEIGHT, ASSIGNED NODE NUMBER):
#
# 12301.0
# thop/instances/eil51-thop/eil51_n49_uncorr_05_03.thop
# NODE_COORD_SECTION  (INDEX, X, Y):
#
# ITEMS SECTION    (INDEX, PROFIT, WEIGHT, ASSIGNED NODE NUMBER):
#
# 15161.0
# thop/instances/eil51-thop/eil51_n49_uncorr_10_01.thop
# NODE_COORD_SECTION  (INDEX, X, Y):
#
# ITEMS SECTION    (INDEX, PROFIT, WEIGHT, ASSIGNED NODE NUMBER):
#
# 11080.0
# thop/instances/eil51-thop/eil51_n49_uncorr_10_02.thop
# NODE_COORD_SECTION  (INDEX, X, Y):
#
# ITEMS SECTION    (INDEX, PROFIT, WEIGHT, ASSIGNED NODE NUMBER):
#
# 15448.0
# thop/instances/eil51-thop/eil51_n49_uncorr_10_03.thop
# NODE_COORD_SECTION  (INDEX, X, Y):
#
# ITEMS SECTION    (INDEX, PROFIT, WEIGHT, ASSIGNED NODE NUMBER):
#
# 18865.0
# thop/instances/eil51-thop/eil51_n49_uncorr-similar-weights_01_01.thop
# NODE_COORD_SECTION  (INDEX, X, Y):
#
# ITEMS SECTION    (INDEX, PROFIT, WEIGHT, ASSIGNED NODE NUMBER):
#
# 2425.0
# thop/instances/eil51-thop/eil51_n49_uncorr-similar-weights_01_02.thop
# NODE_COORD_SECTION  (INDEX, X, Y):
#
# ITEMS SECTION    (INDEX, PROFIT, WEIGHT, ASSIGNED NODE NUMBER):
#
# 3023.0
# thop/instances/eil51-thop/eil51_n49_uncorr-similar-weights_01_03.thop
# NODE_COORD_SECTION  (INDEX, X, Y):
#
# ITEMS SECTION    (INDEX, PROFIT, WEIGHT, ASSIGNED NODE NUMBER):
#
# 3185.0
# thop/instances/eil51-thop/eil51_n49_uncorr-similar-weights_05_01.thop
# NODE_COORD_SECTION  (INDEX, X, Y):
#
# ITEMS SECTION    (INDEX, PROFIT, WEIGHT, ASSIGNED NODE NUMBER):
#
# 9965.0
# thop/instances/eil51-thop/eil51_n49_uncorr-similar-weights_05_02.thop
# NODE_COORD_SECTION  (INDEX, X, Y):
#
# ITEMS SECTION    (INDEX, PROFIT, WEIGHT, ASSIGNED NODE NUMBER):
#
# 12070.0
# thop/instances/eil51-thop/eil51_n49_uncorr-similar-weights_05_03.thop
# NODE_COORD_SECTION  (INDEX, X, Y):
#
# ITEMS SECTION    (INDEX, PROFIT, WEIGHT, ASSIGNED NODE NUMBER):
#
# 13598.0
# thop/instances/eil51-thop/eil51_n49_uncorr-similar-weights_10_01.thop
# NODE_COORD_SECTION  (INDEX, X, Y):
#
# ITEMS SECTION    (INDEX, PROFIT, WEIGHT, ASSIGNED NODE NUMBER):
#
# 12648.0
# thop/instances/eil51-thop/eil51_n49_uncorr-similar-weights_10_02.thop
# NODE_COORD_SECTION  (INDEX, X, Y):
#
# ITEMS SECTION    (INDEX, PROFIT, WEIGHT, ASSIGNED NODE NUMBER):
#
# 16187.0
# thop/instances/eil51-thop/eil51_n49_uncorr-similar-weights_10_03.thop
# NODE_COORD_SECTION  (INDEX, X, Y):
#
# ITEMS SECTION    (INDEX, PROFIT, WEIGHT, ASSIGNED NODE NUMBER):
#
# 19045.0
# thop/instances/eil51-thop/eil51_n490_bounded-strongly-corr_01_01.thop
# NODE_COORD_SECTION  (INDEX, X, Y):
#
# ITEMS SECTION    (INDEX, PROFIT, WEIGHT, ASSIGNED NODE NUMBER):
#
# 55610.0
# thop/instances/eil51-thop/eil51_n490_bounded-strongly-corr_01_02.thop
# NODE_COORD_SECTION  (INDEX, X, Y):
#
# ITEMS SECTION    (INDEX, PROFIT, WEIGHT, ASSIGNED NODE NUMBER):
#
# 56533.0
# thop/instances/eil51-thop/eil51_n490_bounded-strongly-corr_01_03.thop
# NODE_COORD_SECTION  (INDEX, X, Y):
#
# ITEMS SECTION    (INDEX, PROFIT, WEIGHT, ASSIGNED NODE NUMBER):
#
# 56706.0
# thop/instances/eil51-thop/eil51_n490_bounded-strongly-corr_05_01.thop
# NODE_COORD_SECTION  (INDEX, X, Y):
#
# ITEMS SECTION    (INDEX, PROFIT, WEIGHT, ASSIGNED NODE NUMBER):
#
# 205997.0
# thop/instances/eil51-thop/eil51_n490_bounded-strongly-corr_05_02.thop
# NODE_COORD_SECTION  (INDEX, X, Y):
#
# ITEMS SECTION    (INDEX, PROFIT, WEIGHT, ASSIGNED NODE NUMBER):
#
# 252518.0
# thop/instances/eil51-thop/eil51_n490_bounded-strongly-corr_05_03.thop
# NODE_COORD_SECTION  (INDEX, X, Y):
#
# ITEMS SECTION    (INDEX, PROFIT, WEIGHT, ASSIGNED NODE NUMBER):
#
# 267687.0
# thop/instances/eil51-thop/eil51_n490_bounded-strongly-corr_10_01.thop
# NODE_COORD_SECTION  (INDEX, X, Y):
#
# ITEMS SECTION    (INDEX, PROFIT, WEIGHT, ASSIGNED NODE NUMBER):
#
# 296380.0
# thop/instances/eil51-thop/eil51_n490_bounded-strongly-corr_10_02.thop
# NODE_COORD_SECTION  (INDEX, X, Y):
#
# ITEMS SECTION    (INDEX, PROFIT, WEIGHT, ASSIGNED NODE NUMBER):
#
# 371141.0
# thop/instances/eil51-thop/eil51_n490_bounded-strongly-corr_10_03.thop
# NODE_COORD_SECTION  (INDEX, X, Y):
#
# ITEMS SECTION    (INDEX, PROFIT, WEIGHT, ASSIGNED NODE NUMBER):
#
# 436722.0
# thop/instances/eil51-thop/eil51_n490_uncorr_01_01.thop
# NODE_COORD_SECTION  (INDEX, X, Y):
#
# ITEMS SECTION    (INDEX, PROFIT, WEIGHT, ASSIGNED NODE NUMBER):
#
# 29955.0
# thop/instances/eil51-thop/eil51_n490_uncorr_01_02.thop
# NODE_COORD_SECTION  (INDEX, X, Y):
#
# ITEMS SECTION    (INDEX, PROFIT, WEIGHT, ASSIGNED NODE NUMBER):
#
# 31531.0
# thop/instances/eil51-thop/eil51_n490_uncorr_01_03.thop
# NODE_COORD_SECTION  (INDEX, X, Y):
#
# ITEMS SECTION    (INDEX, PROFIT, WEIGHT, ASSIGNED NODE NUMBER):
#
# 31652.0
# thop/instances/eil51-thop/eil51_n490_uncorr_05_01.thop
# NODE_COORD_SECTION  (INDEX, X, Y):
#
# ITEMS SECTION    (INDEX, PROFIT, WEIGHT, ASSIGNED NODE NUMBER):
#
# 78619.0
# thop/instances/eil51-thop/eil51_n490_uncorr_05_02.thop
# NODE_COORD_SECTION  (INDEX, X, Y):
#
# ITEMS SECTION    (INDEX, PROFIT, WEIGHT, ASSIGNED NODE NUMBER):
#
# 104209.0
# thop/instances/eil51-thop/eil51_n490_uncorr_05_03.thop
# NODE_COORD_SECTION  (INDEX, X, Y):
#
# ITEMS SECTION    (INDEX, PROFIT, WEIGHT, ASSIGNED NODE NUMBER):
# 117130.0
# thop/instances/eil51-thop/eil51_n490_uncorr_10_01.thop
# NODE_COORD_SECTION  (INDEX, X, Y):
#
# ITEMS SECTION    (INDEX, PROFIT, WEIGHT, ASSIGNED NODE NUMBER):
#
# 97295.0
# thop/instances/eil51-thop/eil51_n490_uncorr_10_02.thop
# NODE_COORD_SECTION  (INDEX, X, Y):
#
# ITEMS SECTION    (INDEX, PROFIT, WEIGHT, ASSIGNED NODE NUMBER):
#
# 143097.0
# thop/instances/eil51-thop/eil51_n490_uncorr_10_03.thop
# NODE_COORD_SECTION  (INDEX, X, Y):
#
# ITEMS SECTION    (INDEX, PROFIT, WEIGHT, ASSIGNED NODE NUMBER):
#
# 171987.0
# thop/instances/eil51-thop/eil51_n490_uncorr-similar-weights_01_01.thop
# NODE_COORD_SECTION  (INDEX, X, Y):
#
# ITEMS SECTION    (INDEX, PROFIT, WEIGHT, ASSIGNED NODE NUMBER):
#
# 25280.0
# thop/instances/eil51-thop/eil51_n490_uncorr-similar-weights_01_02.thop
# NODE_COORD_SECTION  (INDEX, X, Y):
#
# ITEMS SECTION    (INDEX, PROFIT, WEIGHT, ASSIGNED NODE NUMBER):
#
# 26778.0
# thop/instances/eil51-thop/eil51_n490_uncorr-similar-weights_01_03.thop
# NODE_COORD_SECTION  (INDEX, X, Y):
#
# ITEMS SECTION    (INDEX, PROFIT, WEIGHT, ASSIGNED NODE NUMBER):
#
# 26013.0
# thop/instances/eil51-thop/eil51_n490_uncorr-similar-weights_05_01.thop
# NODE_COORD_SECTION  (INDEX, X, Y):
#
# ITEMS SECTION    (INDEX, PROFIT, WEIGHT, ASSIGNED NODE NUMBER):
#
# 100940.0
# thop/instances/eil51-thop/eil51_n490_uncorr-similar-weights_05_02.thop
# NODE_COORD_SECTION  (INDEX, X, Y):
#
# ITEMS SECTION    (INDEX, PROFIT, WEIGHT, ASSIGNED NODE NUMBER):
#
# 111662.0
# thop/instances/eil51-thop/eil51_n490_uncorr-similar-weights_05_03.thop
# NODE_COORD_SECTION  (INDEX, X, Y):
#
# ITEMS SECTION    (INDEX, PROFIT, WEIGHT, ASSIGNED NODE NUMBER):
#
# 117815.0
# thop/instances/eil51-thop/eil51_n490_uncorr-similar-weights_10_01.thop
# NODE_COORD_SECTION  (INDEX, X, Y):
#
# ITEMS SECTION    (INDEX, PROFIT, WEIGHT, ASSIGNED NODE NUMBER):
#
# 127287.0
# thop/instances/eil51-thop/eil51_n490_uncorr-similar-weights_10_02.thop
# NODE_COORD_SECTION  (INDEX, X, Y):
#
# ITEMS SECTION    (INDEX, PROFIT, WEIGHT, ASSIGNED NODE NUMBER):
#
# 168006.0
# thop/instances/eil51-thop/eil51_n490_uncorr-similar-weights_10_03.thop
# NODE_COORD_SECTION  (INDEX, X, Y):
#
# ITEMS SECTION    (INDEX, PROFIT, WEIGHT, ASSIGNED NODE NUMBER):
#
# 186318.0
# thop/instances/pr107-thop/pr107_n105_bounded-strongly-corr_01_01.thop
# NODE_COORD_SECTION  (INDEX, X, Y):
#
# ITEMS SECTION    (INDEX, PROFIT, WEIGHT, ASSIGNED NODE NUMBER):
#
# entrou
# saiu
# 10419.0
# thop/instances/pr107-thop/pr107_n105_bounded-strongly-corr_01_02.thop
# NODE_COORD_SECTION  (INDEX, X, Y):
#
# ITEMS SECTION    (INDEX, PROFIT, WEIGHT, ASSIGNED NODE NUMBER):
#
# 11889.0
# thop/instances/pr107-thop/pr107_n105_bounded-strongly-corr_01_03.thop
# NODE_COORD_SECTION  (INDEX, X, Y):
#
# ITEMS SECTION    (INDEX, PROFIT, WEIGHT, ASSIGNED NODE NUMBER):
#
# 12241.0
# thop/instances/pr107-thop/pr107_n105_bounded-strongly-corr_05_01.thop
# NODE_COORD_SECTION  (INDEX, X, Y):
#
# ITEMS SECTION    (INDEX, PROFIT, WEIGHT, ASSIGNED NODE NUMBER):
#
# 33105.0
# thop/instances/pr107-thop/pr107_n105_bounded-strongly-corr_05_02.thop
# NODE_COORD_SECTION  (INDEX, X, Y):
#
# ITEMS SECTION    (INDEX, PROFIT, WEIGHT, ASSIGNED NODE NUMBER):
#
# 46050.0
# thop/instances/pr107-thop/pr107_n105_bounded-strongly-corr_05_03.thop
# NODE_COORD_SECTION  (INDEX, X, Y):
#
# ITEMS SECTION    (INDEX, PROFIT, WEIGHT, ASSIGNED NODE NUMBER):
#
# 51044.0
# thop/instances/pr107-thop/pr107_n105_bounded-strongly-corr_10_01.thop
# NODE_COORD_SECTION  (INDEX, X, Y):
#
# ITEMS SECTION    (INDEX, PROFIT, WEIGHT, ASSIGNED NODE NUMBER):
#
# 52311.0
# thop/instances/pr107-thop/pr107_n105_bounded-strongly-corr_10_02.thop
# NODE_COORD_SECTION  (INDEX, X, Y):
#
# ITEMS SECTION    (INDEX, PROFIT, WEIGHT, ASSIGNED NODE NUMBER):
#
# 71720.0
# thop/instances/pr107-thop/pr107_n105_bounded-strongly-corr_10_03.thop
# NODE_COORD_SECTION  (INDEX, X, Y):
#
# ITEMS SECTION    (INDEX, PROFIT, WEIGHT, ASSIGNED NODE NUMBER):
#
# 87792.0
# thop/instances/pr107-thop/pr107_n105_uncorr_01_01.thop
# NODE_COORD_SECTION  (INDEX, X, Y):
#
# ITEMS SECTION    (INDEX, PROFIT, WEIGHT, ASSIGNED NODE NUMBER):
#
# 6198.0
# thop/instances/pr107-thop/pr107_n105_uncorr_01_02.thop
# NODE_COORD_SECTION  (INDEX, X, Y):
#
# ITEMS SECTION    (INDEX, PROFIT, WEIGHT, ASSIGNED NODE NUMBER):
#
# 8521.0
# thop/instances/pr107-thop/pr107_n105_uncorr_01_03.thop
# NODE_COORD_SECTION  (INDEX, X, Y):
#
# ITEMS SECTION    (INDEX, PROFIT, WEIGHT, ASSIGNED NODE NUMBER):
#
# 9129.0
# thop/instances/pr107-thop/pr107_n105_uncorr_05_01.thop
# NODE_COORD_SECTION  (INDEX, X, Y):
#
# ITEMS SECTION    (INDEX, PROFIT, WEIGHT, ASSIGNED NODE NUMBER):
#
# 11386.0
# thop/instances/pr107-thop/pr107_n105_uncorr_05_02.thop
# NODE_COORD_SECTION  (INDEX, X, Y):
#
# ITEMS SECTION    (INDEX, PROFIT, WEIGHT, ASSIGNED NODE NUMBER):
#
# 15813.0
# thop/instances/pr107-thop/pr107_n105_uncorr_05_03.thop
# NODE_COORD_SECTION  (INDEX, X, Y):
#
# ITEMS SECTION    (INDEX, PROFIT, WEIGHT, ASSIGNED NODE NUMBER):
#
# 20309.0
# thop/instances/pr107-thop/pr107_n105_uncorr_10_01.thop
# NODE_COORD_SECTION  (INDEX, X, Y):
#
# ITEMS SECTION    (INDEX, PROFIT, WEIGHT, ASSIGNED NODE NUMBER):
#
# 13505.0
# thop/instances/pr107-thop/pr107_n105_uncorr_10_02.thop
# NODE_COORD_SECTION  (INDEX, X, Y):
#
# ITEMS SECTION    (INDEX, PROFIT, WEIGHT, ASSIGNED NODE NUMBER):
#
# 22035.0
# thop/instances/pr107-thop/pr107_n105_uncorr_10_03.thop
# NODE_COORD_SECTION  (INDEX, X, Y):
#
# ITEMS SECTION    (INDEX, PROFIT, WEIGHT, ASSIGNED NODE NUMBER):
#
# 27547.0
# thop/instances/pr107-thop/pr107_n105_uncorr-similar-weights_01_01.thop
# NODE_COORD_SECTION  (INDEX, X, Y):
#
# ITEMS SECTION    (INDEX, PROFIT, WEIGHT, ASSIGNED NODE NUMBER):
#
# 5286.0
# thop/instances/pr107-thop/pr107_n105_uncorr-similar-weights_01_02.thop
# NODE_COORD_SECTION  (INDEX, X, Y):
#
# ITEMS SECTION    (INDEX, PROFIT, WEIGHT, ASSIGNED NODE NUMBER):
#
# 6455.0
# thop/instances/pr107-thop/pr107_n105_uncorr-similar-weights_01_03.thop
# NODE_COORD_SECTION  (INDEX, X, Y):
#
# ITEMS SECTION    (INDEX, PROFIT, WEIGHT, ASSIGNED NODE NUMBER):
#
# 7485.0
# thop/instances/pr107-thop/pr107_n105_uncorr-similar-weights_05_01.thop
# NODE_COORD_SECTION  (INDEX, X, Y):
#
# ITEMS SECTION    (INDEX, PROFIT, WEIGHT, ASSIGNED NODE NUMBER):
#
# 23060.0
# thop/instances/pr107-thop/pr107_n105_uncorr-similar-weights_05_02.thop
# NODE_COORD_SECTION  (INDEX, X, Y):
#
# ITEMS SECTION    (INDEX, PROFIT, WEIGHT, ASSIGNED NODE NUMBER):
#
# 27843.0
# thop/instances/pr107-thop/pr107_n105_uncorr-similar-weights_05_03.thop
# NODE_COORD_SECTION  (INDEX, X, Y):
#
# ITEMS SECTION    (INDEX, PROFIT, WEIGHT, ASSIGNED NODE NUMBER):
#
# 28250.0
# thop/instances/pr107-thop/pr107_n105_uncorr-similar-weights_10_01.thop
# NODE_COORD_SECTION  (INDEX, X, Y):
#
# ITEMS SECTION    (INDEX, PROFIT, WEIGHT, ASSIGNED NODE NUMBER):
#
# 27892.0
# thop/instances/pr107-thop/pr107_n105_uncorr-similar-weights_10_02.thop
# NODE_COORD_SECTION  (INDEX, X, Y):
#
# ITEMS SECTION    (INDEX, PROFIT, WEIGHT, ASSIGNED NODE NUMBER):
#
# 29006.0
# thop/instances/pr107-thop/pr107_n105_uncorr-similar-weights_10_03.thop
# NODE_COORD_SECTION  (INDEX, X, Y):
#
# ITEMS SECTION    (INDEX, PROFIT, WEIGHT, ASSIGNED NODE NUMBER):
#
# 38652.0
# thop/instances/pr107-thop/pr107_n1050_bounded-strongly-corr_01_01.thop
# NODE_COORD_SECTION  (INDEX, X, Y):
#
# ITEMS SECTION    (INDEX, PROFIT, WEIGHT, ASSIGNED NODE NUMBER):
#
# 114624.0
# thop/instances/pr107-thop/pr107_n1050_bounded-strongly-corr_01_02.thop
# NODE_COORD_SECTION  (INDEX, X, Y):
#
# ITEMS SECTION    (INDEX, PROFIT, WEIGHT, ASSIGNED NODE NUMBER):
#
# 114678.0
# thop/instances/pr107-thop/pr107_n1050_bounded-strongly-corr_01_03.thop
# NODE_COORD_SECTION  (INDEX, X, Y):
#
# ITEMS SECTION    (INDEX, PROFIT, WEIGHT, ASSIGNED NODE NUMBER):
#
# 114984.0
# thop/instances/pr107-thop/pr107_n1050_bounded-strongly-corr_05_01.thop
# NODE_COORD_SECTION  (INDEX, X, Y):
#
# ITEMS SECTION    (INDEX, PROFIT, WEIGHT, ASSIGNED NODE NUMBER):
#
# 363839.0
# thop/instances/pr107-thop/pr107_n1050_bounded-strongly-corr_05_02.thop
# NODE_COORD_SECTION  (INDEX, X, Y):
#
# ITEMS SECTION    (INDEX, PROFIT, WEIGHT, ASSIGNED NODE NUMBER):
#
# 471988.0
# thop/instances/pr107-thop/pr107_n1050_bounded-strongly-corr_05_03.thop
# NODE_COORD_SECTION  (INDEX, X, Y):
#
# ITEMS SECTION    (INDEX, PROFIT, WEIGHT, ASSIGNED NODE NUMBER):
#
# 528086.0
# thop/instances/pr107-thop/pr107_n1050_bounded-strongly-corr_10_01.thop
# NODE_COORD_SECTION  (INDEX, X, Y):
#
# ITEMS SECTION    (INDEX, PROFIT, WEIGHT, ASSIGNED NODE NUMBER):
#
# 520829.0
# thop/instances/pr107-thop/pr107_n1050_bounded-strongly-corr_10_02.thop
# NODE_COORD_SECTION  (INDEX, X, Y):
#
# ITEMS SECTION    (INDEX, PROFIT, WEIGHT, ASSIGNED NODE NUMBER):
# 702149.0
# thop/instances/pr107-thop/pr107_n1050_bounded-strongly-corr_10_03.thop
# NODE_COORD_SECTION  (INDEX, X, Y):
#
# ITEMS SECTION    (INDEX, PROFIT, WEIGHT, ASSIGNED NODE NUMBER):
#
# 898731.0
# thop/instances/pr107-thop/pr107_n1050_uncorr_01_01.thop
# NODE_COORD_SECTION  (INDEX, X, Y):
#
# ITEMS SECTION    (INDEX, PROFIT, WEIGHT, ASSIGNED NODE NUMBER):
#
# 54296.0
# thop/instances/pr107-thop/pr107_n1050_uncorr_01_02.thop
# NODE_COORD_SECTION  (INDEX, X, Y):
#
# ITEMS SECTION    (INDEX, PROFIT, WEIGHT, ASSIGNED NODE NUMBER):
#
# 58277.0
# thop/instances/pr107-thop/pr107_n1050_uncorr_01_03.thop
# NODE_COORD_SECTION  (INDEX, X, Y):
#
# ITEMS SECTION    (INDEX, PROFIT, WEIGHT, ASSIGNED NODE NUMBER):
#
# 60007.0
# thop/instances/pr107-thop/pr107_n1050_uncorr_05_01.thop
# NODE_COORD_SECTION  (INDEX, X, Y):
#
# ITEMS SECTION    (INDEX, PROFIT, WEIGHT, ASSIGNED NODE NUMBER):
#
# 149824.0
# thop/instances/pr107-thop/pr107_n1050_uncorr_05_02.thop
# NODE_COORD_SECTION  (INDEX, X, Y):
#
# ITEMS SECTION    (INDEX, PROFIT, WEIGHT, ASSIGNED NODE NUMBER):
#
# 200678.0
# thop/instances/pr107-thop/pr107_n1050_uncorr_05_03.thop
# NODE_COORD_SECTION  (INDEX, X, Y):
#
# ITEMS SECTION    (INDEX, PROFIT, WEIGHT, ASSIGNED NODE NUMBER):
#
# 221804.0
# thop/instances/pr107-thop/pr107_n1050_uncorr_10_01.thop
# NODE_COORD_SECTION  (INDEX, X, Y):
#
# ITEMS SECTION    (INDEX, PROFIT, WEIGHT, ASSIGNED NODE NUMBER):
#
# 184295.0
# thop/instances/pr107-thop/pr107_n1050_uncorr_10_02.thop
# NODE_COORD_SECTION  (INDEX, X, Y):
#
# ITEMS SECTION    (INDEX, PROFIT, WEIGHT, ASSIGNED NODE NUMBER):
#
# 244032.0
# thop/instances/pr107-thop/pr107_n1050_uncorr_10_03.thop
# NODE_COORD_SECTION  (INDEX, X, Y):
#
# ITEMS SECTION    (INDEX, PROFIT, WEIGHT, ASSIGNED NODE NUMBER):
#
# 322230.0
# thop/instances/pr107-thop/pr107_n1050_uncorr-similar-weights_01_01.thop
# NODE_COORD_SECTION  (INDEX, X, Y):
#
# ITEMS SECTION    (INDEX, PROFIT, WEIGHT, ASSIGNED NODE NUMBER):
#
# 51434.0
# thop/instances/pr107-thop/pr107_n1050_uncorr-similar-weights_01_02.thop
# NODE_COORD_SECTION  (INDEX, X, Y):
#
# ITEMS SECTION    (INDEX, PROFIT, WEIGHT, ASSIGNED NODE NUMBER):
#
# 53819.0
# thop/instances/pr107-thop/pr107_n1050_uncorr-similar-weights_01_03.thop
# NODE_COORD_SECTION  (INDEX, X, Y):
#
# ITEMS SECTION    (INDEX, PROFIT, WEIGHT, ASSIGNED NODE NUMBER):
#
# 55471.0
# thop/instances/pr107-thop/pr107_n1050_uncorr-similar-weights_05_01.thop
# NODE_COORD_SECTION  (INDEX, X, Y):
#
# ITEMS SECTION    (INDEX, PROFIT, WEIGHT, ASSIGNED NODE NUMBER):
#
# 202668.0
# thop/instances/pr107-thop/pr107_n1050_uncorr-similar-weights_05_02.thop
# NODE_COORD_SECTION  (INDEX, X, Y):
#
# ITEMS SECTION    (INDEX, PROFIT, WEIGHT, ASSIGNED NODE NUMBER):
#
# 232721.0
# thop/instances/pr107-thop/pr107_n1050_uncorr-similar-weights_05_03.thop
# NODE_COORD_SECTION  (INDEX, X, Y):
#
# ITEMS SECTION    (INDEX, PROFIT, WEIGHT, ASSIGNED NODE NUMBER):
#
# 241015.0
# thop/instances/pr107-thop/pr107_n1050_uncorr-similar-weights_10_01.thop
# NODE_COORD_SECTION  (INDEX, X, Y):
#
# ITEMS SECTION    (INDEX, PROFIT, WEIGHT, ASSIGNED NODE NUMBER):
#
# 255025.0
# thop/instances/pr107-thop/pr107_n1050_uncorr-similar-weights_10_02.thop
# NODE_COORD_SECTION  (INDEX, X, Y):
#
# ITEMS SECTION    (INDEX, PROFIT, WEIGHT, ASSIGNED NODE NUMBER):
#
# 316781.0
# thop/instances/pr107-thop/pr107_n1050_uncorr-similar-weights_10_03.thop
# NODE_COORD_SECTION  (INDEX, X, Y):
#
# ITEMS SECTION    (INDEX, PROFIT, WEIGHT, ASSIGNED NODE NUMBER):
#
# 381255.0
# thop/instances/pr107-thop/pr107_n315_bounded-strongly-corr_01_01.thop
# NODE_COORD_SECTION  (INDEX, X, Y):
#
# ITEMS SECTION    (INDEX, PROFIT, WEIGHT, ASSIGNED NODE NUMBER):
#
# 35428.0
# thop/instances/pr107-thop/pr107_n315_bounded-strongly-corr_01_02.thop
# NODE_COORD_SECTION  (INDEX, X, Y):
#
# ITEMS SECTION    (INDEX, PROFIT, WEIGHT, ASSIGNED NODE NUMBER):
#
# 36859.0
# thop/instances/pr107-thop/pr107_n315_bounded-strongly-corr_01_03.thop
# NODE_COORD_SECTION  (INDEX, X, Y):
#
# ITEMS SECTION    (INDEX, PROFIT, WEIGHT, ASSIGNED NODE NUMBER):
#
# 37262.0
# thop/instances/pr107-thop/pr107_n315_bounded-strongly-corr_05_01.thop
# NODE_COORD_SECTION  (INDEX, X, Y):
#
# ITEMS SECTION    (INDEX, PROFIT, WEIGHT, ASSIGNED NODE NUMBER):
#
# 114775.0
# thop/instances/pr107-thop/pr107_n315_bounded-strongly-corr_05_02.thop
# NODE_COORD_SECTION  (INDEX, X, Y):
#
# ITEMS SECTION    (INDEX, PROFIT, WEIGHT, ASSIGNED NODE NUMBER):
#
# 143792.0
# thop/instances/pr107-thop/pr107_n315_bounded-strongly-corr_05_03.thop
# NODE_COORD_SECTION  (INDEX, X, Y):
#
# ITEMS SECTION    (INDEX, PROFIT, WEIGHT, ASSIGNED NODE NUMBER):
#
# 163826.0
# thop/instances/pr107-thop/pr107_n315_bounded-strongly-corr_10_01.thop
# NODE_COORD_SECTION  (INDEX, X, Y):
#
# ITEMS SECTION    (INDEX, PROFIT, WEIGHT, ASSIGNED NODE NUMBER):
#
# 167971.0
# thop/instances/pr107-thop/pr107_n315_bounded-strongly-corr_10_02.thop
# NODE_COORD_SECTION  (INDEX, X, Y):
#
# ITEMS SECTION    (INDEX, PROFIT, WEIGHT, ASSIGNED NODE NUMBER):
#
# 234342.0
# thop/instances/pr107-thop/pr107_n315_bounded-strongly-corr_10_03.thop
# NODE_COORD_SECTION  (INDEX, X, Y):
#
# ITEMS SECTION    (INDEX, PROFIT, WEIGHT, ASSIGNED NODE NUMBER):
#
# 283259.0
# thop/instances/pr107-thop/pr107_n315_uncorr_01_01.thop
# NODE_COORD_SECTION  (INDEX, X, Y):
#
# ITEMS SECTION    (INDEX, PROFIT, WEIGHT, ASSIGNED NODE NUMBER):
#
# 18876.0
# thop/instances/pr107-thop/pr107_n315_uncorr_01_02.thop
# NODE_COORD_SECTION  (INDEX, X, Y):
#
# ITEMS SECTION    (INDEX, PROFIT, WEIGHT, ASSIGNED NODE NUMBER):
#
# 21169.0
# thop/instances/pr107-thop/pr107_n315_uncorr_01_03.thop
# NODE_COORD_SECTION  (INDEX, X, Y):
#
# ITEMS SECTION    (INDEX, PROFIT, WEIGHT, ASSIGNED NODE NUMBER):
#
# 22696.0
# thop/instances/pr107-thop/pr107_n315_uncorr_05_01.thop
# NODE_COORD_SECTION  (INDEX, X, Y):
#
# ITEMS SECTION    (INDEX, PROFIT, WEIGHT, ASSIGNED NODE NUMBER):
#
# 40063.0
# thop/instances/pr107-thop/pr107_n315_uncorr_05_02.thop
# NODE_COORD_SECTION  (INDEX, X, Y):
#
# ITEMS SECTION    (INDEX, PROFIT, WEIGHT, ASSIGNED NODE NUMBER):
#
# 51377.0
# thop/instances/pr107-thop/pr107_n315_uncorr_05_03.thop
# NODE_COORD_SECTION  (INDEX, X, Y):
#
# ITEMS SECTION    (INDEX, PROFIT, WEIGHT, ASSIGNED NODE NUMBER):
#
# 63045.0
# thop/instances/pr107-thop/pr107_n315_uncorr_10_01.thop
# NODE_COORD_SECTION  (INDEX, X, Y):
#
# ITEMS SECTION    (INDEX, PROFIT, WEIGHT, ASSIGNED NODE NUMBER):
#
# 44369.0
# thop/instances/pr107-thop/pr107_n315_uncorr_10_02.thop
# NODE_COORD_SECTION  (INDEX, X, Y):
#
# ITEMS SECTION    (INDEX, PROFIT, WEIGHT, ASSIGNED NODE NUMBER):
#
# 66894.0
# thop/instances/pr107-thop/pr107_n315_uncorr_10_03.thop
# NODE_COORD_SECTION  (INDEX, X, Y):
#
# ITEMS SECTION    (INDEX, PROFIT, WEIGHT, ASSIGNED NODE NUMBER):
#
# 81820.0
# thop/instances/pr107-thop/pr107_n315_uncorr-similar-weights_01_01.thop
# NODE_COORD_SECTION  (INDEX, X, Y):
#
# ITEMS SECTION    (INDEX, PROFIT, WEIGHT, ASSIGNED NODE NUMBER):
#
# 16194.0
# thop/instances/pr107-thop/pr107_n315_uncorr-similar-weights_01_02.thop
# NODE_COORD_SECTION  (INDEX, X, Y):
#
# ITEMS SECTION    (INDEX, PROFIT, WEIGHT, ASSIGNED NODE NUMBER):
#
# 17056.0
# thop/instances/pr107-thop/pr107_n315_uncorr-similar-weights_01_03.thop
# NODE_COORD_SECTION  (INDEX, X, Y):
#
# ITEMS SECTION    (INDEX, PROFIT, WEIGHT, ASSIGNED NODE NUMBER):
#
# 18042.0
# thop/instances/pr107-thop/pr107_n315_uncorr-similar-weights_05_01.thop
# NODE_COORD_SECTION  (INDEX, X, Y):
#
# ITEMS SECTION    (INDEX, PROFIT, WEIGHT, ASSIGNED NODE NUMBER):
#
# 56981.0
# thop/instances/pr107-thop/pr107_n315_uncorr-similar-weights_05_02.thop
# NODE_COORD_SECTION  (INDEX, X, Y):
#
# ITEMS SECTION    (INDEX, PROFIT, WEIGHT, ASSIGNED NODE NUMBER):
#
# 72498.0
# thop/instances/pr107-thop/pr107_n315_uncorr-similar-weights_05_03.thop
# NODE_COORD_SECTION  (INDEX, X, Y):
#
# ITEMS SECTION    (INDEX, PROFIT, WEIGHT, ASSIGNED NODE NUMBER):
#
# 76200.0
# thop/instances/pr107-thop/pr107_n315_uncorr-similar-weights_10_01.thop
# NODE_COORD_SECTION  (INDEX, X, Y):
#
# ITEMS SECTION    (INDEX, PROFIT, WEIGHT, ASSIGNED NODE NUMBER):
#
# 76998.0
# thop/instances/pr107-thop/pr107_n315_uncorr-similar-weights_10_02.thop
# NODE_COORD_SECTION  (INDEX, X, Y):
#
# ITEMS SECTION    (INDEX, PROFIT, WEIGHT, ASSIGNED NODE NUMBER):
#
# 100957.0
# thop/instances/pr107-thop/pr107_n315_uncorr-similar-weights_10_03.thop
# NODE_COORD_SECTION  (INDEX, X, Y):
#
# ITEMS SECTION    (INDEX, PROFIT, WEIGHT, ASSIGNED NODE NUMBER):
#
# 116392.0
# thop/instances/pr107-thop/pr107_n525_bounded-strongly-corr_01_01.thop
# NODE_COORD_SECTION  (INDEX, X, Y):
#
# ITEMS SECTION    (INDEX, PROFIT, WEIGHT, ASSIGNED NODE NUMBER):
# 57693.0
# thop/instances/pr107-thop/pr107_n525_bounded-strongly-corr_01_02.thop
# NODE_COORD_SECTION  (INDEX, X, Y):
#
# ITEMS SECTION    (INDEX, PROFIT, WEIGHT, ASSIGNED NODE NUMBER):
#
# 59528.0
# thop/instances/pr107-thop/pr107_n525_bounded-strongly-corr_01_03.thop
# NODE_COORD_SECTION  (INDEX, X, Y):
#
# ITEMS SECTION    (INDEX, PROFIT, WEIGHT, ASSIGNED NODE NUMBER):
#
# 59452.0
# thop/instances/pr107-thop/pr107_n525_bounded-strongly-corr_05_01.thop
# NODE_COORD_SECTION  (INDEX, X, Y):
#
# ITEMS SECTION    (INDEX, PROFIT, WEIGHT, ASSIGNED NODE NUMBER):
#
# 197204.0
# thop/instances/pr107-thop/pr107_n525_bounded-strongly-corr_05_02.thop
# NODE_COORD_SECTION  (INDEX, X, Y):
#
# ITEMS SECTION    (INDEX, PROFIT, WEIGHT, ASSIGNED NODE NUMBER):
#
# 240415.0
# thop/instances/pr107-thop/pr107_n525_bounded-strongly-corr_05_03.thop
# NODE_COORD_SECTION  (INDEX, X, Y):
#
# ITEMS SECTION    (INDEX, PROFIT, WEIGHT, ASSIGNED NODE NUMBER):
#
# 269038.0
# thop/instances/pr107-thop/pr107_n525_bounded-strongly-corr_10_01.thop
# NODE_COORD_SECTION  (INDEX, X, Y):
#
# ITEMS SECTION    (INDEX, PROFIT, WEIGHT, ASSIGNED NODE NUMBER):
#
# 280567.0
# thop/instances/pr107-thop/pr107_n525_bounded-strongly-corr_10_02.thop
# NODE_COORD_SECTION  (INDEX, X, Y):
#
# ITEMS SECTION    (INDEX, PROFIT, WEIGHT, ASSIGNED NODE NUMBER):
#
# 368816.0
# thop/instances/pr107-thop/pr107_n525_bounded-strongly-corr_10_03.thop
# NODE_COORD_SECTION  (INDEX, X, Y):
#
# ITEMS SECTION    (INDEX, PROFIT, WEIGHT, ASSIGNED NODE NUMBER):
#
# 465288.0
# thop/instances/pr107-thop/pr107_n525_uncorr_01_01.thop
# NODE_COORD_SECTION  (INDEX, X, Y):
#
# ITEMS SECTION    (INDEX, PROFIT, WEIGHT, ASSIGNED NODE NUMBER):
#
# 29427.0
# thop/instances/pr107-thop/pr107_n525_uncorr_01_02.thop
# NODE_COORD_SECTION  (INDEX, X, Y):
#
# ITEMS SECTION    (INDEX, PROFIT, WEIGHT, ASSIGNED NODE NUMBER):
#
# 32508.0
# thop/instances/pr107-thop/pr107_n525_uncorr_01_03.thop
# NODE_COORD_SECTION  (INDEX, X, Y):
#
# ITEMS SECTION    (INDEX, PROFIT, WEIGHT, ASSIGNED NODE NUMBER):
#
# 34187.0
# thop/instances/pr107-thop/pr107_n525_uncorr_05_01.thop
# NODE_COORD_SECTION  (INDEX, X, Y):
#
# ITEMS SECTION    (INDEX, PROFIT, WEIGHT, ASSIGNED NODE NUMBER):
#
# 74445.0
# thop/instances/pr107-thop/pr107_n525_uncorr_05_02.thop
# NODE_COORD_SECTION  (INDEX, X, Y):
#
# ITEMS SECTION    (INDEX, PROFIT, WEIGHT, ASSIGNED NODE NUMBER):
#
# 88841.0
# thop/instances/pr107-thop/pr107_n525_uncorr_05_03.thop
# NODE_COORD_SECTION  (INDEX, X, Y):
#
# ITEMS SECTION    (INDEX, PROFIT, WEIGHT, ASSIGNED NODE NUMBER):
#
# 105055.0
# thop/instances/pr107-thop/pr107_n525_uncorr_10_01.thop
# NODE_COORD_SECTION  (INDEX, X, Y):
#
# ITEMS SECTION    (INDEX, PROFIT, WEIGHT, ASSIGNED NODE NUMBER):
#
# 89109.0
# thop/instances/pr107-thop/pr107_n525_uncorr_10_02.thop
# NODE_COORD_SECTION  (INDEX, X, Y):
#
# ITEMS SECTION    (INDEX, PROFIT, WEIGHT, ASSIGNED NODE NUMBER):
#
# 121523.0
# thop/instances/pr107-thop/pr107_n525_uncorr_10_03.thop
# NODE_COORD_SECTION  (INDEX, X, Y):
#
# ITEMS SECTION    (INDEX, PROFIT, WEIGHT, ASSIGNED NODE NUMBER):
#
# 149041.0
# thop/instances/pr107-thop/pr107_n525_uncorr-similar-weights_01_01.thop
# NODE_COORD_SECTION  (INDEX, X, Y):
#
# ITEMS SECTION    (INDEX, PROFIT, WEIGHT, ASSIGNED NODE NUMBER):
#
# 26373.0
# thop/instances/pr107-thop/pr107_n525_uncorr-similar-weights_01_02.thop
# NODE_COORD_SECTION  (INDEX, X, Y):
#
# ITEMS SECTION    (INDEX, PROFIT, WEIGHT, ASSIGNED NODE NUMBER):
#
# 28212.0
# thop/instances/pr107-thop/pr107_n525_uncorr-similar-weights_01_03.thop
# NODE_COORD_SECTION  (INDEX, X, Y):
#
# ITEMS SECTION    (INDEX, PROFIT, WEIGHT, ASSIGNED NODE NUMBER):
#
# 28541.0
# thop/instances/pr107-thop/pr107_n525_uncorr-similar-weights_05_01.thop
# NODE_COORD_SECTION  (INDEX, X, Y):
#
# ITEMS SECTION    (INDEX, PROFIT, WEIGHT, ASSIGNED NODE NUMBER):
#
# 99740.0
# thop/instances/pr107-thop/pr107_n525_uncorr-similar-weights_05_02.thop
# NODE_COORD_SECTION  (INDEX, X, Y):
#
# ITEMS SECTION    (INDEX, PROFIT, WEIGHT, ASSIGNED NODE NUMBER):
#
# 118457.0
# thop/instances/pr107-thop/pr107_n525_uncorr-similar-weights_05_03.thop
# NODE_COORD_SECTION  (INDEX, X, Y):
#
# ITEMS SECTION    (INDEX, PROFIT, WEIGHT, ASSIGNED NODE NUMBER):
#
# 120761.0
# thop/instances/pr107-thop/pr107_n525_uncorr-similar-weights_10_01.thop
# NODE_COORD_SECTION  (INDEX, X, Y):
#
# ITEMS SECTION    (INDEX, PROFIT, WEIGHT, ASSIGNED NODE NUMBER):
#
# 121911.0
# thop/instances/pr107-thop/pr107_n525_uncorr-similar-weights_10_02.thop
# NODE_COORD_SECTION  (INDEX, X, Y):
#
# ITEMS SECTION    (INDEX, PROFIT, WEIGHT, ASSIGNED NODE NUMBER):
#
# 157418.0
# thop/instances/pr107-thop/pr107_n525_uncorr-similar-weights_10_03.thop
# NODE_COORD_SECTION  (INDEX, X, Y):
#
# ITEMS SECTION    (INDEX, PROFIT, WEIGHT, ASSIGNED NODE NUMBER):
#
# 186846.0
# thop/instances/a280-thop/a280_n1390_bounded-strongly-corr_01_01.thop
# NODE_COORD_SECTION  (INDEX, X, Y):
#
# ITEMS SECTION    (INDEX, PROFIT, WEIGHT, ASSIGNED NODE NUMBER):
#
# entrou
# saiu
# 145814.0
# thop/instances/a280-thop/a280_n1390_bounded-strongly-corr_01_02.thop
# NODE_COORD_SECTION  (INDEX, X, Y):
#
# ITEMS SECTION    (INDEX, PROFIT, WEIGHT, ASSIGNED NODE NUMBER):
#
# 150180.0
# thop/instances/a280-thop/a280_n1390_bounded-strongly-corr_01_03.thop
# NODE_COORD_SECTION  (INDEX, X, Y):
#
# ITEMS SECTION    (INDEX, PROFIT, WEIGHT, ASSIGNED NODE NUMBER):
#
# 153003.0
# thop/instances/a280-thop/a280_n1390_bounded-strongly-corr_05_01.thop
# NODE_COORD_SECTION  (INDEX, X, Y):
#
# ITEMS SECTION    (INDEX, PROFIT, WEIGHT, ASSIGNED NODE NUMBER):
#
# 544842.0
# thop/instances/a280-thop/a280_n1390_bounded-strongly-corr_05_02.thop
# NODE_COORD_SECTION  (INDEX, X, Y):
#
# ITEMS SECTION    (INDEX, PROFIT, WEIGHT, ASSIGNED NODE NUMBER):
#
# 672948.0
# thop/instances/a280-thop/a280_n1390_bounded-strongly-corr_05_03.thop
# NODE_COORD_SECTION  (INDEX, X, Y):
#
# ITEMS SECTION    (INDEX, PROFIT, WEIGHT, ASSIGNED NODE NUMBER):
#
# 734299.0
# thop/instances/a280-thop/a280_n1390_bounded-strongly-corr_10_01.thop
# NODE_COORD_SECTION  (INDEX, X, Y):
#
# ITEMS SECTION    (INDEX, PROFIT, WEIGHT, ASSIGNED NODE NUMBER):
#
# 745896.0
# thop/instances/a280-thop/a280_n1390_bounded-strongly-corr_10_02.thop
# NODE_COORD_SECTION  (INDEX, X, Y):
#
# ITEMS SECTION    (INDEX, PROFIT, WEIGHT, ASSIGNED NODE NUMBER):
#
# 982823.0
# thop/instances/a280-thop/a280_n1390_bounded-strongly-corr_10_03.thop
# NODE_COORD_SECTION  (INDEX, X, Y):
#
# ITEMS SECTION    (INDEX, PROFIT, WEIGHT, ASSIGNED NODE NUMBER):
#
# 1135242.0
# thop/instances/a280-thop/a280_n1390_uncorr_01_01.thop
# NODE_COORD_SECTION  (INDEX, X, Y):
#
# ITEMS SECTION    (INDEX, PROFIT, WEIGHT, ASSIGNED NODE NUMBER):
#
# 72779.0
# thop/instances/a280-thop/a280_n1390_uncorr_01_02.thop
# NODE_COORD_SECTION  (INDEX, X, Y):
#
# ITEMS SECTION    (INDEX, PROFIT, WEIGHT, ASSIGNED NODE NUMBER):
#
# 79247.0
# thop/instances/a280-thop/a280_n1390_uncorr_01_03.thop
# NODE_COORD_SECTION  (INDEX, X, Y):
#
# ITEMS SECTION    (INDEX, PROFIT, WEIGHT, ASSIGNED NODE NUMBER):
#
# 84195.0
# thop/instances/a280-thop/a280_n1390_uncorr_05_01.thop
# NODE_COORD_SECTION  (INDEX, X, Y):
#
# ITEMS SECTION    (INDEX, PROFIT, WEIGHT, ASSIGNED NODE NUMBER):
#
# 170375.0
# thop/instances/a280-thop/a280_n1390_uncorr_05_02.thop
# NODE_COORD_SECTION  (INDEX, X, Y):
#
# ITEMS SECTION    (INDEX, PROFIT, WEIGHT, ASSIGNED NODE NUMBER):
#
# 244345.0
# thop/instances/a280-thop/a280_n1390_uncorr_05_03.thop
# NODE_COORD_SECTION  (INDEX, X, Y):
#
# ITEMS SECTION    (INDEX, PROFIT, WEIGHT, ASSIGNED NODE NUMBER):
#
# 282650.0
# thop/instances/a280-thop/a280_n1390_uncorr_10_01.thop
# NODE_COORD_SECTION  (INDEX, X, Y):
#
# ITEMS SECTION    (INDEX, PROFIT, WEIGHT, ASSIGNED NODE NUMBER):
#
# 191947.0
# thop/instances/a280-thop/a280_n1390_uncorr_10_02.thop
# NODE_COORD_SECTION  (INDEX, X, Y):
#
# ITEMS SECTION    (INDEX, PROFIT, WEIGHT, ASSIGNED NODE NUMBER):
#
# 294538.0
# thop/instances/a280-thop/a280_n1390_uncorr_10_03.thop
# NODE_COORD_SECTION  (INDEX, X, Y):
#
# ITEMS SECTION    (INDEX, PROFIT, WEIGHT, ASSIGNED NODE NUMBER):
#
# 402818.0
# thop/instances/a280-thop/a280_n1390_uncorr-similar-weights_01_01.thop
# NODE_COORD_SECTION  (INDEX, X, Y):
#
# ITEMS SECTION    (INDEX, PROFIT, WEIGHT, ASSIGNED NODE NUMBER):
#
# 70812.0
# thop/instances/a280-thop/a280_n1390_uncorr-similar-weights_01_02.thop
# NODE_COORD_SECTION  (INDEX, X, Y):
#
# ITEMS SECTION    (INDEX, PROFIT, WEIGHT, ASSIGNED NODE NUMBER):
#
# 75934.0
# thop/instances/a280-thop/a280_n1390_uncorr-similar-weights_01_03.thop
# NODE_COORD_SECTION  (INDEX, X, Y):
#
# ITEMS SECTION    (INDEX, PROFIT, WEIGHT, ASSIGNED NODE NUMBER):
#
# 74243.0
# thop/instances/a280-thop/a280_n1390_uncorr-similar-weights_05_01.thop
# NODE_COORD_SECTION  (INDEX, X, Y):
#
# ITEMS SECTION    (INDEX, PROFIT, WEIGHT, ASSIGNED NODE NUMBER):
# 270111.0
# thop/instances/a280-thop/a280_n1390_uncorr-similar-weights_05_02.thop
# NODE_COORD_SECTION  (INDEX, X, Y):
#
# ITEMS SECTION    (INDEX, PROFIT, WEIGHT, ASSIGNED NODE NUMBER):
#
# 319638.0
# thop/instances/a280-thop/a280_n1390_uncorr-similar-weights_05_03.thop
# NODE_COORD_SECTION  (INDEX, X, Y):
#
# ITEMS SECTION    (INDEX, PROFIT, WEIGHT, ASSIGNED NODE NUMBER):
#
# 331412.0
# thop/instances/a280-thop/a280_n1390_uncorr-similar-weights_10_01.thop
# NODE_COORD_SECTION  (INDEX, X, Y):
#
# ITEMS SECTION    (INDEX, PROFIT, WEIGHT, ASSIGNED NODE NUMBER):
#
# 365973.0
# thop/instances/a280-thop/a280_n1390_uncorr-similar-weights_10_02.thop
# NODE_COORD_SECTION  (INDEX, X, Y):
#
# ITEMS SECTION    (INDEX, PROFIT, WEIGHT, ASSIGNED NODE NUMBER):
#
# 468160.0
# thop/instances/a280-thop/a280_n1390_uncorr-similar-weights_10_03.thop
# NODE_COORD_SECTION  (INDEX, X, Y):
#
# ITEMS SECTION    (INDEX, PROFIT, WEIGHT, ASSIGNED NODE NUMBER):
#
# 534626.0
# thop/instances/a280-thop/a280_n278_bounded-strongly-corr_01_01.thop
# NODE_COORD_SECTION  (INDEX, X, Y):
#
# ITEMS SECTION    (INDEX, PROFIT, WEIGHT, ASSIGNED NODE NUMBER):
#
# 32811.0
# thop/instances/a280-thop/a280_n278_bounded-strongly-corr_01_02.thop
# NODE_COORD_SECTION  (INDEX, X, Y):
#
# ITEMS SECTION    (INDEX, PROFIT, WEIGHT, ASSIGNED NODE NUMBER):
#
# 33293.0
# thop/instances/a280-thop/a280_n278_bounded-strongly-corr_01_03.thop
# NODE_COORD_SECTION  (INDEX, X, Y):
#
# ITEMS SECTION    (INDEX, PROFIT, WEIGHT, ASSIGNED NODE NUMBER):
#
# 33986.0
# thop/instances/a280-thop/a280_n278_bounded-strongly-corr_05_01.thop
# NODE_COORD_SECTION  (INDEX, X, Y):
#
# ITEMS SECTION    (INDEX, PROFIT, WEIGHT, ASSIGNED NODE NUMBER):
#
# 112694.0
# thop/instances/a280-thop/a280_n278_bounded-strongly-corr_05_02.thop
# NODE_COORD_SECTION  (INDEX, X, Y):
#
# ITEMS SECTION    (INDEX, PROFIT, WEIGHT, ASSIGNED NODE NUMBER):
#
# 140116.0
# thop/instances/a280-thop/a280_n278_bounded-strongly-corr_05_03.thop
# NODE_COORD_SECTION  (INDEX, X, Y):
#
# ITEMS SECTION    (INDEX, PROFIT, WEIGHT, ASSIGNED NODE NUMBER):
#
# 156768.0
# thop/instances/a280-thop/a280_n278_bounded-strongly-corr_10_01.thop
# NODE_COORD_SECTION  (INDEX, X, Y):
#
# ITEMS SECTION    (INDEX, PROFIT, WEIGHT, ASSIGNED NODE NUMBER):
#
# 150956.0
# thop/instances/a280-thop/a280_n278_bounded-strongly-corr_10_02.thop
# NODE_COORD_SECTION  (INDEX, X, Y):
#
# ITEMS SECTION    (INDEX, PROFIT, WEIGHT, ASSIGNED NODE NUMBER):
#
# 205593.0
# thop/instances/a280-thop/a280_n278_bounded-strongly-corr_10_03.thop
# NODE_COORD_SECTION  (INDEX, X, Y):
#
# ITEMS SECTION    (INDEX, PROFIT, WEIGHT, ASSIGNED NODE NUMBER):
#
# 234462.0
# thop/instances/a280-thop/a280_n278_uncorr_01_01.thop
# NODE_COORD_SECTION  (INDEX, X, Y):
#
# ITEMS SECTION    (INDEX, PROFIT, WEIGHT, ASSIGNED NODE NUMBER):
#
# 20312.0
# thop/instances/a280-thop/a280_n278_uncorr_01_02.thop
# NODE_COORD_SECTION  (INDEX, X, Y):
#
# ITEMS SECTION    (INDEX, PROFIT, WEIGHT, ASSIGNED NODE NUMBER):
#
# 28722.0
# thop/instances/a280-thop/a280_n278_uncorr_01_03.thop
# NODE_COORD_SECTION  (INDEX, X, Y):
#
# ITEMS SECTION    (INDEX, PROFIT, WEIGHT, ASSIGNED NODE NUMBER):
#
# 33672.0
# thop/instances/a280-thop/a280_n278_uncorr_05_01.thop
# NODE_COORD_SECTION  (INDEX, X, Y):
#
# ITEMS SECTION    (INDEX, PROFIT, WEIGHT, ASSIGNED NODE NUMBER):
#
# 28918.0
# thop/instances/a280-thop/a280_n278_uncorr_05_02.thop
# NODE_COORD_SECTION  (INDEX, X, Y):
#
# ITEMS SECTION    (INDEX, PROFIT, WEIGHT, ASSIGNED NODE NUMBER):
#
# 49442.0
# thop/instances/a280-thop/a280_n278_uncorr_05_03.thop
# NODE_COORD_SECTION  (INDEX, X, Y):
#
# ITEMS SECTION    (INDEX, PROFIT, WEIGHT, ASSIGNED NODE NUMBER):
#
# 69044.0
# thop/instances/a280-thop/a280_n278_uncorr_10_01.thop
# NODE_COORD_SECTION  (INDEX, X, Y):
#
# ITEMS SECTION    (INDEX, PROFIT, WEIGHT, ASSIGNED NODE NUMBER):
#
# 39287.0
# thop/instances/a280-thop/a280_n278_uncorr_10_02.thop
# NODE_COORD_SECTION  (INDEX, X, Y):
#
# ITEMS SECTION    (INDEX, PROFIT, WEIGHT, ASSIGNED NODE NUMBER):
#
# 58693.0
# thop/instances/a280-thop/a280_n278_uncorr_10_03.thop
# NODE_COORD_SECTION  (INDEX, X, Y):
#
# ITEMS SECTION    (INDEX, PROFIT, WEIGHT, ASSIGNED NODE NUMBER):
#
# 80141.0
# thop/instances/a280-thop/a280_n278_uncorr-similar-weights_01_01.thop
# NODE_COORD_SECTION  (INDEX, X, Y):
#
# ITEMS SECTION    (INDEX, PROFIT, WEIGHT, ASSIGNED NODE NUMBER):
#
# 17187.0
# thop/instances/a280-thop/a280_n278_uncorr-similar-weights_01_02.thop
# NODE_COORD_SECTION  (INDEX, X, Y):
#
# ITEMS SECTION    (INDEX, PROFIT, WEIGHT, ASSIGNED NODE NUMBER):
#
# 18630.0
# thop/instances/a280-thop/a280_n278_uncorr-similar-weights_01_03.thop
# NODE_COORD_SECTION  (INDEX, X, Y):
#
# ITEMS SECTION    (INDEX, PROFIT, WEIGHT, ASSIGNED NODE NUMBER):
#
# 19533.0
# thop/instances/a280-thop/a280_n278_uncorr-similar-weights_05_01.thop
# NODE_COORD_SECTION  (INDEX, X, Y):
#
# ITEMS SECTION    (INDEX, PROFIT, WEIGHT, ASSIGNED NODE NUMBER):
#
# 54179.0
# thop/instances/a280-thop/a280_n278_uncorr-similar-weights_05_02.thop
# NODE_COORD_SECTION  (INDEX, X, Y):
#
# ITEMS SECTION    (INDEX, PROFIT, WEIGHT, ASSIGNED NODE NUMBER):
#
# 68622.0
# thop/instances/a280-thop/a280_n278_uncorr-similar-weights_05_03.thop
# NODE_COORD_SECTION  (INDEX, X, Y):
#
# ITEMS SECTION    (INDEX, PROFIT, WEIGHT, ASSIGNED NODE NUMBER):
#
# 78803.0
# thop/instances/a280-thop/a280_n278_uncorr-similar-weights_10_01.thop
# NODE_COORD_SECTION  (INDEX, X, Y):
#
# ITEMS SECTION    (INDEX, PROFIT, WEIGHT, ASSIGNED NODE NUMBER):
#
# 75220.0
# thop/instances/a280-thop/a280_n278_uncorr-similar-weights_10_02.thop
# NODE_COORD_SECTION  (INDEX, X, Y):
#
# ITEMS SECTION    (INDEX, PROFIT, WEIGHT, ASSIGNED NODE NUMBER):
#
# 98065.0
# thop/instances/a280-thop/a280_n278_uncorr-similar-weights_10_03.thop
# NODE_COORD_SECTION  (INDEX, X, Y):
#
# ITEMS SECTION    (INDEX, PROFIT, WEIGHT, ASSIGNED NODE NUMBER):
#
# 116959.0
# thop/instances/a280-thop/a280_n2780_bounded-strongly-corr_01_01.thop
# NODE_COORD_SECTION  (INDEX, X, Y):
#
# ITEMS SECTION    (INDEX, PROFIT, WEIGHT, ASSIGNED NODE NUMBER):
#
# 294800.0
# thop/instances/a280-thop/a280_n2780_bounded-strongly-corr_01_02.thop
# NODE_COORD_SECTION  (INDEX, X, Y):
#
# ITEMS SECTION    (INDEX, PROFIT, WEIGHT, ASSIGNED NODE NUMBER):
#
# 297947.0
# thop/instances/a280-thop/a280_n2780_bounded-strongly-corr_01_03.thop
# NODE_COORD_SECTION  (INDEX, X, Y):
#
# ITEMS SECTION    (INDEX, PROFIT, WEIGHT, ASSIGNED NODE NUMBER):
#
# 301006.0
# thop/instances/a280-thop/a280_n2780_bounded-strongly-corr_05_01.thop
# NODE_COORD_SECTION  (INDEX, X, Y):
#
# ITEMS SECTION    (INDEX, PROFIT, WEIGHT, ASSIGNED NODE NUMBER):
#
# 1126964.0
# thop/instances/a280-thop/a280_n2780_bounded-strongly-corr_05_02.thop
# NODE_COORD_SECTION  (INDEX, X, Y):
#
# ITEMS SECTION    (INDEX, PROFIT, WEIGHT, ASSIGNED NODE NUMBER):
#
# 1369386.0
# thop/instances/a280-thop/a280_n2780_bounded-strongly-corr_05_03.thop
# NODE_COORD_SECTION  (INDEX, X, Y):
#
# ITEMS SECTION    (INDEX, PROFIT, WEIGHT, ASSIGNED NODE NUMBER):
#
# 1463729.0
# thop/instances/a280-thop/a280_n2780_bounded-strongly-corr_10_01.thop
# NODE_COORD_SECTION  (INDEX, X, Y):
#
# ITEMS SECTION    (INDEX, PROFIT, WEIGHT, ASSIGNED NODE NUMBER):
#
# 1411858.0
# thop/instances/a280-thop/a280_n2780_bounded-strongly-corr_10_02.thop
# NODE_COORD_SECTION  (INDEX, X, Y):
#
# ITEMS SECTION    (INDEX, PROFIT, WEIGHT, ASSIGNED NODE NUMBER):
#
# 1908036.0
# thop/instances/a280-thop/a280_n2780_bounded-strongly-corr_10_03.thop
# NODE_COORD_SECTION  (INDEX, X, Y):
#
# ITEMS SECTION    (INDEX, PROFIT, WEIGHT, ASSIGNED NODE NUMBER):
#
# 2232488.0
# thop/instances/a280-thop/a280_n2780_uncorr_01_01.thop
# NODE_COORD_SECTION  (INDEX, X, Y):
#
# ITEMS SECTION    (INDEX, PROFIT, WEIGHT, ASSIGNED NODE NUMBER):
#
# 141561.0
# thop/instances/a280-thop/a280_n2780_uncorr_01_02.thop
# NODE_COORD_SECTION  (INDEX, X, Y):
#
# ITEMS SECTION    (INDEX, PROFIT, WEIGHT, ASSIGNED NODE NUMBER):
#
# 158448.0
# thop/instances/a280-thop/a280_n2780_uncorr_01_03.thop
# NODE_COORD_SECTION  (INDEX, X, Y):
#
# ITEMS SECTION    (INDEX, PROFIT, WEIGHT, ASSIGNED NODE NUMBER):
#
# 161992.0
# thop/instances/a280-thop/a280_n2780_uncorr_05_01.thop
# NODE_COORD_SECTION  (INDEX, X, Y):
#
# ITEMS SECTION    (INDEX, PROFIT, WEIGHT, ASSIGNED NODE NUMBER):
#
# 352840.0
# thop/instances/a280-thop/a280_n2780_uncorr_05_02.thop
# NODE_COORD_SECTION  (INDEX, X, Y):
#
# ITEMS SECTION    (INDEX, PROFIT, WEIGHT, ASSIGNED NODE NUMBER):
#
# 490644.0
# thop/instances/a280-thop/a280_n2780_uncorr_05_03.thop
# NODE_COORD_SECTION  (INDEX, X, Y):
#
# ITEMS SECTION    (INDEX, PROFIT, WEIGHT, ASSIGNED NODE NUMBER):
#
# 578795.0
# thop/instances/a280-thop/a280_n2780_uncorr_10_01.thop
# NODE_COORD_SECTION  (INDEX, X, Y):
#
# ITEMS SECTION    (INDEX, PROFIT, WEIGHT, ASSIGNED NODE NUMBER):
# 418577.0
# thop/instances/a280-thop/a280_n2780_uncorr_10_02.thop
# NODE_COORD_SECTION  (INDEX, X, Y):
#
# ITEMS SECTION    (INDEX, PROFIT, WEIGHT, ASSIGNED NODE NUMBER):
#
# 627722.0
# thop/instances/a280-thop/a280_n2780_uncorr_10_03.thop
# NODE_COORD_SECTION  (INDEX, X, Y):
#
# ITEMS SECTION    (INDEX, PROFIT, WEIGHT, ASSIGNED NODE NUMBER):
#
# 798700.0
# thop/instances/a280-thop/a280_n2780_uncorr-similar-weights_01_01.thop
# NODE_COORD_SECTION  (INDEX, X, Y):
#
# ITEMS SECTION    (INDEX, PROFIT, WEIGHT, ASSIGNED NODE NUMBER):
#
# 136052.0
# thop/instances/a280-thop/a280_n2780_uncorr-similar-weights_01_02.thop
# NODE_COORD_SECTION  (INDEX, X, Y):
#
# ITEMS SECTION    (INDEX, PROFIT, WEIGHT, ASSIGNED NODE NUMBER):
#
# 140206.0
# thop/instances/a280-thop/a280_n2780_uncorr-similar-weights_01_03.thop
# NODE_COORD_SECTION  (INDEX, X, Y):
#
# ITEMS SECTION    (INDEX, PROFIT, WEIGHT, ASSIGNED NODE NUMBER):
#
# 140134.0
# thop/instances/a280-thop/a280_n2780_uncorr-similar-weights_05_01.thop
# NODE_COORD_SECTION  (INDEX, X, Y):
#
# ITEMS SECTION    (INDEX, PROFIT, WEIGHT, ASSIGNED NODE NUMBER):
#
# 564123.0
# thop/instances/a280-thop/a280_n2780_uncorr-similar-weights_05_02.thop
# NODE_COORD_SECTION  (INDEX, X, Y):
#
# ITEMS SECTION    (INDEX, PROFIT, WEIGHT, ASSIGNED NODE NUMBER):
#
# 640438.0
# thop/instances/a280-thop/a280_n2780_uncorr-similar-weights_05_03.thop
# NODE_COORD_SECTION  (INDEX, X, Y):
#
# ITEMS SECTION    (INDEX, PROFIT, WEIGHT, ASSIGNED NODE NUMBER):
#
# 663047.0
# thop/instances/a280-thop/a280_n2780_uncorr-similar-weights_10_01.thop
# NODE_COORD_SECTION  (INDEX, X, Y):
#
# ITEMS SECTION    (INDEX, PROFIT, WEIGHT, ASSIGNED NODE NUMBER):
#
# 732982.0
# thop/instances/a280-thop/a280_n2780_uncorr-similar-weights_10_02.thop
# NODE_COORD_SECTION  (INDEX, X, Y):
#
# ITEMS SECTION    (INDEX, PROFIT, WEIGHT, ASSIGNED NODE NUMBER):
#
# 910143.0
# thop/instances/a280-thop/a280_n2780_uncorr-similar-weights_10_03.thop
# NODE_COORD_SECTION  (INDEX, X, Y):
#
# ITEMS SECTION    (INDEX, PROFIT, WEIGHT, ASSIGNED NODE NUMBER):
#
# 1072489.0
# thop/instances/a280-thop/a280_n834_bounded-strongly-corr_01_01.thop
# NODE_COORD_SECTION  (INDEX, X, Y):
#
# ITEMS SECTION    (INDEX, PROFIT, WEIGHT, ASSIGNED NODE NUMBER):
#
# 78128.0
# thop/instances/a280-thop/a280_n834_bounded-strongly-corr_01_02.thop
# NODE_COORD_SECTION  (INDEX, X, Y):
#
# ITEMS SECTION    (INDEX, PROFIT, WEIGHT, ASSIGNED NODE NUMBER):
#
# 92031.0
# thop/instances/a280-thop/a280_n834_bounded-strongly-corr_01_03.thop
# NODE_COORD_SECTION  (INDEX, X, Y):
#
# ITEMS SECTION    (INDEX, PROFIT, WEIGHT, ASSIGNED NODE NUMBER):
#
# 93071.0
# thop/instances/a280-thop/a280_n834_bounded-strongly-corr_05_01.thop
# NODE_COORD_SECTION  (INDEX, X, Y):
#
# ITEMS SECTION    (INDEX, PROFIT, WEIGHT, ASSIGNED NODE NUMBER):
#
# 293166.0
# thop/instances/a280-thop/a280_n834_bounded-strongly-corr_05_02.thop
# NODE_COORD_SECTION  (INDEX, X, Y):
#
# ITEMS SECTION    (INDEX, PROFIT, WEIGHT, ASSIGNED NODE NUMBER):
#
# 386387.0
# thop/instances/a280-thop/a280_n834_bounded-strongly-corr_05_03.thop
# NODE_COORD_SECTION  (INDEX, X, Y):
#
# ITEMS SECTION    (INDEX, PROFIT, WEIGHT, ASSIGNED NODE NUMBER):
#
# 424303.0
# thop/instances/a280-thop/a280_n834_bounded-strongly-corr_10_01.thop
# NODE_COORD_SECTION  (INDEX, X, Y):
#
# ITEMS SECTION    (INDEX, PROFIT, WEIGHT, ASSIGNED NODE NUMBER):
#
# 415798.0
# thop/instances/a280-thop/a280_n834_bounded-strongly-corr_10_02.thop
# NODE_COORD_SECTION  (INDEX, X, Y):
#
# ITEMS SECTION    (INDEX, PROFIT, WEIGHT, ASSIGNED NODE NUMBER):
#
# 525675.0
# thop/instances/a280-thop/a280_n834_bounded-strongly-corr_10_03.thop
# NODE_COORD_SECTION  (INDEX, X, Y):
#
# ITEMS SECTION    (INDEX, PROFIT, WEIGHT, ASSIGNED NODE NUMBER):
#
# 633015.0
# thop/instances/a280-thop/a280_n834_uncorr_01_01.thop
# NODE_COORD_SECTION  (INDEX, X, Y):
#
# ITEMS SECTION    (INDEX, PROFIT, WEIGHT, ASSIGNED NODE NUMBER):
#
# 48644.0
# thop/instances/a280-thop/a280_n834_uncorr_01_02.thop
# NODE_COORD_SECTION  (INDEX, X, Y):
#
# ITEMS SECTION    (INDEX, PROFIT, WEIGHT, ASSIGNED NODE NUMBER):
#
# 58097.0
# thop/instances/a280-thop/a280_n834_uncorr_01_03.thop
# NODE_COORD_SECTION  (INDEX, X, Y):
#
# ITEMS SECTION    (INDEX, PROFIT, WEIGHT, ASSIGNED NODE NUMBER):
#
# 61814.0
# thop/instances/a280-thop/a280_n834_uncorr_05_01.thop
# NODE_COORD_SECTION  (INDEX, X, Y):
#
# ITEMS SECTION    (INDEX, PROFIT, WEIGHT, ASSIGNED NODE NUMBER):
#
# 87619.0
# thop/instances/a280-thop/a280_n834_uncorr_05_02.thop
# NODE_COORD_SECTION  (INDEX, X, Y):
#
# ITEMS SECTION    (INDEX, PROFIT, WEIGHT, ASSIGNED NODE NUMBER):
#
# 151224.0
# thop/instances/a280-thop/a280_n834_uncorr_05_03.thop
# NODE_COORD_SECTION  (INDEX, X, Y):
#
# ITEMS SECTION    (INDEX, PROFIT, WEIGHT, ASSIGNED NODE NUMBER):
#
# 191659.0
# thop/instances/a280-thop/a280_n834_uncorr_10_01.thop
# NODE_COORD_SECTION  (INDEX, X, Y):
#
# ITEMS SECTION    (INDEX, PROFIT, WEIGHT, ASSIGNED NODE NUMBER):
#
# 100631.0
# thop/instances/a280-thop/a280_n834_uncorr_10_02.thop
# NODE_COORD_SECTION  (INDEX, X, Y):
#
# ITEMS SECTION    (INDEX, PROFIT, WEIGHT, ASSIGNED NODE NUMBER):
#
# 194447.0
# thop/instances/a280-thop/a280_n834_uncorr_10_03.thop
# NODE_COORD_SECTION  (INDEX, X, Y):
#
# ITEMS SECTION    (INDEX, PROFIT, WEIGHT, ASSIGNED NODE NUMBER):
#
# 240597.0
# thop/instances/a280-thop/a280_n834_uncorr-similar-weights_01_01.thop
# NODE_COORD_SECTION  (INDEX, X, Y):
#
# ITEMS SECTION    (INDEX, PROFIT, WEIGHT, ASSIGNED NODE NUMBER):
#
# 46308.0
# thop/instances/a280-thop/a280_n834_uncorr-similar-weights_01_02.thop
# NODE_COORD_SECTION  (INDEX, X, Y):
#
# ITEMS SECTION    (INDEX, PROFIT, WEIGHT, ASSIGNED NODE NUMBER):
#
# 48281.0
# thop/instances/a280-thop/a280_n834_uncorr-similar-weights_01_03.thop
# NODE_COORD_SECTION  (INDEX, X, Y):
#
# ITEMS SECTION    (INDEX, PROFIT, WEIGHT, ASSIGNED NODE NUMBER):
#
# 48426.0
# thop/instances/a280-thop/a280_n834_uncorr-similar-weights_05_01.thop
# NODE_COORD_SECTION  (INDEX, X, Y):
#
# ITEMS SECTION    (INDEX, PROFIT, WEIGHT, ASSIGNED NODE NUMBER):
#
# 168288.0
# thop/instances/a280-thop/a280_n834_uncorr-similar-weights_05_02.thop
# NODE_COORD_SECTION  (INDEX, X, Y):
#
# ITEMS SECTION    (INDEX, PROFIT, WEIGHT, ASSIGNED NODE NUMBER):
#
# 196959.0
# thop/instances/a280-thop/a280_n834_uncorr-similar-weights_05_03.thop
# NODE_COORD_SECTION  (INDEX, X, Y):
#
# ITEMS SECTION    (INDEX, PROFIT, WEIGHT, ASSIGNED NODE NUMBER):
#
# 212471.0
# thop/instances/a280-thop/a280_n834_uncorr-similar-weights_10_01.thop
# NODE_COORD_SECTION  (INDEX, X, Y):
#
# ITEMS SECTION    (INDEX, PROFIT, WEIGHT, ASSIGNED NODE NUMBER):
#
# 201561.0
# thop/instances/a280-thop/a280_n834_uncorr-similar-weights_10_02.thop
# NODE_COORD_SECTION  (INDEX, X, Y):
#
# ITEMS SECTION    (INDEX, PROFIT, WEIGHT, ASSIGNED NODE NUMBER):
#
# 286139.0
# thop/instances/a280-thop/a280_n834_uncorr-similar-weights_10_03.thop
# NODE_COORD_SECTION  (INDEX, X, Y):
#
# ITEMS SECTION    (INDEX, PROFIT, WEIGHT, ASSIGNED NODE NUMBER):
#
# 320395.0
# thop/instances/dsj1000-thop/dsj1000_n2994_bounded-strongly-corr_01_01.thop
# NODE_COORD_SECTION  (INDEX, X, Y):
#
# ITEMS SECTION    (INDEX, PROFIT, WEIGHT, ASSIGNED NODE NUMBER):
#
# entrou
# saiu
# 318680.0
# thop/instances/dsj1000-thop/dsj1000_n2994_bounded-strongly-corr_01_02.thop
# NODE_COORD_SECTION  (INDEX, X, Y):
#
# ITEMS SECTION    (INDEX, PROFIT, WEIGHT, ASSIGNED NODE NUMBER):
#
# 321200.0
# thop/instances/dsj1000-thop/dsj1000_n2994_bounded-strongly-corr_01_03.thop
# NODE_COORD_SECTION  (INDEX, X, Y):
#
# ITEMS SECTION    (INDEX, PROFIT, WEIGHT, ASSIGNED NODE NUMBER):
#
# 323292.0
# thop/instances/dsj1000-thop/dsj1000_n2994_bounded-strongly-corr_05_01.thop
# NODE_COORD_SECTION  (INDEX, X, Y):
#
# ITEMS SECTION    (INDEX, PROFIT, WEIGHT, ASSIGNED NODE NUMBER):
#
# 1254163.0
# thop/instances/dsj1000-thop/dsj1000_n2994_bounded-strongly-corr_05_02.thop
# NODE_COORD_SECTION  (INDEX, X, Y):
#
# ITEMS SECTION    (INDEX, PROFIT, WEIGHT, ASSIGNED NODE NUMBER):
#
# 1486594.0
# thop/instances/dsj1000-thop/dsj1000_n2994_bounded-strongly-corr_05_03.thop
# NODE_COORD_SECTION  (INDEX, X, Y):
#
# ITEMS SECTION    (INDEX, PROFIT, WEIGHT, ASSIGNED NODE NUMBER):
#
# 1569152.0
# thop/instances/dsj1000-thop/dsj1000_n2994_bounded-strongly-corr_10_01.thop
# NODE_COORD_SECTION  (INDEX, X, Y):
#
# ITEMS SECTION    (INDEX, PROFIT, WEIGHT, ASSIGNED NODE NUMBER):
#
# 1698265.0
# thop/instances/dsj1000-thop/dsj1000_n2994_bounded-strongly-corr_10_02.thop
# NODE_COORD_SECTION  (INDEX, X, Y):
#
# ITEMS SECTION    (INDEX, PROFIT, WEIGHT, ASSIGNED NODE NUMBER):
#
# 2045184.0
# thop/instances/dsj1000-thop/dsj1000_n2994_bounded-strongly-corr_10_03.thop
# NODE_COORD_SECTION  (INDEX, X, Y):
#
# ITEMS SECTION    (INDEX, PROFIT, WEIGHT, ASSIGNED NODE NUMBER):
# 2416811.0
# thop/instances/dsj1000-thop/dsj1000_n2994_uncorr_01_01.thop
# NODE_COORD_SECTION  (INDEX, X, Y):
#
# ITEMS SECTION    (INDEX, PROFIT, WEIGHT, ASSIGNED NODE NUMBER):
#
# 182896.0
# thop/instances/dsj1000-thop/dsj1000_n2994_uncorr_01_02.thop
# NODE_COORD_SECTION  (INDEX, X, Y):
#
# ITEMS SECTION    (INDEX, PROFIT, WEIGHT, ASSIGNED NODE NUMBER):
#
# 207203.0
# thop/instances/dsj1000-thop/dsj1000_n2994_uncorr_01_03.thop
# NODE_COORD_SECTION  (INDEX, X, Y):
#
# ITEMS SECTION    (INDEX, PROFIT, WEIGHT, ASSIGNED NODE NUMBER):
#
# 211015.0
# thop/instances/dsj1000-thop/dsj1000_n2994_uncorr_05_01.thop
# NODE_COORD_SECTION  (INDEX, X, Y):
#
# ITEMS SECTION    (INDEX, PROFIT, WEIGHT, ASSIGNED NODE NUMBER):
#
# 436460.0
# thop/instances/dsj1000-thop/dsj1000_n2994_uncorr_05_02.thop
# NODE_COORD_SECTION  (INDEX, X, Y):
#
# ITEMS SECTION    (INDEX, PROFIT, WEIGHT, ASSIGNED NODE NUMBER):
#
# 634602.0
# thop/instances/dsj1000-thop/dsj1000_n2994_uncorr_05_03.thop
# NODE_COORD_SECTION  (INDEX, X, Y):
#
# ITEMS SECTION    (INDEX, PROFIT, WEIGHT, ASSIGNED NODE NUMBER):
#
# 717702.0
# thop/instances/dsj1000-thop/dsj1000_n2994_uncorr_10_01.thop
# NODE_COORD_SECTION  (INDEX, X, Y):
#
# ITEMS SECTION    (INDEX, PROFIT, WEIGHT, ASSIGNED NODE NUMBER):
#
# 571755.0
# thop/instances/dsj1000-thop/dsj1000_n2994_uncorr_10_02.thop
# NODE_COORD_SECTION  (INDEX, X, Y):
#
# ITEMS SECTION    (INDEX, PROFIT, WEIGHT, ASSIGNED NODE NUMBER):
#
# 769740.0
# thop/instances/dsj1000-thop/dsj1000_n2994_uncorr_10_03.thop
# NODE_COORD_SECTION  (INDEX, X, Y):
#
# ITEMS SECTION    (INDEX, PROFIT, WEIGHT, ASSIGNED NODE NUMBER):
#
# 973545.0
# thop/instances/dsj1000-thop/dsj1000_n2994_uncorr-similar-weights_01_01.thop
# NODE_COORD_SECTION  (INDEX, X, Y):
#
# ITEMS SECTION    (INDEX, PROFIT, WEIGHT, ASSIGNED NODE NUMBER):
#
# 151025.0
# thop/instances/dsj1000-thop/dsj1000_n2994_uncorr-similar-weights_01_02.thop
# NODE_COORD_SECTION  (INDEX, X, Y):
#
# ITEMS SECTION    (INDEX, PROFIT, WEIGHT, ASSIGNED NODE NUMBER):
#
# 156999.0
# thop/instances/dsj1000-thop/dsj1000_n2994_uncorr-similar-weights_01_03.thop
# NODE_COORD_SECTION  (INDEX, X, Y):
#
# ITEMS SECTION    (INDEX, PROFIT, WEIGHT, ASSIGNED NODE NUMBER):
#
# 159650.0
# thop/instances/dsj1000-thop/dsj1000_n2994_uncorr-similar-weights_05_01.thop
# NODE_COORD_SECTION  (INDEX, X, Y):
#
# ITEMS SECTION    (INDEX, PROFIT, WEIGHT, ASSIGNED NODE NUMBER):
#
# 678130.0
# thop/instances/dsj1000-thop/dsj1000_n2994_uncorr-similar-weights_05_02.thop
# NODE_COORD_SECTION  (INDEX, X, Y):
#
# ITEMS SECTION    (INDEX, PROFIT, WEIGHT, ASSIGNED NODE NUMBER):
# ---------------------------------------------------------------------------
# KeyboardInterrupt                         Traceback (most recent call last)
# <ipython-input-7-b5df586b87fc> in <module>()
#     193
#     194
# --> 195                                 solu, tempo = solucaoFinal2(rotaVazia, todosItens.copy(), matrizAdjacencia.copy(), itens.copy(), minS, maxS, (maxS-minS)/cap, maxT, cap)
#     196                                 if(tempo<tempoAtual):
#     197                                     rota=rotaVazia
#
# <ipython-input-1-4aaa3c6b2ab7> in solucaoFinal2(vRota, vItens, matriz, itens, vMin, vMax, v, maxTime, w)
#      40     itensCid=[]
#      41     for x in matriz:
# ---> 42         itensCid.append([])
#      43     for x in vItens:
#      44         #print(x)
#
# KeyboardInterrupt:

# %%
# Out:
# 3845995.0

# %%
for numero in resultados:
    print(int(numero))

# %%
solucaoFinal(rotaInicial, itensIniciais.copy(), matrizAdjacencia.copy(), itens.copy(), minS, maxS, (maxS-minS)/cap, maxT, cap)
# Out:
# 3779866.0

# %%
solucoes
# Out:
# [4006283.0,
#  3736488.0,
#  3748008.0,
#  3616276.0,
#  3741260.0,
#  3713284.0,
#  3648899.0,
#  3757572.0,
#  3740811.0,
#  3745773.0,
#  3741798.0,
#  3949885.0,
#  3748512.0,
#  4059758.0,
#  3752222.0,
#  3678375.0,
#  3731481.0,
#  3752867.0,
#  3750074.0,
#  3982440.0,
#  4146254.0,
#  3783205.0,
#  3779866.0]
