# %%
# metaheuristica procurar ponto mais proximo de 2 pontos e colocar ele ali no meio

import math
import copy
def solucaoFinal(vRota, vItens, matriz, itens, vMin, vMax, v, maxTime, w):
    vRota = [0] + vRota + [len(matriz)-1]
    peso = 0
    valor=0
    itensCid=[]
    for x in matriz:
        itensCid.append([])
    for x in vItens:        
        #print(x)
        itensCid[int(itens[x][3])].append(itens[x])
        peso += itens[x][2]
        valor += itens[x][1]
    
    t = 0
    pesoAtual = 0
    for index, x in enumerate(vRota):
        #print(index,x , len(vRota))
        if(index < len(vRota)-1):
            for y in itensCid[x]:
                #print('cidade', x-1, 'peso', pesoAtual)
                pesoAtual +=y[2]
            #print(matriz[x-1][vRota[index+1]-1], vMax , v*pesoAtual, vMin)
            t += matriz[x][vRota[index+1]]/max(vMax - v*pesoAtual, vMin)
    tempoAtual = (t/maxTime) * (pesoAtual/w)
    #print('tempo', t,maxTime, pesoAtual, w, 'peso:', tempoAtual, valor)
    #print(t,maxTime , peso,w)
    if(t<=maxTime and pesoAtual<=w):
        return valor
    else:
        return -1
    return 0
def solucaoFinal2(vRota, vItens, matriz, itens, vMin, vMax, v, maxTime, w):
    vRota = [0] + vRota + [len(matriz)-1]
    peso = 0
    valor=0
    itensCid=[]
    for x in matriz:
        itensCid.append([])
    for x in vItens:        
        #print(x)
        itensCid[int(itens[x][3])].append(itens[x])
        peso += itens[x][2]
        valor += itens[x][1]
    
    t = 0
    pesoAtual = 0
    for index, x in enumerate(vRota):
        #print(index,x , len(vRota))
        if(index < len(vRota)-1):
            for y in itensCid[x]:
                #print('cidade', x-1, 'peso', pesoAtual)
                pesoAtual +=y[2]
            #print(matriz[x-1][vRota[index+1]-1], vMax , v*pesoAtual, vMin)
            t += matriz[x][vRota[index+1]]/max(vMax - v*pesoAtual, vMin)
    tempoAtual = (t/maxTime) * (pesoAtual/w)
    #print('tempo', t,maxTime, pesoAtual, w, 'peso:', tempoAtual)
    #print(t,maxTime , peso,w)
    if(t<=maxTime and pesoAtual<=w):
        return valor, tempoAtual
    else:
        return -1, tempoAtual
    return 0
def dist(a, b):
    #print(a)
    #print(b)
    t = math.sqrt((a[1]-b[1])*(a[1]-b[1])+(a[2]-b[2])*(a[2]-b[2]))
    if int(t)==t:
        n = int(t)
    else:
        n = int(t)+1
    return n

def solucao(vRota, cidadeItens, matriz):
    vRota = [0] + vRota + [len(matriz)-1]
    peso = 0
    valor=0
    v = (maxSpeed - minSpeed)/capacity
    t = 0
    pesoAtual = 0
    for index, x in enumerate(vRota):
        #print(index,x , len(vRota))
        if(index < len(vRota)-1):
            valor+=cidadeItens[x]['valor']    
            pesoAtual +=cidadeItens[x]['peso']            
            t += matriz[x][vRota[index+1]]/max(maxSpeed - v*pesoAtual, minSpeed)
    if(t<=maxTime and pesoAtual<=capacity):
        return valor
    else:
        return -1
    return 0


def proximaCidade(matriz, dadosCidade, cidadeAtual, cidadeVisitada):
    maxi = -1
    ind = -1
    for index, x in enumerate(dadosCidade):
        #if  matriz[cidadeAtual][index]==0 and cidadeAtual!=index:
            #print(cidadeAtual, index, matriz[cidadeAtual][index])
            #continue
        value = (x/(matriz[cidadeAtual][index]+1))
        if (cidadeAtual!=index and maxi<value and not cidadeVisitada[index]):            
            maxi = value
            ind = index            
            
    return ind


def adicionaMaximoItens(rota, cidadeItens, cidadeAtual, itens, matriz, todosItens):
    rotaCopia = copy.deepcopy(rota)
    rotaCopia.append(cidadeAtual)
    lastResult = -1
    for x in itens:       
        cidadeItens[cidadeAtual]['valor']+=x[1]
        cidadeItens[cidadeAtual]['peso']+=x[2]         
        cidadeItens[cidadeAtual]['qtdItens']+=1
        todosItens.append(x[0])
        result = solucao(rotaCopia, cidadeItens, matriz)
        #print(rotaCopia, cidadeItens[cidadeAtual])
        if result==-1:            
            cidadeItens[cidadeAtual]['valor']-=x[1]
            cidadeItens[cidadeAtual]['peso']-=x[2]
            cidadeItens[cidadeAtual]['qtdItens']-=1
            todosItens.remove(x[0])
            break
        else:
            lastResult = result
            if(cidadeAtual not in rota):
                rota.append(cidadeAtual)
            
    return lastResult

def melhoraVelocidade(rota):
    
    solAtual, tempoAtual = solucaoFinal2(rota, todosItens.copy(), matrizAdjacencia.copy(), itens.copy(), minS, maxS, (maxS-minS)/cap, maxT, cap)
    print(solAtual, tempoAtual)
    aux22= copy.deepcopy(rota)
    for x in range(5):
        rotaVazia=[]
        for x in range(len(rota)-2):
            if (matrizCidadeProxima[rota[x]][rota[x+1]] in rota):
                rotaCopia = copy.deepcopy(rota)        
                rotaVazia=[]
                for index, i in enumerate(rotaCopia):
                    if i == matrizCidadeProxima[rotaCopia[x]][rotaCopia[x+1]]:
                        pass
                    elif rota[index]!=rotaCopia[x]:
                        rotaVazia.append(rotaCopia[index])

                    elif rota[index]==rotaCopia[x]:                
                        rotaVazia.append(rotaCopia[index])
                        rotaVazia.append(matrizCidadeProxima[rotaCopia[x]][rotaCopia[x+1]])                              

                        #print(len(rotaCopia), x)



                solu, tempo = solucaoFinal2(rotaVazia, todosItens.copy(), matrizAdjacencia.copy(), itens.copy(), minS, maxS, (maxS-minS)/cap, maxT, cap)
                if(tempo<tempoAtual):
                    rota=rotaVazia
                    tempoAtual=tempo
                    solAtual = solu

        retornoa,b = solucaoFinal2(rota, todosItens.copy(), matrizAdjacencia.copy(), itens.copy(), minS, maxS, (maxS-minS)/cap, maxT, cap)
        print(retornoa, b)
        for index, x in enumerate(cidadeVisitada):
            cidadeVisitada[index]=False
        cidadeVisitada[0]=True
        cidadeVisitada[len(cidadeVisitada)-1]=True
        for x in rota:
            cidadeVisitada[x]=True


        for x in range(len(matrizAdjacencia)): 
            cidadeProxima = proximaCidade(matrizAdjacencia, dadosCidade, rota[len(rota)-1], cidadeVisitada)
            #print(cidadeProxima)
            if(cidadeProxima ==-1):
                continue
            cidadeVisitada[cidadeProxima]=True    
            adicionaMaximoItens(rota, cidadeItens, cidadeProxima, itensCidade[cidadeProxima], matrizAdjacencia, todosItens)
            #print(solution)
            cidadeAtual = cidadeProxima
    retornoa,b = solucaoFinal2(rota, todosItens.copy(), matrizAdjacencia.copy(), itens.copy(), minS, maxS, (maxS-minS)/cap, maxT, cap)
    print(retornoa, b)
    return retornoa, b

# %%
import numpy as np
import json
import random
resultados = []
import csv
arquivo='xxx'
podeEntrar=True
with open('file.csv', "rt") as f:
    reader = csv.reader(f)
    for row in reader:
        
        if (row[0] == 'a280_n1390_uncorr-similar-weights_10_01.thop'):
            #break
            podeEntrar=True
        if podeEntrar==False:
            continue
        print ('thop/instances/'+row[0].split('_')[0] +'-thop/'+row[0])
        pontos = []
        itens = []


        with open('thop/instances/'+row[0].split('_')[0] +'-thop/'+row[0], 'r') as file:    
            name = file.readline().strip().replace(' ','').split(':')[1]    
            knapsack = file.readline().strip().replace(' ','').split(':')[1]    
            dimension = int(file.readline().strip().replace(' ','').split(':')[1])
            nItens = int(file.readline().strip().replace(' ','').split(':')[1])
            capacity = int(file.readline().strip().replace(' ','').split(':')[1])
            maxTime = int(file.readline().strip().replace(' ','').split(':')[1])
            minSpeed = float(file.readline().strip().replace(' ','').split(':')[1])
            maxSpeed = float(file.readline().strip().replace(' ','').split(':')[1])
            edgeType = file.readline().strip().replace(' ','').split(':')[1]
            pontosSection = True

            for x in file:
                if 'NODE_COORD_SECTION' in x: 
                    print(x)
                elif 'ITEMS SECTION' in x: 
                    pontosSection = False
                    print(x)
                else:
                    if(pontosSection):
                        pontos.append([float(i) for i in x.split()])
                    else:                
                        itens.append([float(i) if index!=0 and index!=3 else int(i)-1 for index, i in enumerate(x.split())]+[float(x.split()[1])/float(x.split()[2])]+[False])

        #print(pontos)
        #print(itens)



        matrizAdjacencia = []
        vetorCidadeProxima = {}
        itensCidade=[]
        dadosCidade = []
        cidadeVisitada = []

        for x in pontos:    
            itensCidade.append([])      
            dadosCidade.append(0) 
            cidadeVisitada.append(False)
            aux = []
            menor = 100000000000
            for y in pontos:
                d = dist(x,y)
                if(d<menor):
                    menor=d
                    ponto = y
                aux.append(d)

            vetorCidadeProxima[x[0]]=ponto[0]
            matrizAdjacencia.append(aux)

        for x in itens:
            itensCidade[int(x[3])].append(x)
            dadosCidade[int(x[3])]+=x[4]
        itensOrdenados = []
        #print(itensCidade)

        for index, x in enumerate(itensCidade):
            itensCidade[index]= sorted(x, key=lambda y: y[5], reverse=True)
            #print(itensOrdenados[index])
        #for x in itensOrdenados:
            #print (x)




    ################################
    
        
        if(arquivo!=row[0].split('_')[0]):
            arquivo=row[0].split('_')[0]
            print('entrou')



            #rota, cidadeItens
            matrizCidadeProxima = []
            for x in matrizAdjacencia:    
                matrizCidadeProxima.append([0]*len(matrizAdjacencia))
            ind = -1
            for x in range(len(matrizCidadeProxima)):
                for y in range(len(matrizCidadeProxima)):
                    soma = 10000000000000000        
                    for z in range(len(matrizCidadeProxima)):
                        if(x!=y and y!=z and z!=x):
                            valor = matrizAdjacencia[x][z] + matrizAdjacencia[z][y]
                            #print(valor)
                            if(soma > valor):
                                ind = z
                                soma = valor
                    matrizCidadeProxima[x][y] = ind
            matrizCidadeProxima[0]

            print("saiu")
        ##################################
        solucoes = []
        for nSolucoes in range(10):
            minS = minSpeed
            maxS = maxSpeed
            cap = capacity
            maxT = maxTime
            todosItens = []  
            for index, x in enumerate(cidadeVisitada):
                cidadeVisitada[index]=False
            cidadeVisitada[0]=True
            cidadeVisitada[len(cidadeVisitada)-1]=True

            cidadeItens=[]
            for x in range(len(matrizAdjacencia)):
                cidadeItens.append(copy.deepcopy({'peso':0, 'valor':0, 'qtdItens':0}))


            rota = []
            while(len(rota)==0):
                cidadeInicial = np.random.randint(1, len(pontos)-1)
                #rota.append(cidadeInicial)
                cidadeAtual = cidadeInicial
                cidadeVisitada[cidadeInicial]=True


                adicionaMaximoItens(rota, cidadeItens, cidadeInicial, itensCidade[cidadeAtual], matrizAdjacencia, todosItens)
            #print('saiu')
            #print('sol', solucaoFinal(rota, todosItens.copy(), matrizAdjacencia.copy(), itens.copy(), minS, maxS, (maxS-minS)/cap, maxT, cap))
            #cidadeAtual = cidadeInicial
            for x in range(len(matrizAdjacencia)):  
                cidadeProxima = proximaCidade(matrizAdjacencia, dadosCidade, cidadeAtual, cidadeVisitada)
                #print(cidadeProxima)
                if(cidadeProxima ==-1):
                    continue
                cidadeVisitada[cidadeProxima]=True    
                adicionaMaximoItens(rota, cidadeItens, cidadeProxima, itensCidade[cidadeProxima], matrizAdjacencia, todosItens)
                #print(solution)
                cidadeAtual = cidadeProxima


            soma = 0
            for x in cidadeItens:
                soma += x['valor']
            #print(rota, todosItens, soma)



            #################################

            melhorSolucao = -1
            naoSei = 0
            while(naoSei < 50):
                solAtual, tempoAtual = solucaoFinal2(rota, todosItens.copy(), matrizAdjacencia.copy(), itens.copy(), minS, maxS, (maxS-minS)/cap, maxT, cap)
                print(solAtual, tempoAtual)
                aux22= []
                while len(rota)!=len(aux22):#se não adicionar ninguem sai
                    print("adicionou")
                    aux22= copy.deepcopy(rota)
                    aux33 = []
                    while rota!=aux33:#se não mudar ninguem de lugar sai
                        aux33 = copy.deepcopy(rota)
                        rotaVazia=[]
                        for x in range(len(rota)-1):
                            if (matrizCidadeProxima[rota[x]][rota[x+1]] in rota):
                                rotaCopia = copy.deepcopy(rota)        
                                rotaVazia=[]
                                for index, i in enumerate(rotaCopia):
                                    if i == matrizCidadeProxima[rotaCopia[x]][rotaCopia[x+1]]:
                                        pass
                                    elif rota[index]!=rotaCopia[x]:
                                        rotaVazia.append(rotaCopia[index])

                                    elif rota[index]==rotaCopia[x]:                
                                        rotaVazia.append(rotaCopia[index])
                                        rotaVazia.append(matrizCidadeProxima[rotaCopia[x]][rotaCopia[x+1]])



                                solu, tempo = solucaoFinal2(rotaVazia, todosItens.copy(), matrizAdjacencia.copy(), itens.copy(), minS, maxS, (maxS-minS)/cap, maxT, cap)
                                if(tempo<tempoAtual):
                                    rota=rotaVazia
                                    tempoAtual=tempo
                                    solAtual = solu
                        solu, tempo = solucaoFinal2(rota, todosItens.copy(), matrizAdjacencia.copy(), itens.copy(), minS, maxS, (maxS-minS)/cap, maxT, cap)
                        #print(solu, tempo)
                        '''
                        for index, x in enumerate(cidadeVisitada):
                            cidadeVisitada[index]=False
                        cidadeVisitada[0]=True
                        cidadeVisitada[len(cidadeVisitada)-1]=True
                        for x in rota:
                            cidadeVisitada[x]=True
                        '''


                    print('antes trocar pos', solucaoFinal2(rota, todosItens.copy(), matrizAdjacencia.copy(), itens.copy(), minS, maxS, (maxS-minS)/cap, maxT, cap))                    
                    for x in range(len(matrizAdjacencia)): 
                        cidadeProxima = proximaCidade(matrizAdjacencia, dadosCidade, rota[len(rota)-1], cidadeVisitada)
                        #print(cidadeProxima)
                        if(cidadeProxima ==-1):
                            continue
                        cidadeVisitada[cidadeProxima]=True    
                        adicionaMaximoItens(rota, cidadeItens, cidadeProxima, itensCidade[cidadeProxima], matrizAdjacencia, todosItens)
                        #print(solution)
                        cidadeAtual = cidadeProxima

                    solucaoAux = solucaoFinal(rota, todosItens.copy(), matrizAdjacencia.copy(), itens.copy(), minS, maxS, (maxS-minS)/cap, maxT, cap)
                    #print(solucaoAux)
                    #print('depois de trocar', solucaoFinal2(rota, todosItens.copy(), matrizAdjacencia.copy(), itens.copy(), minS, maxS, (maxS-minS)/cap, maxT, cap))
                atualSolucao = solucaoFinal(rota, todosItens.copy(), matrizAdjacencia.copy(), itens.copy(), minS, maxS, (maxS-minS)/cap, maxT, cap)
                
                if atualSolucao > melhorSolucao:
                    melhorSolucao = atualSolucao
                    melhorRota = rota
                    melhorItens = todosItens
                    melhorCidadeItens = cidadeItens
                solucoes.append({'instancia':row[0],'solucao':melhorSolucao, 'rota':melhorRota, 'itens':melhorItens})
                #print('outra solução')
                #################################
                
                ###gera outra solução e repete###
                
                #################################

                #melhoraVelocidade(rota)
                #solucoes.append(solucaoAux)
                rotaInicial = copy.deepcopy(rota)
                if len(rotaInicial)>20:
                    percent = len(rotaInicial)/10
                elif len(rotaInicial)>=3:
                    percent = len(rotaInicial)/3     
                else:
                    percent = len(rotaInicial)

                itensIniciais = copy.deepcopy(todosItens)
                cidadeItensIniciais = copy.deepcopy(cidadeItens)

                
                #############################################################
                
                
                #melhorSolucao = solucaoFinal(rota, todosItens.copy(), matrizAdjacencia.copy(), itens.copy(), minS, maxS, (maxS-minS)/cap, maxT, cap)

                #print(percent)
                
                #print('antesde gerar ', solucaoFinal(rota, todosItens.copy(), matrizAdjacencia.copy(), itens.copy(), minS, maxS, (maxS-minS)/cap, maxT, cap))
                while True:
                    for i in range(int(percent)):
                        element = random.choice (rota)
                        todosItens = [h for h in todosItens if itens[h][3] != element]
                        rota.remove(element)                
                        cidadeItens[element]['valor']=0
                        cidadeItens[element]['peso']=0
                        cidadeItens[element]['qtdItens']=0
                        #print(len(rotaInicial))

                    cidadeVisitada = [True if x in rota else False for x in range(len(pontos))]
                    cidadeAtual = rota[len(rota)-1]
                    for x in range(len(matrizAdjacencia)):
                        cidadeProxima = proximaCidade(matrizAdjacencia, dadosCidade, cidadeAtual, cidadeVisitada)
                        #print(cidadeProxima)
                        if(cidadeProxima ==-1):
                            break
                        cidadeVisitada[cidadeProxima]=True    
                        adicionaMaximoItens(rota, cidadeItensIniciais, cidadeProxima, itensCidade[cidadeProxima], matrizAdjacencia, todosItens)
                        #print(solution)
                        cidadeAtual = cidadeProxima
                    if(solucaoFinal(rota, todosItens.copy(), matrizAdjacencia.copy(), itens.copy(), minS, maxS, (maxS-minS)/cap, maxT, cap)!=-1):
                        #print('gerouSolucao aqui ', solucaoFinal(rota, todosItens.copy(), matrizAdjacencia.copy(), itens.copy(), minS, maxS, (maxS-minS)/cap, maxT, cap))
                        naoSei+=1
                        break
                    if naoSei==50:
                        break
                    
                    
                    naoSei+=1
                    
              
                #print('sol', solucaoAux, atualSolucao)  

            #solucoes.append(melhorSolucao)
                    
                    
            solucoes.append({'instancia':row[0],'solucao':melhorSolucao, 'rota':melhorRota, 'itens':melhorItens})
        maior=-1
        for x in solucoes:
            if x['solucao']>maior:
                maior=x['solucao']
                salvaInd=x
        with open('solucao.json','a') as ar:
            json.dump(salvaInd, ar)
        
        print(maior)
        #resultados.append(max(solucoes))
       
        #print(rota, aux22)
        #soma=0
        #for x in range(len(rota)):
        #    if rota[x]!=aux22[x]:
        #        soma+=1
        #print(soma)
# Out:
# thop/instances/eil51-thop/eil51_n147_bounded-strongly-corr_01_01.thop
# NODE_COORD_SECTION  (INDEX, X, Y):
#
# ITEMS SECTION    (INDEX, PROFIT, WEIGHT, ASSIGNED NODE NUMBER):
#
# entrou
# saiu
# 13084.0 0.7614236400601357
# adicionou
# antes trocar pos (13084.0, 0.6962058142216315)
# 12920.0 0.6099219288472206
# adicionou
# antes trocar pos (12920.0, 0.6099219288472206)
# 13057.0 0.7227490421142643
# adicionou
# antes trocar pos (13057.0, 0.6897343075551398)
# 10299.0 0.6090849347576234
# adicionou
# antes trocar pos (10299.0, 0.5765757693239916)
# 8230.0 0.4349070453244552
# adicionou
# antes trocar pos (8230.0, 0.4349070453244552)
# 11798.0 0.4851841361916559
# adicionou
# antes trocar pos (11798.0, 0.42234551595999137)
# 10184.0 0.5417514375445718
# adicionou
# antes trocar pos (10184.0, 0.5417514375445718)
# 11963.0 0.709058873879728
# adicionou
# antes trocar pos (11963.0, 0.709058873879728)
# 11762.0 0.5448227928769783
# adicionou
# antes trocar pos (11762.0, 0.5448227928769783)
# 15156.0 0.8488665554348097
# adicionou
# antes trocar pos (15156.0, 0.8488665554348097)
# 13036.0 0.7884106066467657
# adicionou
# antes trocar pos (13036.0, 0.6801485872166559)
# 12634.0 0.7652797432165738
# adicionou
# antes trocar pos (12634.0, 0.7652797432165738)
# 10104.0 0.6057042050495118
# adicionou
# antes trocar pos (10104.0, 0.6057042050495118)
# 10483.0 0.6092483143448492
# adicionou
# antes trocar pos (10483.0, 0.5199881969911903)
# 13047.0 0.6392304919974264
# adicionou
# antes trocar pos (13047.0, 0.6392304919974264)
# 11314.0 0.6591312044616555
# adicionou
# antes trocar pos (11314.0, 0.6494544779167395)
# 12593.0 0.681757408823001
# adicionou
# antes trocar pos (12593.0, 0.6458009770077804)
# 8617.0 0.5055359389790766
# adicionou
# antes trocar pos (8617.0, 0.32779220109043)
# 12103.0 0.6195991588261909
# adicionou
# antes trocar pos (12103.0, 0.5681595297766978)
# 7032.0 0.36777583869246444
# adicionou
# antes trocar pos (7032.0, 0.31518509720314586)
# 10104.0 0.6057042050495118
# adicionou
# antes trocar pos (10104.0, 0.6057042050495118)
# 10597.0 0.6462257234347056
# adicionou
# antes trocar pos (10597.0, 0.6462257234347056)
# 9723.0 0.5576056274616608
# adicionou
# antes trocar pos (9723.0, 0.5576056274616608)
# 11308.0 0.6566190379856718
# adicionou
# antes trocar pos (11308.0, 0.6566190379856718)
# 9950.0 0.5836934261439807
# adicionou
# antes trocar pos (9950.0, 0.5836934261439807)
# 11380.0 0.49548290933019296
# adicionou
# antes trocar pos (11380.0, 0.4474850738647906)
# 10814.0 0.5654604627485653
# adicionou
# antes trocar pos (10814.0, 0.5654604627485653)
# 12527.0 0.5420195485309379
# adicionou
# antes trocar pos (12527.0, 0.43367736516340094)
# 13258.0 0.7418691371499128
# adicionou
# antes trocar pos (13258.0, 0.7418691371499128)
# 10419.0 0.5340672242873614
# adicionou
# antes trocar pos (10419.0, 0.5340672242873614)
# 12518.0 0.7371415117492537
# adicionou
# antes trocar pos (12518.0, 0.7371415117492537)
# 12808.0 0.7937666180124454
# adicionou
# antes trocar pos (12808.0, 0.7937666180124454)
# 9610.0 0.5808452448661628
# adicionou
# antes trocar pos (9610.0, 0.5282832074010673)
# 11718.0 0.7195005361452559
# adicionou
# antes trocar pos (11718.0, 0.7195005361452559)
# 8045.0 0.4784726337065841
# adicionou
# antes trocar pos (8045.0, 0.39795556650460623)
# 13406.0 0.7497379275370225
# adicionou
# antes trocar pos (13406.0, 0.6879216164319758)
# 7690.0 0.2862484210973587
# adicionou
# antes trocar pos (7690.0, 0.2862484210973587)
# 12135.0 0.7305371052751327
# adicionou
# antes trocar pos (12135.0, 0.7305371052751327)
# 10230.0 0.5052456963185131
# adicionou
# antes trocar pos (10230.0, 0.5052456963185131)
# 13561.0 0.8637985434537349
# adicionou
# antes trocar pos (13561.0, 0.8240001731838356)
# 10160.0 0.5487409818594194
# adicionou
# antes trocar pos (10160.0, 0.4823041284787299)
# 14210.0 0.8037871195889458
# adicionou
# antes trocar pos (14210.0, 0.6814480276670337)
# 9814.0 0.41090519771178907
# adicionou
# antes trocar pos (9814.0, 0.41090519771178907)
# 7474.0 0.395271097561298
# adicionou
# antes trocar pos (7474.0, 0.395271097561298)
# 13992.0 0.8240226930133469
# adicionou
# antes trocar pos (13992.0, 0.8240226930133469)
# 12177.0 0.6853293739341256
# adicionou
# antes trocar pos (12177.0, 0.6734329113893607)
# 10526.0 0.6235566172910614
# adicionou
# antes trocar pos (10526.0, 0.5702507589836014)
# 11472.0 0.6854163525967679
# adicionou
# antes trocar pos (11472.0, 0.684107985663909)
# 10257.0 0.39769276000973136
# adicionou
# antes trocar pos (10257.0, 0.3078865901704119)
# 11629.0 0.6711630125690665
# adicionou
# antes trocar pos (11629.0, 0.541077113894865)
# 13214.0 0.7821952306954516
# adicionou
# antes trocar pos (13214.0, 0.7821952306954516)
# 13214.0 0.7821952306954516
# adicionou
# antes trocar pos (13214.0, 0.7821952306954516)
# 13214.0 0.7821952306954516
# adicionou
# antes trocar pos (13214.0, 0.7821952306954516)
# 12988.0 0.8375219250079602
# adicionou
# antes trocar pos (12988.0, 0.8375219250079602)
# 10479.0 0.6282800310746177
# adicionou
# antes trocar pos (10479.0, 0.6282800310746177)
# 10669.0 0.557401497817766
# adicionou
# antes trocar pos (10669.0, 0.4732058161902461)
# 8656.0 0.4965085619467182
# adicionou
# antes trocar pos (8656.0, 0.4965085619467182)
# 10467.0 0.5763046103344628
# adicionou
# antes trocar pos (10467.0, 0.5763046103344628)
# 12465.0 0.7307873186867638
# adicionou
# antes trocar pos (12465.0, 0.7307873186867638)
# 11680.0 0.7137109660765611
# adicionou
# antes trocar pos (11680.0, 0.6509930947955275)
# 12389.0 0.7810528969303542
# adicionou
# antes trocar pos (12389.0, 0.7298983044324262)
# 12714.0 0.739407113755871
# adicionou
# antes trocar pos (12714.0, 0.739407113755871)
# 11712.0 0.5663758394118911
# adicionou
# antes trocar pos (11712.0, 0.5663758394118911)
# 12027.0 0.7453045406848023
# adicionou
# antes trocar pos (12027.0, 0.6989445564606804)
# 10930.0 0.5047892926325949
# adicionou
# antes trocar pos (10930.0, 0.5047892926325949)
# 11239.0 0.6615760343272007
# adicionou
# antes trocar pos (11239.0, 0.6615760343272007)
# 10657.0 0.5229591706371295
# adicionou
# antes trocar pos (10657.0, 0.4643317110624138)
# 11634.0 0.6874151657543426
# adicionou
# antes trocar pos (11634.0, 0.6598110364393935)
# 10195.0 0.5717849257728226
# adicionou
# antes trocar pos (10195.0, 0.44743631875707396)
# 12922.0 0.7554838282736411
# adicionou
# antes trocar pos (12922.0, 0.7554838282736411)
# 10074.0 0.5260570115837245
# adicionou
# antes trocar pos (10074.0, 0.5260570115837245)
# 12259.0 0.7377037876820295
# adicionou
# antes trocar pos (12259.0, 0.7377037876820295)
# 11180.0 0.6442260632025919
# adicionou
# antes trocar pos (11180.0, 0.607241601105293)
# 13649.0 0.6808388191884329
# adicionou
# antes trocar pos (13649.0, 0.6808388191884329)
# 11423.0 0.6462890143655163
# adicionou
# antes trocar pos (11423.0, 0.5436090828228517)
# 8516.0 0.47898137730185214
# adicionou
# antes trocar pos (8516.0, 0.47898137730185214)
# 11069.0 0.6863841564063585
# adicionou
# antes trocar pos (11069.0, 0.6863841564063585)
# 12200.0 0.7302824638026874
# adicionou
# antes trocar pos (12200.0, 0.5478737248707903)
# 13084.0 0.7614236400601357
# adicionou
# antes trocar pos (13084.0, 0.6962058142216315)
# 9186.0 0.4275083787533399
# adicionou
# antes trocar pos (9186.0, 0.4275083787533399)
# 14933.0 0.9116599611759583
# adicionou
# antes trocar pos (14933.0, 0.9116599611759583)
# 12391.0 0.7204390155497751
# adicionou
# antes trocar pos (12391.0, 0.7204390155497751)
# 14018.0 0.8262052056318403
# adicionou
# antes trocar pos (14018.0, 0.8262052056318403)
# 11695.0 0.6891672737851492
# adicionou
# antes trocar pos (11695.0, 0.6891672737851492)
# 11116.0 0.5947055710789736
# adicionou
# antes trocar pos (11116.0, 0.5947055710789736)
# 12999.0 0.5213027941878279
# adicionou
# antes trocar pos (12999.0, 0.49791459134719135)
# 8473.0 0.38935475141848735
# adicionou
# antes trocar pos (8473.0, 0.38935475141848735)
# 11483.0 0.6733473356195451
# adicionou
# antes trocar pos (11483.0, 0.6733473356195451)
# 10413.0 0.6404455416439438
# adicionou
# antes trocar pos (10413.0, 0.6404455416439438)
# 13213.0 0.7669695167464358
# adicionou
# antes trocar pos (13213.0, 0.7566369855044013)
# 10874.0 0.48032560909591254
# adicionou
# antes trocar pos (10874.0, 0.48032560909591254)
# 11172.0 0.5719399468159478
# adicionou
# antes trocar pos (11172.0, 0.5547069799390457)
# 11677.0 0.6197586007391883
# adicionou
# antes trocar pos (11677.0, 0.6197586007391883)
# 13403.0 0.7794961798065345
# adicionou
# antes trocar pos (13403.0, 0.7617019190005401)
# 11980.0 0.6515681827827309
# adicionou
# antes trocar pos (11980.0, 0.6429079492504319)
# 13111.0 0.6980429929190892
# adicionou
# antes trocar pos (13111.0, 0.6980429929190892)
# 10018.0 0.5428256438928145
# adicionou
# antes trocar pos (10018.0, 0.5428256438928145)
# 12219.0 0.6069932681604966
# adicionou
# antes trocar pos (12219.0, 0.6069932681604966)
# 6748.0 0.318926840636121
# adicionou
# antes trocar pos (6748.0, 0.28089423058862634)
# 15156.0
# thop/instances/eil51-thop/eil51_n147_bounded-strongly-corr_01_02.thop
# NODE_COORD_SECTION  (INDEX, X, Y):
#
# ITEMS SECTION    (INDEX, PROFIT, WEIGHT, ASSIGNED NODE NUMBER):
#
# 16115.0 0.9475916632014058
# adicionou
# antes trocar pos (16115.0, 0.8600848687637991)
# 14879.0 0.8915479407186417
# adicionou
# antes trocar pos (14879.0, 0.8902375301882778)
# 15408.0 0.9200516710704622
# adicionou
# antes trocar pos (15408.0, 0.9200516710704622)
# 13668.0 0.8439477764959247
# adicionou
# antes trocar pos (13668.0, 0.8439477764959247)
# 14242.0 0.8136530709278283
# adicionou
# antes trocar pos (14242.0, 0.6078057163361462)
# 8151.0 0.2946591866443237
# adicionou
# antes trocar pos (8151.0, 0.2946591866443237)
# 10182.0 0.5010197626709885
# adicionou
# antes trocar pos (10182.0, 0.2963939241014179)
# 9583.0 0.4060678251648764
# adicionou
# antes trocar pos (9583.0, 0.3590097232414459)
# 14900.0 0.7004430548118094
# adicionou
# antes trocar pos (14900.0, 0.6048122668260566)
# 12201.0 0.7124976150449922
# adicionou
# antes trocar pos (12201.0, 0.5672014579809078)
# 13860.0 0.8379096310689681
# adicionou
# antes trocar pos (13860.0, 0.8379096310689681)
# 13819.0 0.8215400044984886
# adicionou
# antes trocar pos (13819.0, 0.7835627820661079)
# 13054.0 0.6630440734005003
# adicionou
# antes trocar pos (13054.0, 0.6423475860399559)
# 8610.0 0.38250643405459067
# adicionou
# antes trocar pos (8610.0, 0.3522278831577296)
# 12383.0 0.7102418346147948
# adicionou
# antes trocar pos (12383.0, 0.6872256771613902)
# 10956.0 0.5815979980573703
# adicionou
# antes trocar pos (10956.0, 0.4154550291122851)
# 11857.0 0.6696658689556196
# adicionou
# antes trocar pos (11857.0, 0.5993037344045992)
# 12612.0 0.777848216286498
# adicionou
# antes trocar pos (12612.0, 0.777848216286498)
# 14203.0 0.8545840339540615
# adicionou
# antes trocar pos (14203.0, 0.8545840339540615)
# 14522.0 0.8921378738587425
# adicionou
# antes trocar pos (14522.0, 0.878592205410525)
# 12927.0 0.6522438992152388
# adicionou
# antes trocar pos (12927.0, 0.6463892739267866)
# 12002.0 0.5203732962487451
# adicionou
# antes trocar pos (12002.0, 0.5203732962487451)
# 15599.0 0.9546486543327201
# adicionou
# antes trocar pos (15599.0, 0.9100961294246149)
# 12515.0 0.728068554599252
# adicionou
# antes trocar pos (12515.0, 0.728068554599252)
# 13435.0 0.8235410984513672
# adicionou
# antes trocar pos (13435.0, 0.7070908084743631)
# 10072.0 0.38217996590663766
# adicionou
# antes trocar pos (10072.0, 0.37882762004346193)
# 15861.0 0.9699250831029321
# adicionou
# antes trocar pos (15861.0, 0.9270967964838561)
# 13336.0 0.6431915956852555
# adicionou
# antes trocar pos (13336.0, 0.6431915956852555)
# 13406.0 0.7904015795802637
# adicionou
# antes trocar pos (13406.0, 0.7904015795802637)
# 12834.0 0.7613234910608105
# adicionou
# antes trocar pos (12834.0, 0.7613234910608105)
# 10989.0 0.6280385222131867
# adicionou
# antes trocar pos (10989.0, 0.5471944202974828)
# 8945.0 0.4362104178767458
# adicionou
# antes trocar pos (8945.0, 0.42709034145190966)
# 11472.0 0.6768065927927288
# adicionou
# antes trocar pos (11472.0, 0.6659530023109004)
# 12215.0 0.5093638695611735
# adicionou
# antes trocar pos (12215.0, 0.5093638695611735)
# 11412.0 0.6646631438964183
# adicionou
# antes trocar pos (11412.0, 0.5185823528654467)
# 14458.0 0.8700808918580554
# adicionou
# antes trocar pos (14458.0, 0.8700808918580554)
# 10839.0 0.49708123573786966
# adicionou
# antes trocar pos (10839.0, 0.4023180684910333)
# 11927.0 0.6141223214774937
# adicionou
# antes trocar pos (11927.0, 0.6141223214774937)
# 13762.0 0.7007146743727038
# adicionou
# antes trocar pos (13762.0, 0.7007146743727038)
# 10161.0 0.47449088433852277
# adicionou
# antes trocar pos (10161.0, 0.3625097653896832)
# 11823.0 0.5169282808100616
# adicionou
# antes trocar pos (11823.0, 0.4778675367104213)
# 12829.0 0.7311637931048639
# adicionou
# antes trocar pos (12829.0, 0.6542359807752262)
# 12681.0 0.648457518660746
# adicionou
# antes trocar pos (12681.0, 0.6264911954952791)
# 13825.0 0.7944647588161643
# adicionou
# antes trocar pos (13825.0, 0.716967160229377)
# 13745.0 0.7943007674136587
# adicionou
# antes trocar pos (13745.0, 0.7943007674136587)
# 13684.0 0.6374873139609721
# adicionou
# antes trocar pos (13684.0, 0.6245568808191261)
# 14688.0 0.7793557959350758
# adicionou
# antes trocar pos (14688.0, 0.749923753753679)
# 12117.0 0.4105856092773649
# adicionou
# antes trocar pos (12117.0, 0.4105856092773649)
# 14358.0 0.7872935131911488
# adicionou
# antes trocar pos (14358.0, 0.7583259712080358)
# 12795.0 0.7406066351620616
# adicionou
# antes trocar pos (12795.0, 0.6926324375477966)
# 11141.0 0.48445027152874987
# adicionou
# antes trocar pos (11141.0, 0.33731250268492813)
# 15810.0 0.9394387944635897
# adicionou
# antes trocar pos (15810.0, 0.9259027997373412)
# 13300.0 0.7698199933023374
# adicionou
# antes trocar pos (13300.0, 0.6144014566453457)
# 9356.0 0.4995223605694428
# adicionou
# antes trocar pos (9356.0, 0.43034652462740663)
# 13887.0 0.7594355077291376
# adicionou
# antes trocar pos (13887.0, 0.7594355077291376)
# 15189.0 0.849693623181944
# adicionou
# antes trocar pos (15189.0, 0.7955042943553456)
# 14205.0 0.7610834106096694
# adicionou
# antes trocar pos (14205.0, 0.6285397891870659)
# 13914.0 0.6756946680773127
# adicionou
# antes trocar pos (13914.0, 0.6053411400301115)
# 13080.0 0.7377929719101629
# adicionou
# antes trocar pos (13080.0, 0.6172080904778185)
# 9501.0 0.4428357580628834
# adicionou
# antes trocar pos (9501.0, 0.3691696102671004)
# 14394.0 0.8842206766214045
# adicionou
# antes trocar pos (14394.0, 0.8842206766214045)
# 10974.0 0.4868099748689437
# adicionou
# antes trocar pos (10974.0, 0.4602057589269773)
# 13825.0 0.8351700964858677
# adicionou
# antes trocar pos (13825.0, 0.7422625351601359)
# 13896.0 0.7769669328955564
# adicionou
# antes trocar pos (13896.0, 0.6614991838697274)
# 15047.0 0.9028195780387066
# adicionou
# antes trocar pos (15047.0, 0.9028195780387066)
# 14398.0 0.8605646040590611
# adicionou
# antes trocar pos (14398.0, 0.8605646040590611)
# 11371.0 0.530364670993503
# adicionou
# antes trocar pos (11371.0, 0.3963409284066564)
# 13610.0 0.8342315686691794
# adicionou
# antes trocar pos (13610.0, 0.8342315686691794)
# 14433.0 0.6766202214086405
# adicionou
# antes trocar pos (14433.0, 0.6766202214086405)
# 12221.0 0.706694684416686
# adicionou
# antes trocar pos (12221.0, 0.5276495566150441)
# 8567.0 0.4586980320490791
# adicionou
# antes trocar pos (8567.0, 0.3819280905971138)
# 15285.0 0.9414094030077501
# adicionou
# antes trocar pos (15285.0, 0.9390445489303407)
# 11505.0 0.4401287930391651
# adicionou
# antes trocar pos (11505.0, 0.35325366768335537)
# 13860.0 0.8379096310689681
# adicionou
# antes trocar pos (13860.0, 0.8379096310689681)
# 13819.0 0.8215400044984886
# adicionou
# antes trocar pos (13819.0, 0.7835627820661079)
# 13819.0 0.8215400044984886
# adicionou
# antes trocar pos (13819.0, 0.7835627820661079)
# 13287.0 0.6465899538669808
# adicionou
# antes trocar pos (13287.0, 0.5930060017106383)
# 14264.0 0.8599474833212741
# adicionou
# antes trocar pos (14264.0, 0.8243373272496519)
# 8312.0 0.3197472337165704
# adicionou
# antes trocar pos (8312.0, 0.3197472337165704)
# 12875.0 0.42755469490395903
# adicionou
# antes trocar pos (12875.0, 0.36736539397484763)
# 12910.0 0.6383778915978713
# adicionou
# antes trocar pos (12910.0, 0.573112730580249)
# 16292.0 0.9346785854337202
# adicionou
# antes trocar pos (16292.0, 0.9346785854337202)
# 10985.0 0.5771280515631566
# adicionou
# antes trocar pos (10985.0, 0.5771280515631566)
# 9786.0 0.34596453843286523
# adicionou
# antes trocar pos (9786.0, 0.34596453843286523)
# 14369.0 0.8509452184788713
# adicionou
# antes trocar pos (14369.0, 0.7767203008503)
# 14735.0 0.870824071214793
# adicionou
# antes trocar pos (14735.0, 0.870824071214793)
# 13621.0 0.7542459513000562
# adicionou
# antes trocar pos (13621.0, 0.7542459513000562)
# 13516.0 0.7518560979698985
# adicionou
# antes trocar pos (13516.0, 0.7518560979698985)
# 12976.0 0.676137902078584
# adicionou
# antes trocar pos (12976.0, 0.6638035520886658)
# 12004.0 0.6318677999286224
# adicionou
# antes trocar pos (12004.0, 0.6318677999286224)
# 14615.0 0.7272762680166637
# adicionou
# antes trocar pos (14615.0, 0.7040319391685744)
# 9476.0 0.408941522442138
# adicionou
# antes trocar pos (9476.0, 0.40172222118668877)
# 10724.0 0.6031236553803396
# adicionou
# antes trocar pos (10724.0, 0.4909098429027112)
# 12454.0 0.7229478888744455
# adicionou
# antes trocar pos (12454.0, 0.7229478888744455)
# 16292.0
# thop/instances/eil51-thop/eil51_n147_bounded-strongly-corr_01_03.thop
# NODE_COORD_SECTION  (INDEX, X, Y):
#
# ITEMS SECTION    (INDEX, PROFIT, WEIGHT, ASSIGNED NODE NUMBER):
# 14635.0 0.8482748664312255
# adicionou
# antes trocar pos (14635.0, 0.7914969604620756)
# 15403.0 0.9116857829978599
# adicionou
# antes trocar pos (15403.0, 0.8842177540066386)
# 13354.0 0.5206245038578888
# adicionou
# antes trocar pos (13354.0, 0.5206245038578888)
# 15566.0 0.9077356746781778
# adicionou
# antes trocar pos (15566.0, 0.9077356746781778)
# 13723.0 0.6837029241836868
# adicionou
# antes trocar pos (13723.0, 0.5596416787413578)
# 14364.0 0.8438894147176839
# adicionou
# antes trocar pos (14364.0, 0.6900559804714981)
# 14684.0 0.8420857883830476
# adicionou
# antes trocar pos (14684.0, 0.6307960955910202)
# 12506.0 0.5121807694998082
# adicionou
# antes trocar pos (12506.0, 0.4835035929261073)
# 9579.0 0.45893639598517655
# adicionou
# antes trocar pos (9579.0, 0.45893639598517655)
# 14001.0 0.8078278138703623
# adicionou
# antes trocar pos (14001.0, 0.619289280480944)
# 15800.0 0.9175646501704492
# adicionou
# antes trocar pos (15800.0, 0.8581116536282118)
# 14402.0 0.8317175752996571
# adicionou
# antes trocar pos (14402.0, 0.8317175752996571)
# 13647.0 0.6932981323982488
# adicionou
# antes trocar pos (13647.0, 0.6932981323982488)
# 12308.0 0.6245390658847438
# adicionou
# antes trocar pos (12308.0, 0.5007527350499585)
# 12599.0 0.5679677700559039
# adicionou
# antes trocar pos (12599.0, 0.4927748140233106)
# 12961.0 0.5974062983610344
# adicionou
# antes trocar pos (12961.0, 0.5147421562519875)
# 14237.0 0.8204197578311893
# adicionou
# antes trocar pos (14237.0, 0.6528116129561999)
# 13135.0 0.6898522041735083
# adicionou
# antes trocar pos (13135.0, 0.5889907059012486)
# 13778.0 0.6892889919276307
# adicionou
# antes trocar pos (13778.0, 0.5661559927159113)
# 13139.0 0.7482166070874378
# adicionou
# antes trocar pos (13139.0, 0.5893910526564954)
# 12232.0 0.7644934934083144
# adicionou
# antes trocar pos (12232.0, 0.7189155768570931)
# 12385.0 0.5084968331507902
# adicionou
# antes trocar pos (12385.0, 0.3996038076090867)
# 16501.0 0.9257326618964528
# adicionou
# antes trocar pos (16501.0, 0.7040514107865171)
# 14288.0 0.5777347914534489
# adicionou
# antes trocar pos (14288.0, 0.5194153101266806)
# 11303.0 0.5105338721690502
# adicionou
# antes trocar pos (11303.0, 0.4796523177701429)
# 15718.0 0.8441549513719806
# adicionou
# antes trocar pos (15718.0, 0.8441549513719806)
# 14681.0 0.8471263912132978
# adicionou
# antes trocar pos (14681.0, 0.6639131644242214)
# 13706.0 0.5687277040679617
# adicionou
# antes trocar pos (13706.0, 0.5687277040679617)
# 12917.0 0.6775310220927934
# adicionou
# antes trocar pos (12917.0, 0.5144916650630079)
# 14958.0 0.8569599275342581
# adicionou
# antes trocar pos (14958.0, 0.731395983166647)
# 15013.0 0.7982845271662254
# adicionou
# antes trocar pos (15013.0, 0.7440642928751898)
# 16737.0 0.8810252123923501
# adicionou
# antes trocar pos (16737.0, 0.8810252123923501)
# 14187.0 0.8237815902497811
# adicionou
# antes trocar pos (14187.0, 0.8237815902497811)
# 14239.0 0.8752258298398614
# adicionou
# antes trocar pos (14239.0, 0.8752258298398614)
# 13873.0 0.708298955223781
# adicionou
# antes trocar pos (13873.0, 0.708298955223781)
# 11318.0 0.4666552731308463
# adicionou
# antes trocar pos (11318.0, 0.4666552731308463)
# 12272.0 0.5457618964309632
# adicionou
# antes trocar pos (12272.0, 0.5457618964309632)
# 12239.0 0.4022160690527215
# adicionou
# antes trocar pos (12239.0, 0.3564753904186611)
# 11879.0 0.5663217099018151
# adicionou
# antes trocar pos (11879.0, 0.48558012457017025)
# 14896.0 0.8519241323136227
# adicionou
# antes trocar pos (14896.0, 0.8519241323136227)
# 14820.0 0.7367176231253624
# adicionou
# antes trocar pos (14820.0, 0.7367176231253624)
# 14457.0 0.8423442366705228
# adicionou
# antes trocar pos (14457.0, 0.8423442366705228)
# 16578.0 0.9436823359963825
# adicionou
# antes trocar pos (16578.0, 0.9316728492420444)
# 13833.0 0.5607574831042018
# adicionou
# antes trocar pos (13833.0, 0.5139915772883751)
# 12538.0 0.3344947930717988
# adicionou
# antes trocar pos (12538.0, 0.3344947930717988)
# 11132.0 0.5531544973032702
# adicionou
# antes trocar pos (11132.0, 0.4387512022549115)
# 9863.0 0.2614099320495937
# adicionou
# antes trocar pos (9863.0, 0.2614099320495937)
# 14355.0 0.7816548833230694
# adicionou
# antes trocar pos (14355.0, 0.7816548833230694)
# 13097.0 0.5464307847571451
# adicionou
# antes trocar pos (13097.0, 0.520683949401189)
# 14405.0 0.865336172569706
# adicionou
# antes trocar pos (14405.0, 0.8517400618453113)
# 13256.0 0.7288039641284737
# adicionou
# antes trocar pos (13256.0, 0.6214125667716317)
# 12529.0 0.6902634821452268
# adicionou
# antes trocar pos (12529.0, 0.5104104599651411)
# 15133.0 0.8836339553398176
# adicionou
# antes trocar pos (15133.0, 0.8612569312413615)
# 14394.0 0.7251281008154883
# adicionou
# antes trocar pos (14394.0, 0.7018290812015254)
# 12906.0 0.47134319488650506
# adicionou
# antes trocar pos (12906.0, 0.47134319488650506)
# 13885.0 0.6847994779657361
# adicionou
# antes trocar pos (13885.0, 0.6318318014050552)
# 13719.0 0.6854191775124975
# adicionou
# antes trocar pos (13719.0, 0.5500411438938572)
# 16121.0 0.8877141564192146
# adicionou
# antes trocar pos (16121.0, 0.7615263069288222)
# 12426.0 0.42473358713207254
# adicionou
# antes trocar pos (12426.0, 0.42473358713207254)
# 11554.0 0.4419964109661339
# adicionou
# antes trocar pos (11554.0, 0.38024484949551585)
# 14980.0 0.8221143601977025
# adicionou
# antes trocar pos (14980.0, 0.7921105380590544)
# 13843.0 0.7479259198955375
# adicionou
# antes trocar pos (13843.0, 0.7163110870119738)
# 13159.0 0.7333903592459691
# adicionou
# antes trocar pos (13159.0, 0.5556947640340311)
# 16429.0 0.9338770791784246
# adicionou
# antes trocar pos (16429.0, 0.9338770791784246)
# 16604.0 0.8326069201135101
# adicionou
# antes trocar pos (16604.0, 0.7327966535037549)
# 16232.0 0.8151089438376087
# adicionou
# antes trocar pos (16232.0, 0.7631486793739002)
# 13433.0 0.3896274352772024
# adicionou
# antes trocar pos (13433.0, 0.3896274352772024)
# 16031.0 0.8503431019918691
# adicionou
# antes trocar pos (16031.0, 0.8076999537909298)
# 13420.0 0.720558497899182
# adicionou
# antes trocar pos (13420.0, 0.6083746692104494)
# 13544.0 0.476065411315489
# adicionou
# antes trocar pos (13544.0, 0.46432645154425967)
# 13735.0 0.7383455822189187
# adicionou
# antes trocar pos (13735.0, 0.5954093839350509)
# 14278.0 0.6596352638548368
# adicionou
# antes trocar pos (14278.0, 0.5844757222585651)
# 14803.0 0.8464404542073891
# adicionou
# antes trocar pos (14803.0, 0.8464404542073891)
# 12042.0 0.5572924204928249
# adicionou
# antes trocar pos (12042.0, 0.38370904316609683)
# 11128.0 0.5242239810296008
# adicionou
# antes trocar pos (11128.0, 0.42830967274116716)
# 12683.0 0.796407080560472
# adicionou
# antes trocar pos (12683.0, 0.7471162090865887)
# 9456.0 0.38363102089696816
# adicionou
# antes trocar pos (9456.0, 0.38363102089696816)
# 14635.0 0.8482748664312255
# adicionou
# antes trocar pos (14635.0, 0.7914969604620756)
# 14644.0 0.7793910746041816
# adicionou
# antes trocar pos (14644.0, 0.770899107073286)
# 13692.0 0.7896854328280802
# adicionou
# antes trocar pos (13692.0, 0.7896854328280802)
# 13437.0 0.7262603732278529
# adicionou
# antes trocar pos (13437.0, 0.6566674461327058)
# 12603.0 0.6393643437359915
# adicionou
# antes trocar pos (12603.0, 0.5570562769904935)
# 15595.0 0.8173323505047996
# adicionou
# antes trocar pos (15595.0, 0.8173323505047996)
# 14164.0 0.8464308124652936
# adicionou
# antes trocar pos (14164.0, 0.7191078671030601)
# 15126.0 0.7423753101265785
# adicionou
# antes trocar pos (15126.0, 0.7423753101265785)
# 15913.0 0.9335113015417648
# adicionou
# antes trocar pos (15913.0, 0.8027428655162787)
# 14619.0 0.48018681415776104
# adicionou
# antes trocar pos (14619.0, 0.48018681415776104)
# 15750.0 0.7554246262396763
# adicionou
# antes trocar pos (15750.0, 0.7357889401258526)
# 14778.0 0.6930889333240172
# adicionou
# antes trocar pos (14778.0, 0.6836145336092829)
# 15588.0 0.7999142117976467
# adicionou
# antes trocar pos (15588.0, 0.611143755383242)
# 12362.0 0.5601684312874546
# adicionou
# antes trocar pos (12362.0, 0.5601684312874546)
# 11970.0 0.4980121715356833
# adicionou
# antes trocar pos (11970.0, 0.4754647815595594)
# 13194.0 0.6238102861281587
# adicionou
# antes trocar pos (13194.0, 0.5286492228597361)
# 14472.0 0.7815506176485372
# adicionou
# antes trocar pos (14472.0, 0.7010670459997675)
# 13089.0 0.5170889804400711
# adicionou
# antes trocar pos (13089.0, 0.47568796943199765)
# 14035.0 0.7158262223279294
# adicionou
# antes trocar pos (14035.0, 0.5801739890900502)
# 15517.0 0.9032199163730409
# adicionou
# antes trocar pos (15517.0, 0.7642937360452134)
# 10196.0 0.5645012406046848
# adicionou
# antes trocar pos (10196.0, 0.5337208193335952)
# 15800.0 0.9175646501704492
# adicionou
# antes trocar pos (15800.0, 0.8581116536282118)
# 12166.0 0.4307452569993798
# adicionou
# antes trocar pos (12166.0, 0.4307452569993798)
# 14220.0 0.8057593398457198
# adicionou
# antes trocar pos (14220.0, 0.6362609450371173)
# 15664.0 0.9590310978578389
# adicionou
# antes trocar pos (15664.0, 0.7757735911489669)
# 13844.0 0.6555403142624697
# adicionou
# antes trocar pos (13844.0, 0.6321896193599078)
# 10807.0 0.5074730885592209
# adicionou
# antes trocar pos (10807.0, 0.4054361227813397)
# 11823.0 0.5200294471737438
# adicionou
# antes trocar pos (11823.0, 0.45209494269738215)
# 12629.0 0.48770332711034686
# adicionou
# antes trocar pos (12629.0, 0.29041002621323797)
# 15036.0 0.8361238014181586
# adicionou
# antes trocar pos (15036.0, 0.7692556921703522)
# 13671.0 0.815880524553564
# adicionou
# antes trocar pos (13671.0, 0.6141233739282786)
# 16737.0
# thop/instances/eil51-thop/eil51_n147_bounded-strongly-corr_05_01.thop
# NODE_COORD_SECTION  (INDEX, X, Y):
#
# ITEMS SECTION    (INDEX, PROFIT, WEIGHT, ASSIGNED NODE NUMBER):
#
# 48988.0 0.6307540936849007
# adicionou
# antes trocar pos (48988.0, 0.6161112914694777)
# 45572.0 0.6099421008956197
# adicionou
# antes trocar pos (45572.0, 0.555927450365733)
# 34638.0 0.4348909719898335
# adicionou
# antes trocar pos (34638.0, 0.37997766815433914)
# 37112.0 0.4824001914396415
# adicionou
# antes trocar pos (37112.0, 0.4168301562954432)
# 35494.0 0.44096621743784215
# adicionou
# antes trocar pos (35494.0, 0.3215004088166081)
# 30383.0 0.3802870021848298
# adicionou
# antes trocar pos (30383.0, 0.291915422074864)
# 24024.0 0.28537039147161936
# adicionou
# antes trocar pos (24024.0, 0.22037182932130717)
# 43501.0 0.5366785098916749
# adicionou
# antes trocar pos (43501.0, 0.46953308664171955)
# 31831.0 0.40262430895186874
# adicionou
# antes trocar pos (31831.0, 0.3831878283759281)
# 33900.0 0.3921461633899719
# adicionou
# antes trocar pos (33900.0, 0.3921461633899719)
# 52282.0 0.6879535481006932
# adicionou
# antes trocar pos (52282.0, 0.6702445782111618)
# 46391.0 0.5849655223351444
# adicionou
# antes trocar pos (46391.0, 0.5849655223351444)
# 41805.0 0.551287370174721
# adicionou
# antes trocar pos (41805.0, 0.4560403978587242)
# 35586.0 0.4127663559070387
# adicionou
# antes trocar pos (35586.0, 0.36364671063108994)
# 38378.0 0.4797742238193516
# adicionou
# antes trocar pos (38378.0, 0.37239677340771526)
# 28662.0 0.3626190026906455
# adicionou
# antes trocar pos (28662.0, 0.33707928013872346)
# 33031.0 0.41124941181032465
# adicionou
# antes trocar pos (33031.0, 0.40689879166096327)
# 34176.0 0.39988715464609553
# adicionou
# antes trocar pos (34176.0, 0.38450580933289047)
# 41233.0 0.4909423668836442
# adicionou
# antes trocar pos (41233.0, 0.48466801569262086)
# 25872.0 0.3084091896736293
# adicionou
# antes trocar pos (25872.0, 0.21328839848037556)
# 57549.0 0.7393627824904996
# adicionou
# antes trocar pos (57549.0, 0.7393627824904996)
# 47953.0 0.6003480181321881
# adicionou
# antes trocar pos (47953.0, 0.5394398422694324)
# 45741.0 0.6040572151234027
# adicionou
# antes trocar pos (45741.0, 0.5258566662563214)
# 24852.0 0.29298901620491663
# adicionou
# antes trocar pos (24852.0, 0.29298901620491663)
# 36515.0 0.443846650539152
# adicionou
# antes trocar pos (36515.0, 0.443846650539152)
# 36636.0 0.45574045520055717
# adicionou
# antes trocar pos (36636.0, 0.421442526771756)
# 32932.0 0.3722479781906752
# adicionou
# antes trocar pos (32932.0, 0.3095108133785493)
# 37701.0 0.44210442808877587
# adicionou
# antes trocar pos (37701.0, 0.29197744349207516)
# 27730.0 0.34511368670430875
# adicionou
# antes trocar pos (27730.0, 0.2985407833615667)
# 48655.0 0.6325093274068628
# adicionou
# antes trocar pos (48655.0, 0.6141574486459134)
# 42691.0 0.5445718116409268
# adicionou
# antes trocar pos (42691.0, 0.5324733450173271)
# 44799.0 0.5546385130397045
# adicionou
# antes trocar pos (44799.0, 0.5020794237907936)
# 33393.0 0.4115928899457424
# adicionou
# antes trocar pos (33393.0, 0.3982704755879622)
# 33309.0 0.4118249422205093
# adicionou
# antes trocar pos (33309.0, 0.38817654013287206)
# 36530.0 0.45675983546867344
# adicionou
# antes trocar pos (36530.0, 0.396454250289958)
# 34499.0 0.43745971917260423
# adicionou
# antes trocar pos (34499.0, 0.3646068577714465)
# 25059.0 0.3155564511997134
# adicionou
# antes trocar pos (25059.0, 0.3155564511997134)
# 31291.0 0.3937370410658015
# adicionou
# antes trocar pos (31291.0, 0.35453038296269346)
# 39812.0 0.4994599991344241
# adicionou
# antes trocar pos (39812.0, 0.40423682667736155)
# 43704.0 0.5667139207654691
# adicionou
# antes trocar pos (43704.0, 0.5391586671818945)
# 39961.0 0.5139881397044295
# adicionou
# antes trocar pos (39961.0, 0.5139881397044295)
# 39961.0 0.4997627456327067
# adicionou
# antes trocar pos (39961.0, 0.4997627456327067)
# 46787.0 0.5932559405925963
# adicionou
# antes trocar pos (46787.0, 0.5372924929704238)
# 33637.0 0.4116104292371121
# adicionou
# antes trocar pos (33637.0, 0.3683259344175846)
# 43356.0 0.48661387115743965
# adicionou
# antes trocar pos (43356.0, 0.43296704929695806)
# 34195.0 0.4149831104772847
# adicionou
# antes trocar pos (34195.0, 0.38785293200056065)
# 36013.0 0.44997334571410297
# adicionou
# antes trocar pos (36013.0, 0.3164454554539923)
# 38853.0 0.5080697092175498
# adicionou
# antes trocar pos (38853.0, 0.4158615517360087)
# 30569.0 0.38320082685361634
# adicionou
# antes trocar pos (30569.0, 0.25011623479477285)
# 47790.0 0.620161224262012
# adicionou
# antes trocar pos (47790.0, 0.5949374061038819)
# 39022.0 0.49177114912885395
# adicionou
# antes trocar pos (39022.0, 0.4473730437177844)
# 35034.0 0.44013125952250604
# adicionou
# antes trocar pos (35034.0, 0.3915482484603503)
# 37984.0 0.4773917248713436
# adicionou
# antes trocar pos (37984.0, 0.46732771560512076)
# 34022.0 0.4235006654673806
# adicionou
# antes trocar pos (34022.0, 0.34057137173939184)
# 34573.0 0.4400406816131912
# adicionou
# antes trocar pos (34573.0, 0.4397986079520095)
# 33553.0 0.39365379910743936
# adicionou
# antes trocar pos (33553.0, 0.26041222441363815)
# 30448.0 0.35894060768690755
# adicionou
# antes trocar pos (30448.0, 0.2519336331235866)
# 30228.0 0.37771527025934387
# adicionou
# antes trocar pos (30228.0, 0.3142252391278264)
# 33723.0 0.3946232462440003
# adicionou
# antes trocar pos (33723.0, 0.3670431079858561)
# 51211.0 0.6530923322566943
# adicionou
# antes trocar pos (51211.0, 0.6465038005121605)
# 43888.0 0.556946732126388
# adicionou
# antes trocar pos (43888.0, 0.556946732126388)
# 41298.0 0.5266543238765988
# adicionou
# antes trocar pos (41298.0, 0.4205847983527533)
# 34270.0 0.4241158395641799
# adicionou
# antes trocar pos (34270.0, 0.3369233097910251)
# 37142.0 0.47141164102673144
# adicionou
# antes trocar pos (37142.0, 0.4189171417924132)
# 22520.0 0.28042587782900635
# adicionou
# antes trocar pos (22520.0, 0.2700439233691158)
# 36755.0 0.4648201819514791
# adicionou
# antes trocar pos (36755.0, 0.38531535553624263)
# 31474.0 0.3995395628678178
# adicionou
# antes trocar pos (31474.0, 0.2578443290908729)
# 37042.0 0.47836909832283697
# adicionou
# antes trocar pos (37042.0, 0.41269240781208166)
# 35864.0 0.42247592154782904
# adicionou
# antes trocar pos (35864.0, 0.33775057248249996)
# 48988.0 0.6307540936849007
# adicionou
# antes trocar pos (48988.0, 0.6161112914694777)
# 47603.0 0.5975633936956621
# adicionou
# antes trocar pos (47603.0, 0.5975633936956621)
# 29875.0 0.35343942491184965
# adicionou
# antes trocar pos (29875.0, 0.31846830257162817)
# 21107.0 0.2581496612083597
# adicionou
# antes trocar pos (21107.0, 0.23133246585936507)
# 34204.0 0.4185955356803011
# adicionou
# antes trocar pos (34204.0, 0.3359099203291925)
# 34456.0 0.4093673089120003
# adicionou
# antes trocar pos (34456.0, 0.317641977463952)
# 34047.0 0.43248451096932106
# adicionou
# antes trocar pos (34047.0, 0.4235062312079766)
# 34006.0 0.42907334308868167
# adicionou
# antes trocar pos (34006.0, 0.3674550184548376)
# 39231.0 0.457298355190633
# adicionou
# antes trocar pos (39231.0, 0.3335617032096609)
# 53582.0 0.6985649857212559
# adicionou
# antes trocar pos (53582.0, 0.6985649857212559)
# 51963.0 0.6658999676952679
# adicionou
# antes trocar pos (51963.0, 0.6534170200494946)
# 42916.0 0.5208038232288771
# adicionou
# antes trocar pos (42916.0, 0.4543567536799435)
# 36467.0 0.4509832787191445
# adicionou
# antes trocar pos (36467.0, 0.4019064065609961)
# 39374.0 0.49791595791362797
# adicionou
# antes trocar pos (39374.0, 0.4055542801558828)
# 39058.0 0.49480941125101713
# adicionou
# antes trocar pos (39058.0, 0.41527864270000475)
# 35598.0 0.44223701468014637
# adicionou
# antes trocar pos (35598.0, 0.2868595878641596)
# 38530.0 0.43239839798957497
# adicionou
# antes trocar pos (38530.0, 0.42049143921180954)
# 31713.0 0.4009488095735265
# adicionou
# antes trocar pos (31713.0, 0.38139267494672313)
# 39281.0 0.4707229152599998
# adicionou
# antes trocar pos (39281.0, 0.4251616519088677)
# 46875.0 0.6132811317118391
# adicionou
# antes trocar pos (46875.0, 0.6132811317118391)
# 45184.0 0.565408305341973
# adicionou
# antes trocar pos (45184.0, 0.565408305341973)
# 40108.0 0.5210473395926103
# adicionou
# antes trocar pos (40108.0, 0.5002261758849357)
# 45935.0 0.5589234743985468
# adicionou
# antes trocar pos (45935.0, 0.5133945731913128)
# 28425.0 0.3444816678594793
# adicionou
# antes trocar pos (28425.0, 0.32261710156115253)
# 44608.0 0.5686969553652195
# adicionou
# antes trocar pos (44608.0, 0.5686969553652195)
# 28967.0 0.35227002594123286
# adicionou
# antes trocar pos (28967.0, 0.30764094811915865)
# 28341.0 0.35238706286270355
# adicionou
# antes trocar pos (28341.0, 0.3293140016624087)
# 37953.0 0.44505909022569606
# adicionou
# antes trocar pos (37953.0, 0.42045512343482316)
# 28004.0 0.34756842561503914
# adicionou
# antes trocar pos (28004.0, 0.34756842561503914)
# 26297.0 0.30162045582609653
# adicionou
# antes trocar pos (26297.0, 0.26383464919329785)
# 57549.0
# thop/instances/eil51-thop/eil51_n147_bounded-strongly-corr_05_02.thop
# NODE_COORD_SECTION  (INDEX, X, Y):
#
# ITEMS SECTION    (INDEX, PROFIT, WEIGHT, ASSIGNED NODE NUMBER):
#
# 61891.0 0.7872196499341623
# adicionou
# antes trocar pos (61891.0, 0.7410466073559914)
# 53063.0 0.6618955004692145
# adicionou
# antes trocar pos (53063.0, 0.6073767675207431)
# 50606.0 0.5688311023747442
# adicionou
# antes trocar pos (50606.0, 0.5454408463726887)
# 39716.0 0.47224043397581905
# adicionou
# antes trocar pos (39716.0, 0.36234395183668844)
# 56272.0 0.7350909218927568
# adicionou
# antes trocar pos (56272.0, 0.6443908352077748)
# 50752.0 0.6094772426977925
# adicionou
# antes trocar pos (50752.0, 0.545564554197237)
# 49984.0 0.5842468266746418
# adicionou
# antes trocar pos (49984.0, 0.479966448140608)
# 42230.0 0.5251159344520427
# adicionou
# antes trocar pos (42230.0, 0.39290820194006143)
# 45116.0 0.49176011427470656
# adicionou
# antes trocar pos (45116.0, 0.4571456367968856)
# 68115.0 0.8531974351761465
# adicionou
# antes trocar pos (68115.0, 0.8531974351761465)
# 53196.0 0.6282445596525971
# adicionou
# antes trocar pos (53196.0, 0.5774090996035649)
# 53032.0 0.6613577905624143
# adicionou
# antes trocar pos (53032.0, 0.6467393586945055)
# 56815.0 0.7315239768707792
# adicionou
# antes trocar pos (56815.0, 0.5704350540194895)
# 45763.0 0.5878788575633127
# adicionou
# antes trocar pos (45763.0, 0.5600981280780818)
# 53161.0 0.6859403091015388
# adicionou
# antes trocar pos (53161.0, 0.6190757529921008)
# 47704.0 0.5803741077206507
# adicionou
# antes trocar pos (47704.0, 0.5590148033485779)
# 43028.0 0.5095854000909263
# adicionou
# antes trocar pos (43028.0, 0.3588979986888601)
# 42995.0 0.5075931769618515
# adicionou
# antes trocar pos (42995.0, 0.479769040360245)
# 46553.0 0.570857169990492
# adicionou
# antes trocar pos (46553.0, 0.32434452995438445)
# 69408.0 0.919315291669658
# adicionou
# antes trocar pos (69408.0, 0.8840049437482975)
# 59520.0 0.7156940253800156
# adicionou
# antes trocar pos (59520.0, 0.7156940253800156)
# 52798.0 0.611139948787461
# adicionou
# antes trocar pos (52798.0, 0.5907478544031483)
# 54898.0 0.7126203695738504
# adicionou
# antes trocar pos (54898.0, 0.5768539683096008)
# 46470.0 0.5104548521995957
# adicionou
# antes trocar pos (46470.0, 0.4613914471580632)
# 48723.0 0.6229393874087877
# adicionou
# antes trocar pos (48723.0, 0.4545137253837197)
# 53979.0 0.6725562837083279
# adicionou
# antes trocar pos (53979.0, 0.6327226685485018)
# 47150.0 0.6095570982685043
# adicionou
# antes trocar pos (47150.0, 0.45329920141470154)
# 46383.0 0.5729258558452418
# adicionou
# antes trocar pos (46383.0, 0.44021009863237387)
# 40383.0 0.5005151339414604
# adicionou
# antes trocar pos (40383.0, 0.47748122512696006)
# 43986.0 0.5589314263132805
# adicionou
# antes trocar pos (43986.0, 0.35489170124299685)
# 59709.0 0.774098210263252
# adicionou
# antes trocar pos (59709.0, 0.7634772285858955)
# 59225.0 0.7490404515382516
# adicionou
# antes trocar pos (59225.0, 0.7269035182998381)
# 43738.0 0.5771270568076662
# adicionou
# antes trocar pos (43738.0, 0.4806908864735049)
# 56138.0 0.7017210987606987
# adicionou
# antes trocar pos (56138.0, 0.7017210987606987)
# 48545.0 0.6172267661510733
# adicionou
# antes trocar pos (48545.0, 0.6035398466597633)
# 47441.0 0.5242230859084419
# adicionou
# antes trocar pos (47441.0, 0.44003287873469654)
# 36810.0 0.35025693898576843
# adicionou
# antes trocar pos (36810.0, 0.2357736041538147)
# 51149.0 0.6322208018209671
# adicionou
# antes trocar pos (51149.0, 0.6032592538458096)
# 41149.0 0.499410509723572
# adicionou
# antes trocar pos (41149.0, 0.37893048349740766)
# 62186.0 0.7828348758527515
# adicionou
# antes trocar pos (62186.0, 0.7603892826741575)
# 58623.0 0.7437511528850161
# adicionou
# antes trocar pos (58623.0, 0.7437511528850161)
# 43856.0 0.5412427984464583
# adicionou
# antes trocar pos (43856.0, 0.5070382637072882)
# 47999.0 0.6038769067664403
# adicionou
# antes trocar pos (47999.0, 0.4401415057379327)
# 42032.0 0.4991861860596058
# adicionou
# antes trocar pos (42032.0, 0.3544087875929505)
# 37808.0 0.46290664271140425
# adicionou
# antes trocar pos (37808.0, 0.3582232880840657)
# 51962.0 0.6426958086889898
# adicionou
# antes trocar pos (51962.0, 0.5159828489541133)
# 46378.0 0.4827071342961039
# adicionou
# antes trocar pos (46378.0, 0.46468470721906047)
# 49250.0 0.5997887274695355
# adicionou
# antes trocar pos (49250.0, 0.5113947861653815)
# 55262.0 0.7212870793623728
# adicionou
# antes trocar pos (55262.0, 0.5590573662052106)
# 59709.0 0.774098210263252
# adicionou
# antes trocar pos (59709.0, 0.7634772285858955)
# 51321.0 0.6593397931509827
# adicionou
# antes trocar pos (51321.0, 0.563507735120759)
# 35863.0 0.4402991790638786
# adicionou
# antes trocar pos (35863.0, 0.33598439411478165)
# 40970.0 0.502336665987022
# adicionou
# antes trocar pos (40970.0, 0.4806759815533029)
# 56252.0 0.674968734092103
# adicionou
# antes trocar pos (56252.0, 0.6266999521298443)
# 43026.0 0.5388482775334887
# adicionou
# antes trocar pos (43026.0, 0.4308796571268751)
# 47781.0 0.5538645674700359
# adicionou
# antes trocar pos (47781.0, 0.41346926772571063)
# 51778.0 0.6590403871792478
# adicionou
# antes trocar pos (51778.0, 0.6496642044583175)
# 48638.0 0.504048114684239
# adicionou
# antes trocar pos (48638.0, 0.4988685650748885)
# 39815.0 0.4473743733711491
# adicionou
# antes trocar pos (39815.0, 0.39212107593275225)
# 57286.0 0.7454539048504212
# adicionou
# antes trocar pos (57286.0, 0.7315206790057213)
# 43220.0 0.5427479673701008
# adicionou
# antes trocar pos (43220.0, 0.4962891032860043)
# 48985.0 0.5983091247306347
# adicionou
# antes trocar pos (48985.0, 0.5406768576071784)
# 42390.0 0.4832079917493835
# adicionou
# antes trocar pos (42390.0, 0.4215688024992407)
# 39967.0 0.4477997047684572
# adicionou
# antes trocar pos (39967.0, 0.33805244521689615)
# 48594.0 0.5929016230317851
# adicionou
# antes trocar pos (48594.0, 0.4708768029570111)
# 47513.0 0.5108862037153734
# adicionou
# antes trocar pos (47513.0, 0.3846811185209344)
# 48031.0 0.5779964977595815
# adicionou
# antes trocar pos (48031.0, 0.5415440534931888)
# 42213.0 0.5051295979291649
# adicionou
# antes trocar pos (42213.0, 0.4245039190463722)
# 34575.0 0.41808004765390544
# adicionou
# antes trocar pos (34575.0, 0.40680395855373624)
# 67461.0 0.7999272812264185
# adicionou
# antes trocar pos (67461.0, 0.7755851879202785)
# 61631.0 0.7453076020959283
# adicionou
# antes trocar pos (61631.0, 0.6962073195259542)
# 42632.0 0.5506418792896934
# adicionou
# antes trocar pos (42632.0, 0.48712346575371834)
# 51678.0 0.6635459998925145
# adicionou
# antes trocar pos (51678.0, 0.6344269044124194)
# 54567.0 0.6942656903819422
# adicionou
# antes trocar pos (54567.0, 0.6226618477953751)
# 42913.0 0.5327785357987815
# adicionou
# antes trocar pos (42913.0, 0.4104815731113706)
# 61342.0 0.7629086910035116
# adicionou
# antes trocar pos (61342.0, 0.6920902917141227)
# 47733.0 0.6061143615785877
# adicionou
# antes trocar pos (47733.0, 0.46566405884707207)
# 46346.0 0.5773723027515498
# adicionou
# antes trocar pos (46346.0, 0.5041812629809884)
# 59143.0 0.7680086275572161
# adicionou
# antes trocar pos (59143.0, 0.7376048728102882)
# 51063.0 0.6394408734815474
# adicionou
# antes trocar pos (51063.0, 0.5566049536224981)
# 56344.0 0.7355126546262455
# adicionou
# antes trocar pos (56344.0, 0.7228974297957043)
# 44434.0 0.547364090961068
# adicionou
# antes trocar pos (44434.0, 0.5015500217321847)
# 39884.0 0.48081794078014056
# adicionou
# antes trocar pos (39884.0, 0.421823347949305)
# 37201.0 0.4743834165422001
# adicionou
# antes trocar pos (37201.0, 0.44770951479070464)
# 45060.0 0.5606260791898446
# adicionou
# antes trocar pos (45060.0, 0.4331678963250138)
# 50098.0 0.5949524860044318
# adicionou
# antes trocar pos (50098.0, 0.5444722599421497)
# 47287.0 0.5965294401833297
# adicionou
# antes trocar pos (47287.0, 0.45081202314558594)
# 39066.0 0.4275550859929877
# adicionou
# antes trocar pos (39066.0, 0.29958959840500315)
# 53581.0 0.5553244829462454
# adicionou
# antes trocar pos (53581.0, 0.4018024898374244)
# 62643.0 0.8109305909806037
# adicionou
# antes trocar pos (62643.0, 0.7947362443068)
# 60695.0 0.7788772129920752
# adicionou
# antes trocar pos (60695.0, 0.7560891118967674)
# 48882.0 0.5799126595552827
# adicionou
# antes trocar pos (48882.0, 0.3642498245472416)
# 48483.0 0.5844701584963665
# adicionou
# antes trocar pos (48483.0, 0.52168887241996)
# 38938.0 0.426302679151497
# adicionou
# antes trocar pos (38938.0, 0.42124756223932136)
# 36176.0 0.4278917575582591
# adicionou
# antes trocar pos (36176.0, 0.35842937516186146)
# 42141.0 0.48028252361894613
# adicionou
# antes trocar pos (42141.0, 0.47697206229927613)
# 50232.0 0.6558977228116165
# adicionou
# antes trocar pos (50232.0, 0.4102154072502664)
# 48729.0 0.6104195297493836
# adicionou
# antes trocar pos (48729.0, 0.5980367613267973)
# 69408.0
# thop/instances/eil51-thop/eil51_n147_bounded-strongly-corr_05_03.thop
# NODE_COORD_SECTION  (INDEX, X, Y):
#
# ITEMS SECTION    (INDEX, PROFIT, WEIGHT, ASSIGNED NODE NUMBER):
#
# 70463.0 0.91651879491474
# adicionou
# antes trocar pos (70463.0, 0.91651879491474)
# 68962.0 0.8677181928624895
# adicionou
# antes trocar pos (68962.0, 0.81079882450641)
# 57836.0 0.6483633925223438
# adicionou
# antes trocar pos (57836.0, 0.591740209073358)
# 57191.0 0.7162171188672913
# adicionou
# antes trocar pos (57191.0, 0.5131808032468411)
# 59048.0 0.742366152726484
# adicionou
# antes trocar pos (59048.0, 0.5386991493400886)
# 46985.0 0.5655216659816099
# adicionou
# antes trocar pos (46985.0, 0.3638584839233776)
# 49937.0 0.47998541653081483
# adicionou
# antes trocar pos (49937.0, 0.4215524169190976)
# 47818.0 0.5365412854000705
# adicionou
# antes trocar pos (47818.0, 0.37624658736361827)
# 69881.0 0.9096432965521236
# adicionou
# antes trocar pos (69881.0, 0.8522184005642344)
# 71661.0 0.949037245272175
# adicionou
# antes trocar pos (71661.0, 0.949037245272175)
# 59764.0 0.7094808170283713
# adicionou
# antes trocar pos (59764.0, 0.6190036637674632)
# 48874.0 0.5480327468488537
# adicionou
# antes trocar pos (48874.0, 0.45356893569261475)
# 51592.0 0.6063244850916767
# adicionou
# antes trocar pos (51592.0, 0.5660376889019287)
# 46669.0 0.5852750480998256
# adicionou
# antes trocar pos (46669.0, 0.5306780647455623)
# 55583.0 0.6867436319559401
# adicionou
# antes trocar pos (55583.0, 0.4932447732591116)
# 55591.0 0.6897178861492178
# adicionou
# antes trocar pos (55591.0, 0.6225983810596507)
# 59066.0 0.763680865969278
# adicionou
# antes trocar pos (59066.0, 0.4919593357697222)
# 48855.0 0.6018029711186893
# adicionou
# antes trocar pos (48855.0, 0.3364726702849878)
# 68836.0 0.8994669190475559
# adicionou
# antes trocar pos (68836.0, 0.8994669190475559)
# 68182.0 0.8524382602622121
# adicionou
# antes trocar pos (68182.0, 0.8073677368223509)
# 59717.0 0.7632200476362523
# adicionou
# antes trocar pos (59717.0, 0.5901592414251199)
# 58607.0 0.7430288905026846
# adicionou
# antes trocar pos (58607.0, 0.7133936686109354)
# 53341.0 0.6450490080220596
# adicionou
# antes trocar pos (53341.0, 0.49158690605946725)
# 52890.0 0.6618283556658191
# adicionou
# antes trocar pos (52890.0, 0.5056862355402898)
# 58799.0 0.6293429057344602
# adicionou
# antes trocar pos (58799.0, 0.5466609411412713)
# 53600.0 0.49938918090567447
# adicionou
# antes trocar pos (53600.0, 0.3585464824406507)
# 69306.0 0.9018333605544498
# adicionou
# antes trocar pos (69306.0, 0.7899498497793479)
# 68970.0 0.8805732863339494
# adicionou
# antes trocar pos (68970.0, 0.8634654798547734)
# 68589.0 0.8696581378437394
# adicionou
# antes trocar pos (68589.0, 0.7491261056306233)
# 55844.0 0.7028970989145398
# adicionou
# antes trocar pos (55844.0, 0.5684729258653703)
# 55286.0 0.6749087575156041
# adicionou
# antes trocar pos (55286.0, 0.4693952540848028)
# 67682.0 0.8800439442281158
# adicionou
# antes trocar pos (67682.0, 0.870242876281012)
# 62299.0 0.7194576121224319
# adicionou
# antes trocar pos (62299.0, 0.6639414168153539)
# 62188.0 0.7319524277921966
# adicionou
# antes trocar pos (62188.0, 0.6557706328193651)
# 48099.0 0.5646622124038534
# adicionou
# antes trocar pos (48099.0, 0.4402330394481827)
# 55322.0 0.5706327759294685
# adicionou
# antes trocar pos (55322.0, 0.5019668798867197)
# 57893.0 0.7421403226193986
# adicionou
# antes trocar pos (57893.0, 0.6235813328609986)
# 49261.0 0.5967875499150207
# adicionou
# antes trocar pos (49261.0, 0.5249495906763207)
# 54993.0 0.6533044325964619
# adicionou
# antes trocar pos (54993.0, 0.49601329543308403)
# 49567.0 0.6318426363973918
# adicionou
# antes trocar pos (49567.0, 0.5452212458109029)
# 51501.0 0.5079686845519693
# adicionou
# antes trocar pos (51501.0, 0.45661810724839574)
# 70463.0 0.91651879491474
# adicionou
# antes trocar pos (70463.0, 0.91651879491474)
# 68336.0 0.8962925726744128
# adicionou
# antes trocar pos (68336.0, 0.8815530867791441)
# 60229.0 0.7756194372033478
# adicionou
# antes trocar pos (60229.0, 0.7276136588797368)
# 46879.0 0.48020398088232863
# adicionou
# antes trocar pos (46879.0, 0.38889083256620677)
# 51693.0 0.5391729222790634
# adicionou
# antes trocar pos (51693.0, 0.3390928763020297)
# 58048.0 0.6910059788334533
# adicionou
# antes trocar pos (58048.0, 0.547522162968283)
# 53543.0 0.6353580850763243
# adicionou
# antes trocar pos (53543.0, 0.5686596833289752)
# 52241.0 0.6803495534558879
# adicionou
# antes trocar pos (52241.0, 0.5662343726696096)
# 50383.0 0.6092494725817806
# adicionou
# antes trocar pos (50383.0, 0.506438325406985)
# 45705.0 0.4387081481716896
# adicionou
# antes trocar pos (45705.0, 0.36359308710330046)
# 72054.0 0.9012754421713008
# adicionou
# antes trocar pos (72054.0, 0.6977552256901328)
# 66108.0 0.8569620682212898
# adicionou
# antes trocar pos (66108.0, 0.8436667287805184)
# 59814.0 0.7971368290294729
# adicionou
# antes trocar pos (59814.0, 0.6609708010714059)
# 47883.0 0.5045565111076562
# adicionou
# antes trocar pos (47883.0, 0.33785739077217747)
# 53176.0 0.5918810173605245
# adicionou
# antes trocar pos (53176.0, 0.4508846845032659)
# 66696.0 0.8433903184684867
# adicionou
# antes trocar pos (66696.0, 0.7267685809451182)
# 54500.0 0.7029491042044012
# adicionou
# antes trocar pos (54500.0, 0.5130657886557394)
# 69306.0 0.9018333605544498
# adicionou
# antes trocar pos (69306.0, 0.7899498497793479)
# 66716.0 0.855870172773953
# adicionou
# antes trocar pos (66716.0, 0.6992628238557432)
# 67033.0 0.8150569137425736
# adicionou
# ...
# 57520.0 0.6550322256808873
# adicionou
# antes trocar pos (57520.0, 0.6332382399233645)
# 70528.0 0.9208300381304665
# adicionou
# antes trocar pos (70528.0, 0.8069741479143204)
# 65239.0 0.8487965795164655
# adicionou
# antes trocar pos (65239.0, 0.8462638483157944)
# 60890.0 0.6711293953331746
# adicionou
# antes trocar pos (60890.0, 0.5926113077251695)
# 60278.0 0.7350792886135944
# adicionou
# antes trocar pos (60278.0, 0.5414202239812111)
# 58918.0 0.7210222580211155
# adicionou
# antes trocar pos (58918.0, 0.6248619796705558)
# 55681.0 0.7088663058584461
# adicionou
# antes trocar pos (55681.0, 0.621313968115065)
# 50351.0 0.5646580790943064
# adicionou
# antes trocar pos (50351.0, 0.5100800001316638)
# 59176.0 0.681781073187848
# adicionou
# antes trocar pos (59176.0, 0.5710040501984504)
# 56017.0 0.6410401006282085
# adicionou
# antes trocar pos (56017.0, 0.5265156202675328)
# 72054.0
# thop/instances/eil51-thop/eil51_n147_bounded-strongly-corr_10_01.thop
# NODE_COORD_SECTION  (INDEX, X, Y):
#
# ITEMS SECTION    (INDEX, PROFIT, WEIGHT, ASSIGNED NODE NUMBER):
#
# 73790.0 0.48796251773336796
# adicionou
# antes trocar pos (73790.0, 0.4775448701892522)
# 74232.0 0.4942426589852305
# adicionou
# antes trocar pos (74232.0, 0.45669802418710187)
# 68091.0 0.44218717925187495
# adicionou
# antes trocar pos (68091.0, 0.4282320133506037)
# 58387.0 0.3837942313841084
# adicionou
# antes trocar pos (58387.0, 0.3798007477829708)
# 54440.0 0.3553088637917827
# adicionou
# antes trocar pos (54440.0, 0.29941219043740097)
# 47541.0 0.2947660434450571
# adicionou
# antes trocar pos (47541.0, 0.2451650501219893)
# 46756.0 0.2926434999129044
# adicionou
# antes trocar pos (46756.0, 0.2607417848213836)
# 47564.0 0.276603244654194
# adicionou
# antes trocar pos (47564.0, 0.22441790272831574)
# 50433.0 0.31858509151861897
# adicionou
# antes trocar pos (50433.0, 0.23223556633941733)
# 53933.0 0.34447559985136816
# adicionou
# antes trocar pos (53933.0, 0.30718024233318436)
# 37949.0 0.22140318681691773
# adicionou
# antes trocar pos (37949.0, 0.21968405296604887)
# 62752.0 0.4094061058217774
# adicionou
# antes trocar pos (62752.0, 0.40182672488980997)
# 63531.0 0.4091785064735227
# adicionou
# antes trocar pos (63531.0, 0.37441055480239355)
# 38990.0 0.24771108207413584
# adicionou
# antes trocar pos (38990.0, 0.2078355846518585)
# 41325.0 0.26078166938167
# adicionou
# antes trocar pos (41325.0, 0.19571436915718496)
# 49174.0 0.3209135601040457
# adicionou
# antes trocar pos (49174.0, 0.2792984205580563)
# 39746.0 0.245836292631646
# adicionou
# antes trocar pos (39746.0, 0.20430635138680575)
# 49273.0 0.3192376588337569
# adicionou
# antes trocar pos (49273.0, 0.2596249484708409)
# 48028.0 0.30539574220777155
# adicionou
# antes trocar pos (48028.0, 0.2602220146262886)
# 43825.0 0.28307045759151084
# adicionou
# antes trocar pos (43825.0, 0.19615239718380956)
# 68851.0 0.44388191629305424
# adicionou
# antes trocar pos (68851.0, 0.35323649827651094)
# 48948.0 0.3009704528081945
# adicionou
# antes trocar pos (48948.0, 0.2152859433259224)
# 71684.0 0.4675107954707296
# adicionou
# antes trocar pos (71684.0, 0.42978594018790695)
# 77382.0 0.5076024705389167
# adicionou
# antes trocar pos (77382.0, 0.5031621337225288)
# 66942.0 0.43931433457821295
# adicionou
# antes trocar pos (66942.0, 0.4146164606383078)
# 33557.0 0.21277654028989892
# adicionou
# antes trocar pos (33557.0, 0.1716216177662364)
# 51502.0 0.33555598621690813
# adicionou
# antes trocar pos (51502.0, 0.2851351727408351)
# 50908.0 0.3350622962658465
# adicionou
# antes trocar pos (50908.0, 0.2961618468409719)
# 47389.0 0.30348850806151495
# adicionou
# antes trocar pos (47389.0, 0.2857043741047747)
# 57160.0 0.3624876860891133
# adicionou
# antes trocar pos (57160.0, 0.2780281264463621)
# 38955.0 0.23582460399275224
# adicionou
# antes trocar pos (38955.0, 0.17839239516357078)
# 59467.0 0.3809163434364362
# adicionou
# antes trocar pos (59467.0, 0.36587825971105964)
# 72054.0 0.4619518739524105
# adicionou
# antes trocar pos (72054.0, 0.39176096300917373)
# 57972.0 0.3770210676986773
# adicionou
# antes trocar pos (57972.0, 0.3719700032485763)
# 43786.0 0.27422256039540843
# adicionou
# antes trocar pos (43786.0, 0.24320609284999745)
# 50891.0 0.3264525802182009
# adicionou
# antes trocar pos (50891.0, 0.2945991948823691)
# 55827.0 0.32923165126043974
# adicionou
# antes trocar pos (55827.0, 0.3046648992068749)
# 54824.0 0.3327561750680749
# adicionou
# antes trocar pos (54824.0, 0.23602272560772627)
# 40031.0 0.25910783135673415
# adicionou
# antes trocar pos (40031.0, 0.1620609873856837)
# 43561.0 0.2735081861600126
# adicionou
# antes trocar pos (43561.0, 0.21163387224171729)
# 38599.0 0.23178017824241465
# adicionou
# antes trocar pos (38599.0, 0.19022093619450614)
# 50513.0 0.31321581979372465
# adicionou
# antes trocar pos (50513.0, 0.272130515315118)
# 57706.0 0.3772000734630393
# adicionou
# antes trocar pos (57706.0, 0.3772000734630393)
# 61639.0 0.39659423836484
# adicionou
# antes trocar pos (61639.0, 0.36137731266745604)
# 43478.0 0.2796070487683043
# adicionou
# antes trocar pos (43478.0, 0.25081411086779176)
# 44323.0 0.2768057559925989
# adicionou
# antes trocar pos (44323.0, 0.21090062311982727)
# 53090.0 0.33228807453335324
# adicionou
# antes trocar pos (53090.0, 0.2869906750827137)
# 44550.0 0.28871588070566795
# adicionou
# antes trocar pos (44550.0, 0.22698431705423083)
# 50821.0 0.330079643348447
# adicionou
# antes trocar pos (50821.0, 0.25668493758390676)
# 56870.0 0.3618123550870243
# adicionou
# antes trocar pos (56870.0, 0.3039228319944303)
# 58344.0 0.35014425284893697
# adicionou
# antes trocar pos (58344.0, 0.30050939199688365)
# 47629.0 0.30631847875016693
# adicionou
# antes trocar pos (47629.0, 0.3043062285913865)
# 56501.0 0.33274335172658825
# adicionou
# antes trocar pos (56501.0, 0.2989593809829727)
# 80236.0 0.5267388785503796
# adicionou
# antes trocar pos (80236.0, 0.5242763242712623)
# 77604.0 0.4926555646291908
# adicionou
# antes trocar pos (77604.0, 0.4926555646291908)
# 77903.0 0.5160043111092325
# adicionou
# antes trocar pos (77903.0, 0.4908206495249572)
# 54993.0 0.3647578171181704
# adicionou
# antes trocar pos (54993.0, 0.3519739188144252)
# 55990.0 0.36658070343098403
# adicionou
# antes trocar pos (55990.0, 0.3577817193041258)
# 36028.0 0.22881474576160124
# adicionou
# antes trocar pos (36028.0, 0.22881474576160124)
# 48060.0 0.3035031426678219
# adicionou
# antes trocar pos (48060.0, 0.2622948674429603)
# 50562.0 0.3288897462797855
# adicionou
# antes trocar pos (50562.0, 0.26932042205883056)
# 55680.0 0.33855396712517516
# adicionou
# antes trocar pos (55680.0, 0.28699306046867085)
# 42902.0 0.2597556792572202
# adicionou
# antes trocar pos (42902.0, 0.1938348344023582)
# 42740.0 0.2798931408711688
# adicionou
# antes trocar pos (42740.0, 0.24690544866378653)
# 52501.0 0.33897515381007504
# adicionou
# antes trocar pos (52501.0, 0.2713231216679068)
# 65245.0 0.4175018646842931
# adicionou
# antes trocar pos (65245.0, 0.41082819277142335)
# 62812.0 0.3994744783455725
# adicionou
# antes trocar pos (62812.0, 0.3855531122721117)
# 44309.0 0.2810027501296659
# adicionou
# antes trocar pos (44309.0, 0.26322383696660157)
# 44389.0 0.2871631558524198
# adicionou
# antes trocar pos (44389.0, 0.28464445533646815)
# 45115.0 0.284226389159924
# adicionou
# antes trocar pos (45115.0, 0.24056074502932034)
# 49832.0 0.30617294898754
# adicionou
# antes trocar pos (49832.0, 0.2913084319900896)
# 37442.0 0.23524790862707678
# adicionou
# antes trocar pos (37442.0, 0.22222124450651223)
# 60611.0 0.39343011151381
# adicionou
# antes trocar pos (60611.0, 0.3445803689061551)
# 48695.0 0.3037661187169768
# adicionou
# antes trocar pos (48695.0, 0.21957153067848237)
# 47655.0 0.28613581148618167
# adicionou
# antes trocar pos (47655.0, 0.2502699036630688)
# 50257.0 0.318165084068274
# adicionou
# antes trocar pos (50257.0, 0.29915601452023716)
# 49173.0 0.2994730747280238
# adicionou
# antes trocar pos (49173.0, 0.2905648926476782)
# 61891.0 0.40164280001494795
# adicionou
# antes trocar pos (61891.0, 0.3793961479785098)
# 54712.0 0.34839877361620963
# adicionou
# antes trocar pos (54712.0, 0.33620738860529503)
# 45530.0 0.28823384013715253
# adicionou
# antes trocar pos (45530.0, 0.2361731313719177)
# 60297.0 0.3826983818445795
# adicionou
# antes trocar pos (60297.0, 0.33119484058099613)
# 48692.0 0.3086496566800889
# adicionou
# antes trocar pos (48692.0, 0.27747358333918615)
# 63501.0 0.3960066225972578
# adicionou
# antes trocar pos (63501.0, 0.34867139115545537)
# 50285.0 0.30602490147080064
# adicionou
# antes trocar pos (50285.0, 0.2673043540297212)
# 42170.0 0.25869099921048766
# adicionou
# antes trocar pos (42170.0, 0.2500567021378014)
# 45033.0 0.28497314683531805
# adicionou
# antes trocar pos (45033.0, 0.23376030376686513)
# 45794.0 0.2932691321971237
# adicionou
# antes trocar pos (45794.0, 0.20049880488765454)
# 72140.0 0.46691243013453493
# adicionou
# antes trocar pos (72140.0, 0.45206827850083275)
# 59085.0 0.3861430098855048
# adicionou
# antes trocar pos (59085.0, 0.3759549918531592)
# 48959.0 0.311293951274637
# adicionou
# antes trocar pos (48959.0, 0.28654364943010613)
# 36517.0 0.229651595492047
# adicionou
# antes trocar pos (36517.0, 0.20357829282018325)
# 49314.0 0.30842088686967
# adicionou
# antes trocar pos (49314.0, 0.2489441252654001)
# 44701.0 0.29243712390918536
# adicionou
# antes trocar pos (44701.0, 0.20912403823974762)
# 44001.0 0.28199773732541406
# adicionou
# antes trocar pos (44001.0, 0.2639451618110899)
# 38433.0 0.24106787990869846
# adicionou
# antes trocar pos (38433.0, 0.17607952347009231)
# 41328.0 0.2621409874453954
# adicionou
# antes trocar pos (41328.0, 0.21444092488057181)
# 42821.0 0.2689805099387455
# adicionou
# antes trocar pos (42821.0, 0.2000442614916236)
# 65087.0 0.4241156131491192
# adicionou
# antes trocar pos (65087.0, 0.4145390311700311)
# 62285.0 0.40295735399159854
# adicionou
# antes trocar pos (62285.0, 0.3777470109945108)
# 54401.0 0.34959446767181657
# adicionou
# antes trocar pos (54401.0, 0.34959446767181657)
# 46951.0 0.30461259353742676
# adicionou
# antes trocar pos (46951.0, 0.30241917406874874)
# 60825.0 0.39545397573849683
# adicionou
# antes trocar pos (60825.0, 0.30602798705481604)
# 47938.0 0.29518188592238703
# adicionou
# antes trocar pos (47938.0, 0.1987785072689949)
# 37229.0 0.2381097031817919
# adicionou
# antes trocar pos (37229.0, 0.1903631727058283)
# 44079.0 0.265772124629615
# adicionou
# antes trocar pos (44079.0, 0.25532242864285465)
# 53450.0 0.3485650234739427
# adicionou
# antes trocar pos (53450.0, 0.3130858616917289)
# 38144.0 0.2387354217598717
# adicionou
# antes trocar pos (38144.0, 0.21030482811992177)
# 48833.0 0.3139793077843318
# adicionou
# antes trocar pos (48833.0, 0.29132804207813556)
# 44692.0 0.2853345463873808
# adicionou
# antes trocar pos (44692.0, 0.20799920200410582)
# 80236.0
# thop/instances/eil51-thop/eil51_n147_bounded-strongly-corr_10_02.thop
# NODE_COORD_SECTION  (INDEX, X, Y):
#
# ITEMS SECTION    (INDEX, PROFIT, WEIGHT, ASSIGNED NODE NUMBER):
#
# 97676.0 0.5611602052768061
# adicionou
# antes trocar pos (97676.0, 0.5489989860939526)
# 96381.0 0.6054793298622168
# adicionou
# antes trocar pos (96381.0, 0.529098334428411)
# 95119.0 0.6313581075063611
# adicionou
# antes trocar pos (95119.0, 0.527592610146715)
# 77262.0 0.5066551689687756
# adicionou
# antes trocar pos (77262.0, 0.4462027904421204)
# 70135.0 0.45971716871026264
# adicionou
# antes trocar pos (70135.0, 0.36898555141031353)
# 75752.0 0.4926024952729777
# adicionou
# antes trocar pos (75752.0, 0.37432068203090013)
# 96569.0 0.6338236852172401
# adicionou
# antes trocar pos (96569.0, 0.5922267659897179)
# 96683.0 0.6238024780107874
# adicionou
# antes trocar pos (96683.0, 0.5863457032702624)
# 90461.0 0.5855480415621713
# adicionou
# antes trocar pos (90461.0, 0.5784691618708978)
# 79649.0 0.5249573165791293
# adicionou
# antes trocar pos (79649.0, 0.45268271193309495)
# 86451.0 0.5623024193349531
# adicionou
# antes trocar pos (86451.0, 0.43678018924162787)
# 74766.0 0.4901540479715166
# adicionou
# antes trocar pos (74766.0, 0.3678129379006057)
# 69580.0 0.45837009908638837
# adicionou
# antes trocar pos (69580.0, 0.3712763653779999)
# 63225.0 0.4030488171937686
# adicionou
# antes trocar pos (63225.0, 0.298456951485609)
# 100346.0 0.6575941859036399
# adicionou
# antes trocar pos (100346.0, 0.6392776200338119)
# 92833.0 0.5891230707419568
# adicionou
# antes trocar pos (92833.0, 0.5690654591516843)
# 85484.0 0.5421283471572563
# adicionou
# antes trocar pos (85484.0, 0.4866880576681687)
# 64748.0 0.42334977125332235
# adicionou
# antes trocar pos (64748.0, 0.40308089137958397)
# 73932.0 0.462610072072252
# adicionou
# antes trocar pos (73932.0, 0.32215618769016613)
# 61053.0 0.38968611546952553
# adicionou
# antes trocar pos (61053.0, 0.308206721003188)
# 100779.0 0.6564401678125321
# adicionou
# antes trocar pos (100779.0, 0.6378710707996658)
# 96080.0 0.6319247992040763
# adicionou
# antes trocar pos (96080.0, 0.5707003417880088)
# 89401.0 0.585270599455081
# adicionou
# antes trocar pos (89401.0, 0.5561165183872522)
# 71310.0 0.45783947439165323
# adicionou
# antes trocar pos (71310.0, 0.3909298519259236)
# 63344.0 0.4214002578433964
# adicionou
# antes trocar pos (63344.0, 0.27228268201064454)
# 60848.0 0.3913519897711324
# adicionou
# antes trocar pos (60848.0, 0.284774156228139)
# 98832.0 0.643555659393093
# adicionou
# antes trocar pos (98832.0, 0.6149177669786127)
# 95566.0 0.60192630836396
# adicionou
# antes trocar pos (95566.0, 0.5349006722408005)
# 95133.0 0.607185591706208
# adicionou
# antes trocar pos (95133.0, 0.5490951138173855)
# 87739.0 0.5724200725119059
# adicionou
# antes trocar pos (87739.0, 0.5699132196126031)
# 79905.0 0.5265186067537303
# adicionou
# antes trocar pos (79905.0, 0.47841548924780114)
# 77466.0 0.5117662435564481
# adicionou
# antes trocar pos (77466.0, 0.40240006648987475)
# 98808.0 0.647462614469499
# adicionou
# antes trocar pos (98808.0, 0.5915909582931208)
# 93221.0 0.5930929771281589
# adicionou
# antes trocar pos (93221.0, 0.5289490257048086)
# 95685.0 0.6131192827381662
# adicionou
# antes trocar pos (95685.0, 0.4951367129280554)
# 84671.0 0.5582756498600279
# adicionou
# antes trocar pos (84671.0, 0.5295328950795337)
# 67607.0 0.4420788507290643
# adicionou
# antes trocar pos (67607.0, 0.3206488161303686)
# 71328.0 0.4567685299994674
# adicionou
# antes trocar pos (71328.0, 0.31227769765858204)
# 98391.0 0.6480025431761492
# adicionou
# antes trocar pos (98391.0, 0.6270368521301374)
# 99116.0 0.6552864786814765
# adicionou
# antes trocar pos (99116.0, 0.5667980015782763)
# 96677.0 0.6330547167829185
# adicionou
# antes trocar pos (96677.0, 0.5947161284919352)
# 83493.0 0.5494535987190595
# adicionou
# antes trocar pos (83493.0, 0.4678736882324768)
# 70075.0 0.46917576576420195
# adicionou
# antes trocar pos (70075.0, 0.3510127685834172)
# 55155.0 0.3466246528502665
# adicionou
# antes trocar pos (55155.0, 0.214296942913659)
# 64872.0 0.41347548731242506
# adicionou
# antes trocar pos (64872.0, 0.3411062255806915)
# 97969.0 0.547334807634642
# adicionou
# antes trocar pos (97969.0, 0.5351564582529927)
# 91676.0 0.6014376989623998
# adicionou
# antes trocar pos (91676.0, 0.5635639391279291)
# 90885.0 0.589391837681092
# adicionou
# antes trocar pos (90885.0, 0.5520212943635437)
# 85658.0 0.5332503268009648
# adicionou
# antes trocar pos (85658.0, 0.4757684440183118)
# 84524.0 0.553688263462478
# adicionou
# antes trocar pos (84524.0, 0.48080877058252564)
# 76281.0 0.518355102676082
# adicionou
# antes trocar pos (76281.0, 0.42154941028331383)
# 85105.0 0.5606062198290106
# adicionou
# antes trocar pos (85105.0, 0.4643954618223225)
# 60207.0 0.38488807621495297
# adicionou
# antes trocar pos (60207.0, 0.34381374107605567)
# 102518.0 0.6716340927688778
# adicionou
# antes trocar pos (102518.0, 0.6363316106320563)
# 98406.0 0.6281273083968599
# adicionou
# antes trocar pos (98406.0, 0.6024138355926021)
# 85965.0 0.5646494693983141
# adicionou
# antes trocar pos (85965.0, 0.4712209455528327)
# 63038.0 0.4108668933156905
# adicionou
# antes trocar pos (63038.0, 0.36897447444844705)
# 78730.0 0.5221538610816524
# adicionou
# antes trocar pos (78730.0, 0.4468878394930707)
# 101893.0 0.6702072652607132
# adicionou
# antes trocar pos (101893.0, 0.6511133409782514)
# 100115.0 0.6468564529070315
# adicionou
# antes trocar pos (100115.0, 0.6125982203752359)
# 92525.0 0.6082337178418923
# adicionou
# antes trocar pos (92525.0, 0.5154585970190849)
# 87604.0 0.5589893270699914
# adicionou
# antes trocar pos (87604.0, 0.5140737012802303)
# 79644.0 0.5184818247889648
# adicionou
# antes trocar pos (79644.0, 0.33418317868960845)
# 75918.0 0.49906742427538386
# adicionou
# antes trocar pos (75918.0, 0.411090467140823)
# 67417.0 0.4402167193811022
# adicionou
# antes trocar pos (67417.0, 0.33210102606429365)
# 102518.0
# thop/instances/eil51-thop/eil51_n147_bounded-strongly-corr_10_03.thop

# %%
# Out:
# 3845995.0

# %%
for numero in resultados:
    print(int(numero))

# %%
solucaoFinal(rotaInicial, itensIniciais.copy(), matrizAdjacencia.copy(), itens.copy(), minS, maxS, (maxS-minS)/cap, maxT, cap)
# Out:
# 3779866.0

# %%
solucoes
# Out:
# [4006283.0,
#  3736488.0,
#  3748008.0,
#  3616276.0,
#  3741260.0,
#  3713284.0,
#  3648899.0,
#  3757572.0,
#  3740811.0,
#  3745773.0,
#  3741798.0,
#  3949885.0,
#  3748512.0,
#  4059758.0,
#  3752222.0,
#  3678375.0,
#  3731481.0,
#  3752867.0,
#  3750074.0,
#  3982440.0,
#  4146254.0,
#  3783205.0,
#  3779866.0]
