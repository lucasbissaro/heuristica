# %%
import math
import copy
def solucaoFinal(vRota, vItens, matriz, itens, vMin, vMax, v, maxTime, w):
    vRota = [0] + vRota + [len(matriz)-1]
    peso = 0
    valor=0
    itensCid=[]
    for x in matriz:
        itensCid.append([])
    for x in vItens:        
        #print(x)
        itensCid[int(itens[x][3])].append(itens[x])
        peso += itens[x][2]
        valor += itens[x][1]
    
    t = 0
    pesoAtual = 0
    for index, x in enumerate(vRota):
        #print(index,x , len(vRota))
        if(index < len(vRota)-2):
            for y in itensCid[x]:
                #print('cidade', x-1, 'peso', pesoAtual)
                pesoAtual +=y[2]
            #print(matriz[x-1][vRota[index+1]-1], vMax , v*pesoAtual, vMin)
            t += matriz[x][vRota[index+1]]/max(vMax - v*pesoAtual, vMin)
    #print('tempo', t,maxTime, pesoAtual, w)
    #print(t,maxTime , peso,w)
    if(t<=maxTime and pesoAtual<=w):
        return valor
    else:
        return -1
    return 0

def dist(a, b):
    #print(a)
    #print(b)
    t = math.sqrt((a[1]-b[1])*(a[1]-b[1])+(a[2]-b[2])*(a[2]-b[2]))
    if int(t)==t:
        n = int(t)
    else:
        n = int(t)+1
    return n

def solucao(vRota, cidadeItens, matriz):
    vRota = [0] + vRota + [len(matriz)-1]
    peso = 0
    valor=0
    v = (maxSpeed - minSpeed)/capacity
    t = 0
    pesoAtual = 0
    for index, x in enumerate(vRota):
        #print(index,x , len(vRota))
        if(index < len(vRota)-2):
            valor+=cidadeItens[x]['valor']    
            pesoAtual +=cidadeItens[x]['peso']            
            t += matriz[x][vRota[index+1]]/max(maxSpeed - v*pesoAtual, minSpeed)
    if(t<=maxTime and pesoAtual<=capacity):
        return valor
    else:
        return -1
    return 0


def proximaCidade(matriz, dadosCidade, cidadeAtual, cidadeVisitada):
    maxi = -1
    ind = -1
    for index, x in enumerate(dadosCidade):
        if  matriz[cidadeAtual][index]==0 and cidadeAtual!=index:
            print(cidadeAtual, index, matriz[cidadeAtual][index])
        if (cidadeAtual!=index and maxi<(x/matriz[cidadeAtual][index]) and not cidadeVisitada[index]):            
            maxi = x/matriz[cidadeAtual][index]
            ind = index            
            
    return ind

def adicionaMaximoItens(rota, cidadeItens, cidadeAtual, itens, matriz, todosItens):
    rotaCopia = copy.deepcopy(rota)
    rotaCopia.append(cidadeAtual)
    for x in itens:
        cidadeItens[cidadeAtual]['peso']+=x[3]        
        cidadeItens[cidadeAtual]['valor']+=x[2]        
        cidadeItens[cidadeAtual]['qtdItens']+=1
        todosItens.append(x[0])
        
        result = solucao(rotaCopia, cidadeItens, matriz)
        #print(rotaCopia, cidadeItens[cidadeAtual])
        if result==-1:            
            cidadeItens[cidadeAtual]['peso']-=x[3]
            cidadeItens[cidadeAtual]['valor']-=x[2]
            cidadeItens[cidadeAtual]['qtdItens']-=1
            todosItens.remove(x[0])
            break
        else:
            if(cidadeAtual not in rota):
                rota.append(cidadeAtual)
            
    return

# %%
pontos = []
itens = []

with open('thop/instances/dsj1000-thop/dsj1000_n9980_uncorr-similar-weights_10_03.thop', 'r') as file:    
    name = file.readline().strip().replace(' ','').split(':')[1]    
    knapsack = file.readline().strip().replace(' ','').split(':')[1]    
    dimension = int(file.readline().strip().replace(' ','').split(':')[1])
    nItens = int(file.readline().strip().replace(' ','').split(':')[1])
    capacity = int(file.readline().strip().replace(' ','').split(':')[1])
    maxTime = int(file.readline().strip().replace(' ','').split(':')[1])
    minSpeed = float(file.readline().strip().replace(' ','').split(':')[1])
    maxSpeed = float(file.readline().strip().replace(' ','').split(':')[1])
    edgeType = file.readline().strip().replace(' ','').split(':')[1]
    pontosSection = True
    
    for x in file:
        if 'NODE_COORD_SECTION' in x: 
            print(x)
        elif 'ITEMS SECTION' in x: 
            pontosSection = False
            print(x)
        else:
            if(pontosSection):
                pontos.append([float(i) for i in x.split()])
            else:                
                itens.append([float(i) if index!=0 and index!=3 else int(i)-1 for index, i in enumerate(x.split())]+[float(x.split()[1])/float(x.split()[2])]+[False])
                
#print(pontos)
#print(itens)


    
matrizAdjacencia = []
vetorCidadeProxima = {}
itensCidade=[]
dadosCidade = []
cidadeVisitada = []

for x in pontos:    
    itensCidade.append([])      
    dadosCidade.append(0) 
    cidadeVisitada.append(False)
    aux = []
    menor = 100000000000
    for y in pontos:
        d = dist(x,y)
        if(d<menor):
            menor=d
            ponto = y
        aux.append(d)
        
    vetorCidadeProxima[x[0]]=ponto[0]
    matrizAdjacencia.append(aux)

for x in itens:
    itensCidade[int(x[3])].append(x)
    dadosCidade[int(x[3])]+=x[4]
itensOrdenados = []
#print(itensCidade)

for index, x in enumerate(itensCidade):
    itensCidade[index]= sorted(x, key=lambda y: y[5], reverse=True)
    #print(itensOrdenados[index])
#for x in itensOrdenados:
    #print (x)
# Out:
# NODE_COORD_SECTION  (INDEX, X, Y):
#
# ITEMS SECTION    (INDEX, PROFIT, WEIGHT, ASSIGNED NODE NUMBER):

# %%
import numpy as np
minS = minSpeed
maxS = maxSpeed
cap = capacity
maxT = maxTime
todosItens = []  

cidadeVisitada[0]=True
cidadeVisitada[len(cidadeVisitada)-1]=True

cidadeItens=[]
for x in range(len(matrizAdjacencia)):
    cidadeItens.append(copy.deepcopy({'peso':0, 'valor':0, 'qtdItens':0}))
    
    
rota = []
while(len(rota)==0):
    cidadeInicial = np.random.randint(1, len(pontos)-1)
    #rota.append(cidadeInicial)
    cidadeAtual = cidadeInicial
    cidadeVisitada[cidadeInicial]=True
    
    
    adicionaMaximoItens(rota, cidadeItens, cidadeInicial, itensCidade[cidadeAtual], matrizAdjacencia, todosItens)
print('saiu')
print('sol', solucaoFinal(rota, todosItens.copy(), matrizAdjacencia.copy(), itens.copy(), minS, maxS, (maxS-minS)/cap, maxT, cap))
#cidadeAtual = cidadeInicial
for x in range(len(matrizAdjacencia)):  
    cidadeProxima = proximaCidade(matrizAdjacencia, dadosCidade, cidadeAtual, cidadeVisitada)
    print(cidadeProxima)
    cidadeVisitada[cidadeProxima]=True    
    if(cidadeProxima ==-1):
        continue
    adicionaMaximoItens(rota, cidadeItens, cidadeProxima, itensCidade[cidadeAtual], matrizAdjacencia, todosItens)
    cidadeAtual = cidadeProxima

    
soma = 0
for x in cidadeItens:
    soma += x['valor']
print(rota, todosItens, soma)
# Out:
# saiu
# sol 5411.0
# 13
# 484
# 202
# 610
# 855
# 167
# 777
# 529
# 732
# 307
# 398
# 16
# 848
# 480
# 224
# 407
# 718
# 9
# 353
# 159
# 938
# 983
# 736
# 832
# 638
# 128
# 428
# 871
# 215
# 489
# 294
# 68
# 112
# 801
# 422
# 765
# 423
# 234
# 341
# 517
# 305
# 767
# 193
# 711
# 944
# 684
# 74
# 476
# 300
# 160
# 263
# 596
# 145
# 81
# 778
# 782
# 213
# 852
# 956
# 672
# 706
# 793
# 972
# 221
# 971
# 962
# 264
# 37
# 231
# 522
# 637
# 582
# 59
# 435
# 130
# 577
# 100
# 453
# 90
# 14
# 425
# 806
# 809
# 697
# 696
# 519
# 122
# 80
# 318
# 833
# 7
# 26
# 500
# 283
# 445
# 897
# 535
# 564
# 334
# 770
# 514
# 223
# 597
# 644
# 345
# 712
# 763
# 392
# 176
# 36
# 547
# 25
# 783
# 303
# 666
# 545
# 380
# 980
# 381
# 205
# 491
# 156
# 406
# 47
# 948
# 187
# 791
# 606
# 959
# 626
# 276
# 5
# 850
# 515
# 803
# 573
# 369
# 475
# 271
# 815
# 467
# 170
# 34
# 155
# 949
# 317
# 790
# 376
# 474
# 364
# 488
# 721
# 844
# 900
# 366
# 953
# 342
# 473
# 322
# 87
# 781
# 314
# 804
# 753
# 186
# 734
# 940
# 807
# 704
# 302
# 260
# 88
# 501
# 463
# 444
# 659
# 908
# 403
# 901
# 23
# 388
# 512
# 990
# 822
# 909
# 439
# 813
# 325
# 120
# 150
# 143
# 914
# 982
# 636
# 617
# 933
# 955
# 690
# 401
# 708
# 888
# 886
# 332
# 675
# 729
# 902
# 568
# 1
# 630
# 2
# 327
# 817
# 85
# 889
# 64
# 730
# 469
# 876
# 722
# 238
# 490
# 505
# 452
# 172
# 356
# 716
# 486
# 315
# 333
# 288
# 18
# 250
# 337
# 745
# 147
# 393
# 984
# 373
# 709
# 598
# 682
# 343
# 3
# 232
# 910
# 926
# 880
# 536
# 553
# 188
# 21
# 472
# 197
# -1
# -1
# -1
# [230, 13, 484, 202, 610, 855, 167, 777, 529, 732, 307, 398, 16, 848, 480, 224, 407, 718, 9, 353, 159, 938, 983, 736, 832, 638, 128, 428, 871, 215, 489, 294, 68, 112, 801, 422, 765, 423, 234, 341, 517, 305, 767, 193, 711, 944, 684, 74, 476, 300, 160, 263, 596, 145, 81, 778, 782, 213, 852, 956, 672, 706, 793, 972, 221, 971, 962, 264, 37, 231, 522, 637, 582, 59, 435, 130, 577, 100, 453, 90, 14, 425, 806, 809, 697, 696, 519, 122, 80, 318, 833, 7, 26, 500, 283, 445, 897, 535, 564, 334, 770, 514, 223, 597, 644, 345, 712, 763, 392, 176, 36, 547, 25, 783, 303, 666, 545, 380, 980, 381, 205, 491, 156, 406, 47, 948, 187, 791, 606, 959, 626, 276, 107, 542, 917, 945, 551, 741, 890, 94, 190, 860, 352, 351, 229, 595, 310, 865, 579, 585, 794, 222, 431, 429, 214, 449, 275, 131, 811, 738, 146, 55, 92, 464, 245, 674, 104, 646, 127, 563, 362, 912, 764, 705, 960, 506, 894, 842, 819, 667, 312, 297, 784, 200, 360, 720, 412, 931, 669, 217, 615, 436, 836, 974, 927, 174, 32, 358, 455, 277, 38, 266, 789, 211, 12, 872, 760, 6, 629, 800, 699, 589, 456, 752, 868, 751, 273, 524, 572, 409, 481, 588, 621, 866, 62, 968, 847, 102, 869, 368, 925, 411, 495, 662, 450, 282, 905, 216, 904, 645, 22, 988, 71, 426, 203, 924, 157, 592, 492, 485, 534, 843, 594, 348, 280, 920, 27, 477, 604, 839, 110, 618, 555, 578, 225, 148, 820, 854, 390, 755, 46, 884, 591, 787, 471, 114, 907, 399, 154, 427, 867, 113, 694, 939, 256, 268, 50, 818, 973, 795, 710, 655, 686, 212, 82, 742, 903, 611, 493, 856, 31, 554, 258, 824, 891, 829, 537, 828, 179, 929, 298, 952, 746, 144, 531, 42, 689, 121, 498, 75, 311, 465, 509, 199, 853, 48, 566, 703, 