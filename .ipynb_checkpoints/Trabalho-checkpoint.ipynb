# %%
#adicionar formas - pegar o da cidade mais proxima de todas as cidades ja na solução

#pegar todas cidades mais proximas e pegar um elemento aleatorio de cada cidade

#retirar cidades longe demais das outras

import math
#import random as random

def ordenaItens(itens, chance):
    if chance==0:
        vec = [sorted(itens, key=lambda y: y[4], reverse=True)]
    elif chance==1:
        vec = [sorted(itens, key=lambda y: y[1], reverse=True)]
    elif chance==2:
        vec = [sorted(itens, key=lambda y: y[2], reverse=False)]
    return vec

def dist(a, b):
    #print(a)
    #print(b)
    t = math.sqrt((a[1]-b[1])*(a[1]-b[1])+(a[2]-b[2])*(a[2]-b[2]))
    if int(t)==t:
        n = int(t)
    else:
        n = int(t)+1
    return n


def solucao(vRota, vItens, matriz, itens, vMin, vMax, v, maxTime, w):
    vRota = [0] + vRota + [len(matriz)-1]
    peso = 0
    valor=0
    itensCid=[]
    for x in matriz:
        itensCid.append([])
    for x in vItens:        
        #print(x)
        itensCid[int(itens[x][3])].append(itens[x])
        peso += itens[x][2]
        valor += itens[x][1]
    
    t = 0
    pesoAtual = 0
    for index, x in enumerate(vRota):
        #print(index,x , len(vRota))
        if(index < len(vRota)-2):
            for y in itensCid[x]:
                #print('cidade', x-1, 'peso', pesoAtual)
                pesoAtual +=y[2]
            #print(matriz[x-1][vRota[index+1]-1], vMax , v*pesoAtual, vMin)
            t += matriz[x][vRota[index+1]]/max(vMax - v*pesoAtual, vMin)
    #print('tempo', t,maxTime, peso, w)
    if(t<=maxTime and peso<=w):
        return [valor, t]
    else:
        return [-1, t]
    return [0,t]
     
def ordenar(ordemCidades, cidadesSelecionadas):
    cidades = []
    for x in ordemCidades:
        if x in cidadesSelecionadas:
            cidades.append(x)
            
    return cidades
        
def selecionaItens(ordemCidade, itens, itensUsados, itensCidade, cidadesSelecionadas, vetorCidadeProxima, cidadesAntigas):
    cidade = []
    nFormas = 28
    formas = list(range(nFormas))
    #forma = np.random.randint(3)
    itensSelecionados = []
    t=400
    vezes = 0
    vai = True
    
    
    t = max(5, t-50)
    a = math.pow(2.71,(-40/t))
    p = [a if i<((nFormas)/4) else a if i>=((nFormas)/4) and i<((2*nFormas)/4) else a*2 if i>=((2*nFormas)/4) and i<((3*nFormas)/4) else 1-a for i in formas]
    forma = np.random.choice(formas,1)[0]
    
    vezes+=1
    #for x itens:
    itensRecompensa=ordenaItens(itens,0)
    itensValor=ordenaItens(itens,1)
    itensPeso=ordenaItens(itens,2)        
    while(formas!= []):
        
        t = max(10, t-50)

        '''
        if vai:
            vai=False
            a=1-a
        else:
            vai=True
        '''
        #print(sum(p))
        #print([i/sum(p) for i in p])
        #print('forma:', forma)
        indexItem = formaItem(itens,itensUsados, forma, itensSelecionados, cidadesSelecionadas, ordemCidade, itensCidade, vetorCidadeProxima, cidadesAntigas,-1,itensRecompensa, itensValor, itensPeso)
        
        vezes+=1
        
        if(indexItem!=-1):
            
            itensSelecionados.append(indexItem) 
            
            chance = np.random.randint(3)
            if chance==0:
                vec = [i for i in sorted(itensCidade[int(itens[indexItem][3])], key=lambda y: y[4], reverse=True)]
            elif chance==1:
                vec = [i for i in sorted(itensCidade[int(itens[indexItem][3])], key=lambda y: y[1], reverse=True)]
            elif chance==2:
                vec = [i for i in sorted(itensCidade[int(itens[indexItem][3])], key=lambda y: y[2], reverse=False)]
            
            
            for i in vec:            
                #print(itens[indexItem][3], itens[int(i[0])][3])
                if np.random.randint(2)>0:
                    if(formaItem(itens, itensUsados, 100, itensSelecionados, cidadesSelecionadas, ordemCidade, itensCidade, vetorCidadeProxima, cidadesAntigas,i[0])!=-1):
                        #print(int(i[3]), itens[indexItem][3])
                        itensSelecionados.append(int(i[0]))
                    
                else:
                    break
              
                    
            formas = formas + [i for i in range(nFormas) if i>=((3*nFormas)/4) and i not in formas]
            #formas = list(range(nFormas))
            #formas = list(range(nFormas))
            #print('resultado: ', cidadesSelecionadas, itensSelecionados)
            if(vezes==1 and len(formas)>0):
                a = math.pow(2.71,(-40/t))
                p = [a if i<((nFormas)/4) else a if i>=((nFormas)/4) and i<((2*nFormas)/4) else a*2 if i>=((2*nFormas)/4) and i<((3*nFormas)/4) else 1-a for i in formas]
                forma = np.random.choice(formas,1, p=[i/sum(p) for i in p])[0]
                vezes=0
        else:
            formas.remove(forma)
            if len(formas)>0:
                a = math.pow(2.71,(-40/t))
                p = [a if i<((nFormas)/4) else a if i>=((nFormas)/4) and i<((2*nFormas)/4) else a*2 if i>=((2*nFormas)/4) and i<((3*nFormas)/4) else 1-a for i in formas]
                forma = np.random.choice(formas,1, p=[i/sum(p) for i in p])[0]
                vezes=0
    #for i in cidadesSelecionadas:
        
    return itensSelecionados
            

    
def formaItem(itens, itensUsados, forma, itensSelecionados,  cidadesSelecionadas, ordemCidade, itensCidade, vetorCidadeProxima, cidadesAntigas, indexItem, itensRecompensa=[], itensValor=[], itensPeso=[]):
    #criar metodos para variar entre pegar os melhores custos em novas cidades,
    #e metodos para pegar melhores custos nas cidades da rota
    maxi = -1
    mini = 10000000000000000
    indice = -1
    num=0
    

    if len(cidadesSelecionadas)==0:
        forma%=7
    
    else:
        if(forma<4):
            return -1
    
    #qualquer item
    if forma==num:#pega melhor custo beneficio dos itens disponiveis
        for index, x in enumerate(itensRecompensa):
            if(not x[5]):
                indice = x[0]
                break
    num+=1
    
    if forma==num: #maior recompensa
        for index, x in enumerate(itensPeso):
            if(not x[5]):
                indice = x[0]
                break
    num+=1
        
    if forma==num:#menor peso
        for index, x in enumerate(itensValor):
            if(not x[5]):
                indice = x[0]
                break
    num+=1
    if forma==num:#aleatorio
        aux = []
        for index, x in enumerate(itens):
            if( not x[5]):
                aux.append(index)
        if(len(aux)>0):
            indice = np.random.choice(aux,1)[0]
    num+=1
    
    
    if forma==num:#cidade com mais itens disponiveis, pega o melhor custo beneficio
        aux = []
        maxi=-1
        maxBene = -1
        for index, x in enumerate(itensCidade):
            cont=0
            
            ind2=-1
            for y in x:
                if( not y[5]):
                    if maxBene < y[4]:
                        maxBene = y[4]
                        ind2=int(y[0])
                cont+=1
            if cont>maxi and ind2!=-1:
                maxi=cont
                ind=index
                indice=ind2
    num+=1
    if forma==num:#cidade com mais itens disponiveis, pega o de menor peso
        aux = []
        maxi=-1
        maxBene = -1
        for index, x in enumerate(itensCidade):
            cont=0
            
            ind2=-1
            for y in x:
                if( not y[5]):
                    if maxBene < y[1]:
                        maxBene = y[1]
                        ind2=int(y[0])
                cont+=1
            if cont>maxi and ind2!=-1:
                maxi=cont
                ind=index
                indice=ind2
    num+=1
    if forma==num:#cidade com mais itens disponiveis, pega o de maior recompensa
        aux = []
        maxi=-1
        minBene = 100000000000
        for index, x in enumerate(itensCidade):
            cont=0
            
            ind2=-1
            for y in x:
                if( not y[5]):
                    if minBene > y[2]:
                        minBene = y[2]
                        ind2=int(y[0])
                cont+=1
            if cont>maxi and ind2!=-1:
                maxi=cont
                ind=index
                indice=ind2
    num+=1
    
    #if(forma>=7 and forma <14):
    #    return -1
    
     #NAS CIDADES da melhor solução
    #print(cidadesAntigas)  
        
    if forma==num:#pega melhor custo beneficio dos itens disponiveis
        for index, x in enumerate(itensRecompensa):
            if(not x[5] and x[3] in cidadesAntigas):
                indice = x[0]
                break
    num+=1
    
    if forma==num: #maior recompensa
        for index, x in enumerate(itensPeso):
            if(not x[5] and x[3] in cidadesAntigas):
                indice = x[0]
                break
    num+=1
        
    if forma==num:#menor peso
        for index, x in enumerate(itensValor):
            if(not x[5] and x[3] in cidadesAntigas):
                indice = x[0]
                break
    num+=1
        
        
    if forma==num:#aleatorio
        aux = []
        for index, x in enumerate(itens):
            if( not x[5] and x[3] in cidadesAntigas):
                aux.append(index)
        if(len(aux)>0):
            indice = np.random.choice(aux,1)[0]
    num+=1
    
    
    if forma==num:#cidade com mais itens disponiveis, pega o melhor custo beneficio
        aux = []
        maxi=-1
        maxBene = -1
        for index, x in enumerate(itensCidade):
            cont=0
            
            ind2=-1
            for y in x:
                if( not y[5] and y[3] in cidadesAntigas):
                    if maxBene < y[4]:
                        maxBene = y[4]
                        ind2=int(y[0])
                cont+=1
            if cont>maxi and ind2!=-1:
                maxi=cont
                ind=index
                indice=ind2
    num+=1
    if forma==num:#cidade com mais itens disponiveis, pega o de menor peso
        aux = []
        maxi=-1
        maxBene = -1
        for index, x in enumerate(itensCidade):
            cont=0
            
            ind2=-1
            for y in x:
                if( not y[5] and y[3] in cidadesAntigas):
                    if maxBene < y[1]:
                        maxBene = y[1]
                        ind2=int(y[0])
                cont+=1
            if cont>maxi and ind2!=-1:
                maxi=cont
                ind=index
                indice=ind2
    num+=1
    if forma==num:#cidade com mais itens disponiveis, pega o de maior recompensa
        aux = []
        maxi=-1
        minBene = 100000000000
        for index, x in enumerate(itensCidade):
            cont=0
            
            ind2=-1
            for y in x:
                if( not y[5] and y[3] in cidadesAntigas):
                    if minBene > y[2]:
                        minBene = y[2]
                        ind2=int(y[0])
                cont+=1
            if cont>maxi and ind2!=-1:
                maxi=cont
                ind=index
                indice=ind2
    num+=1
    
    #NAS CIDADES MAIS PROXIMAS DAS SELECIONADAS
    cidadesProximas = []
    for x in cidadesSelecionadas:
        cidadesProximas.append(vetorCidadeProxima[x])        
        cidadesProximas.append(vetorCidadeProxima[vetorCidadeProxima[x]])
        
    if forma==num:#pega melhor custo beneficio dos itens disponiveis
        for index, x in enumerate(itensRecompensa):
            if(not x[5] and x[3] in cidadesProximas):
                indice = x[0]
                break
    num+=1
    
    if forma==num: #maior recompensa
        for index, x in enumerate(itensPeso):
            if(not x[5] and x[3] in cidadesProximas):
                indice = x[0]
                break
    num+=1
        
    if forma==num:#menor peso
        for index, x in enumerate(itensValor):
            if(not x[5] and x[3] in cidadesProximas):
                indice = x[0]
                break
    num+=1
        
        
        
    
    if forma==num:#aleatorio
        aux = []
        for index, x in enumerate(itens):
            if( not x[5] and x[3] in cidadesProximas):
                aux.append(index)
        if(len(aux)>0):
            indice = np.random.choice(aux,1)[0]
    num+=1
    
    
    if forma==num:#cidade com mais itens disponiveis, pega o melhor custo beneficio
        aux = []
        maxi=-1
        maxBene = -1
        for index, x in enumerate(itensCidade):
            cont=0
            
            ind2=-1
            for y in x:
                if( not y[5] and y[3] in cidadesProximas):
                    if maxBene < y[4]:
                        maxBene = y[4]
                        ind2=int(y[0])
                cont+=1
            if cont>maxi and ind2!=-1:
                maxi=cont
                ind=index
                indice=ind2
    num+=1
    if forma==num:#cidade com mais itens disponiveis, pega o de menor peso
        aux = []
        maxi=-1
        maxBene = -1
        for index, x in enumerate(itensCidade):
            cont=0
            
            ind2=-1
            for y in x:
                if( not y[5] and y[3] in cidadesProximas):
                    if maxBene < y[1]:
                        maxBene = y[1]
                        ind2=int(y[0])
                cont+=1
            if cont>maxi and ind2!=-1:
                maxi=cont
                ind=index
                indice=ind2
    num+=1
    if forma==num:#cidade com mais itens disponiveis, pega o de maior recompensa
        aux = []
        maxi=-1
        minBene = 100000000000
        for index, x in enumerate(itensCidade):
            cont=0
            
            ind2=-1
            for y in x:
                if( not y[5] and y[3] in cidadesProximas):
                    if minBene > y[2]:
                        minBene = y[2]
                        ind2=int(y[0])
                cont+=1
            if cont>maxi and ind2!=-1:
                maxi=cont
                ind=index
                indice=ind2
    num+=1
     
    
    # SOMENTE NAS CIDADES JA SELECIONADAS
            
    if forma==num:#pega melhor custo beneficio dos itens disponiveis
        for index, x in enumerate(itensRecompensa):
            if(not x[5] and x[3] in cidadesSelecionadas):
                indice = x[0]
                break
    num+=1
    
    if forma==num: #maior recompensa
        for index, x in enumerate(itensPeso):
            if(not x[5] and x[3] in cidadesSelecionadas):
                indice = x[0]
                break
    num+=1
        
    if forma==num:#menor peso
        for index, x in enumerate(itensValor):
            if(not x[5] and x[3] in cidadesSelecionadas):
                indice = x[0]
                break
    num+=1
        
        
    
    if forma==num:#aleatorio
        aux = []
        for index, x in enumerate(itens):
            if( not x[5] and x[3] in cidadesSelecionadas):
                aux.append(index)
        if(len(aux)>0):
            indice = np.random.choice(aux,1)[0]
    num+=1
    
    if forma==num:#cidade com mais itens, pega o melhor custo beneficio
        aux = []
        maxi=-1
        maxBene = -1
        for index, x in enumerate(itensCidade):
            cont=0
            ind2=-1
            for y in x:
                if( not y[5]  and y[3] in cidadesSelecionadas):
                    if maxBene < y[4]:
                        maxBene = y[4]
                        ind2=int(y[0])
                cont+=1
            if cont>maxi:
                maxi=cont
                ind=index
                indice=ind2
            
            
            
            
    num+=1
    
    if forma==num:#cidade com mais itens disponiveis, pega o de menor peso
        aux = []
        maxi=-1
        maxBene = -1
        for index, x in enumerate(itensCidade):
            cont=0
            
            ind2=-1
            for y in x:
                if( not y[5] and y[3] in cidadesSelecionadas):
                    if maxBene < y[1]:
                        maxBene = y[1]
                        ind2=int(y[0])
                cont+=1
            if cont>maxi and ind2!=-1:
                maxi=cont
                ind=index
                indice=ind2
    num+=1
    if forma==num:#cidade com mais itens disponiveis, pega o de maior recompensa
        aux = []
        maxi=-1
        minBene = 100000000000
        for index, x in enumerate(itensCidade):
            cont=0
            
            ind2=-1
            for y in x:
                if( not y[5] and y[3] in cidadesSelecionadas):
                    if minBene > y[2]:
                        minBene = y[2]
                        ind2=int(y[0])
                cont+=1
            if cont>maxi and ind2!=-1:
                maxi=cont
                ind=index
                indice=ind2
    num+=1
    
        
    if forma==100 and indexItem!=-1:
        #print(indexItem)
        indice=indexItem
        
    
   
    #print('objetivo: ', objetivo, vRota, vItens)
    if(indice!=-1):  
        
        if(int(itens[indice][3]) not in cidadesSelecionadas):    
            vRota = ordenar(ordemCidade, cidadesSelecionadas+[int(itens[indice][3])])
        else:
            vRota = ordenar(ordemCidade, cidadesSelecionadas)

        vItens=itensSelecionados+[int(itens[indice][0])]

        objetivo = solucao(vRota, vItens, matrizAdjacencia, itens, minS, maxS, (maxS-minS)/cap, maxT, cap)
        
        if(objetivo!=-1):
            if(int(itens[indice][3]) not in cidadesSelecionadas):
                cidadesSelecionadas.append(int(itens[indice][3]))
            itens[indice][5]= True
            return int(itens[indice][0])
        else:
            return -1
    else:
        return -1
    return
        
        
                
            
            
            #coloca na rota se puder, se não sorteia outro metodo
        
    return 
def vizinhanca(vetorPermutado, itens):
    formaAleatoria = random.randint(0, 10)
    
    # tem-se um vetor com todas as cidades da rota permutada,
    # a cada iteração escolhe-se um item entre as formas predefinidas, 
    # quando todas as possibilidades não puderem mais ser colocadas
    # tem-se a solução inicial, e a vizinhança vai ser permutar as rotas
    # e itens de forma alternada.
    
    pass

# %%
pontos = []
itens = []

#with open('ex4/instances/ex4-n5_1.thop', 'r') as file:  
with open('thop/instances/a280-thop/a280_n1390_uncorr-similar-weights_10_02.thop', 'r') as file:    
    name = file.readline().strip().replace(' ','').split(':')[1]    
    knapsack = file.readline().strip().replace(' ','').split(':')[1]    
    dimension = int(file.readline().strip().replace(' ','').split(':')[1])
    nItens = int(file.readline().strip().replace(' ','').split(':')[1])
    capacity = int(file.readline().strip().replace(' ','').split(':')[1])
    maxTime = int(file.readline().strip().replace(' ','').split(':')[1])
    minSpeed = float(file.readline().strip().replace(' ','').split(':')[1])
    maxSpeed = float(file.readline().strip().replace(' ','').split(':')[1])
    edgeType = file.readline().strip().replace(' ','').split(':')[1]
    pontosSection = True
    for x in file:
        if 'NODE_COORD_SECTION' in x: 
            print(x)
        elif 'ITEMS SECTION' in x: 
            pontosSection = False
            print(x)
        else:
            if(pontosSection):
                pontos.append([float(i) for i in x.split()])
            else:                
                itens.append([float(i) if index!=0 and index!=3 else int(i)-1 for index, i in enumerate(x.split())]+[float(x.split()[1])/float(x.split()[2])]+[False])
                
print(pontos)
print(itens)
    
matrizAdjacencia = []
vetorCidadeProxima = {}
itensCidade=[]
for x in pontos:    
    itensCidade.append([])  
    aux = []
    menor = 100000000000
    for y in pontos:
        d = dist(x,y)
        if(d<menor):
            menor=d
            ponto = y
        vetorCidadeProxima[x[0]]=ponto[0]
        aux.append(d)      
    matrizAdjacencia.append(aux)


for x in itens:
    itensCidade[int(x[3])].append(x)
# Out:
# NODE_COORD_SECTION  (INDEX, X, Y):
#
# ITEMS SECTION    (INDEX, PROFIT, WEIGHT, ASSIGNED NODE NUMBER):
#
# [[1.0, 981036.0, 508139.0], [2.0, 534120.0, -42453.0], [3.0, 577878.0, -43732.0], [4.0, 532890.0, -96645.0], [5.0, 205322.0, 215891.0], [6.0, 225923.0, 197950.0], [7.0, 69842.0, 667632.0], [8.0, 391965.0, 1054524.0], [9.0, 310065.0, -10714.0], [10.0, 247401.0, 754523.0], [11.0, 217951.0, 218350.0], [12.0, 443097.0, 54051.0], [13.0, 47342.0, 630935.0], [14.0, 317515.0, 713679.0], [15.0, 301816.0, 1021772.0], [16.0, 950864.0, 332234.0], [17.0, 276433.0, 725657.0], [18.0, 921801.0, 410349.0], [19.0, 555508.0, 67090.0], [20.0, 409959.0, 379409.0], [21.0, 968097.0, 540588.0], [22.0, 40089.0, 721860.0], [23.0, 702011.0, 527050.0], [24.0, 726191.0, 326684.0], [25.0, 990428.0, 196959.0], [26.0, 381890.0, 1003805.0], [27.0, 409527.0, 1056227.0], [28.0, 675609.0, 496310.0], [29.0, 971071.0, 188552.0], [30.0, 932494.0, 818793.0], [31.0, 936083.0, 384774.0], [32.0, 835076.0, 517826.0], [33.0, 120444.0, 663239.0], [34.0, 648516.0, 395774.0], [35.0, 402323.0, 126508.0], [36.0, 307839.0, 57178.0], [37.0, 397333.0, 987582.0], [38.0, 314281.0, 949219.0], [39.0, 105042.0, 667806.0], [40.0, 1006036.0, 468020.0], [41.0, 473356.0, 311656.0], [42.0, 970499.0, 257334.0], [43.0, 919732.0, 458332.0], [44.0, 1033956.0, 436231.0], [45.0, 934265.0, 314744.0], [46.0, 239142.0, 55856.0], [47.0, 720304.0, 525053.0], [48.0, 480764.0, 1058084.0], [49.0, 970063.0, 396578.0], [50.0, 543132.0, 334794.0], [51.0, 755587.0, 491352.0], [52.0, 975653.0, 745618.0], [53.0, 272842.0, 58331.0], [54.0, 537123.0, 165900.0], [55.0, 519742.0, 129315.0], [56.0, 35924.0, 947451.0], [57.0, 1064442.0, 490895.0], [58.0, 489393.0, 117496.0], [59.0, 631320.0, 277543.0], [60.0, 261674.0, 961159.0], [61.0, 534617.0, 58056.0], [62.0, 691689.0, 512673.0], [63.0, 182654.0, 715277.0], [64.0, 945838.0, 459916.0], [65.0, 627821.0, -838.0], [66.0, 1022110.0, 283893.0], [67.0,
 594.0, 1008.0, 53.0, 0.5892857142857143, False], [53.0, 226.0, 1006.0, 54.0, 0.22465208747514911, False], [54.0, 226.0, 1002.0, 55.0, 0.22554890219560877, False], [55.0, 921.0, 1000.0, 56.0, 0.921, False], [56.0, 537.0, 1006.0, 57.0, 0.5337972166998012, False], [57.0, 112.0, 1001.0, 58.0, 0.11188811188811189, False], [58.0, 959.0, 1005.0, 59.0, 0.954228855721393, False], [59.0, 392.0, 1001.0, 60.0, 0.3916083916083916, False], [60.0, 709.0, 1006.0, 61.0, 0.7047713717693836, False], [61.0, 940.0, 1002.0, 62.0, 0.93812375249501, False], [62.0, 943.0, 1006.0, 63.0, 0.937375745526839, False], [63.0, 79.0, 1001.0, 64.0, 0.07892107892107893, False], [64.0, 922.0, 1004.0, 65.0, 0.9183266932270916, False], [65.0, 361.0, 1000.0, 66.0, 0.361, False], [66.0, 947.0, 1003.0, 67.0, 0.9441674975074775, False], [67.0, 861.0, 1009.0, 68.0, 0.8533201189296333, False], [68.0, 937.0, 1009.0, 69.0, 0.9286422200198216, False], [69.0, 754.0, 1005.0, 70.0, 0.7502487562189055, False], [70.0, 872.0, 1000.0, 71.0, 0.872, False], [71.0, 636.0, 1001.0, 72.0, 0.6353646353646354, False], [72.0, 459.0, 1009.0, 73.0, 0.45490584737363726, False], [73.0, 390.0, 1001.0, 74.0, 0.38961038961038963, False], [74.0, 141.0, 1005.0, 75.0, 0.14029850746268657, Fa ...

# %%
import numpy as np
minS = minSpeed
maxS = maxSpeed
cap = capacity
maxT = maxTime
cidades = []
melhorTodas = 0
itensSalvos = []
for k in range(100):
    
    piorou = 0
    vetor = np.random.permutation(range(1,len(matrizAdjacencia.copy())-1))
    cidadesSalvas=[]
    solucaoSalva = -1
    comparaItens = itensSalvos
    itensSalvos = []
    vetorSalvo= vetor
    
    for i in range(20):
        
        
        #vetor = np.random.permutation(range(2,len(matrizAdjacencia.copy())))

        cidades = []
        itensUsados = [True]*len(itens.copy())
        for x in itens:
            x[5]=False
        #print(itensUsados)
        vetorAntigo =[j for index, j in enumerate(vetor) if index<max(len(cidadesSalvas)*2,int(math.sqrt(len(vetor))))]
        #print(sorted(cidadesSalvas), sorted(vetorAntigo))
        #vetorAntigo = vetor.copy()[:min(len(cidadesSalvas)*2, len(vetor))]
        itensSelecionados = selecionaItens(vetor.copy(), itens.copy(),itensUsados.copy(), itensCidade.copy(), cidades, vetorCidadeProxima.copy(), vetorAntigo.copy())
        sol,t = solucao(ordenar(vetor.copy(), cidades.copy()), itensSelecionados.copy(), matrizAdjacencia.copy(), itens.copy(), minS, maxS, (maxS-minS)/cap, maxT, cap)
        
        
        melhorTempo=t
        bestsol=sol
        
        print(sol, len(cidades), len(itensSelecionados))
        for x in  range(10):            
            soluc = list(np.random.permutation(cidades.copy()))
            #print(soluc)
            sol, t = solucao(soluc, itensSelecionados.copy(), matrizAdjacencia.copy(), itens.copy(), minS, maxS, (maxS-minS)/cap, maxT, cap)
            if t<melhorTempo and sol!=-1:
                melhorTempo = t
                bestsol = sol
                cidades=soluc.copy()
        
                print(sol, len(cidades), len(itensSelecionados))
        #for x in itensSelecionados:
            #print(itens[x])
        
        if sol > solucaoSalva:
            
            melhorTodas = max(melhorTodas, sol)
            itensSalvos = itensSelecionados
            solucaoSalva = sol
            cidadesSalvas = cidades
            vetorSalvo = vetor
            piorou = 0
        else:
            piorou+=1
        if piorou==6:
            break
            
        #vetor = np.random.permutation(range(2,len(matrizAdjacencia.copy())))
        vetor = cidades.copy() + list(np.random.permutation([x for x in range(1,len(matrizAdjacencia.copy())-1) if x not in cidades]))
        
        print(solucaoSalva, sol, len(itensSelecionados), len(cidades), len(list(set(itensSalvos).intersection(itensSelecionados))))
        #otimizar(cidades, itensSelecionados)
    print(len(list(set(itensSalvos).intersection(comparaItens))))
    
print(melhorTodas)

#refazer tudo, atualizar dinamicamente os melhores valores de tudo
# Out:
# ---------------------------------------------------------------------------
# TypeError                                 Traceback (most recent call last)
# <ipython-input-101-4e0ae1d3debb> in <module>()
#      30         #print(sorted(cidadesSalvas), sorted(vetorAntigo))
#      31         #vetorAntigo = vetor.copy()[:min(len(cidadesSalvas)*2, len(vetor))]
# ---> 32         itensSelecionados = selecionaItens(vetor.copy(), itens.copy(),itensUsados.copy(), itensCidade.copy(), cidades, vetorCidadeProxima.copy(), vetorAntigo.copy())
#      33         sol = solucao(ordenar(vetor.copy(), cidades.copy()), itensSelecionados.copy(), matrizAdjacencia.copy(), itens.copy(), minS, maxS, (maxS-minS)/cap, maxT, cap)
#      34
#
# <ipython-input-99-15775fcd6e50> in selecionaItens(ordemCidade, itens, itensUsados, itensCidade, cidadesSelecionadas, vetorCidadeProxima, cidadesAntigas)
#     111                 #print(itens[indexItem][3], itens[int(i[0])][3])
#     112                 if np.random.randint(2)==0:
# --> 113                     if(formaItem(itens, itensUsados, 100, itensSelecionados, cidadesSelecionadas, ordemCidade, itensCidade, vetorCidadeProxima, cidadesAntigas,i[0])!=-1):
#     114                         #print(int(i[3]), itens[indexItem][3])
#     115                         itensSelecionados.append(int(i[0]))
#
# <ipython-input-99-15775fcd6e50> in formaItem(itens, itensUsados, forma, itensSelecionados, cidadesSelecionadas, ordemCidade, itensCidade, vetorCidadeProxima, cidadesAntigas, indexItem, itensRecompensa, itensValor, itensPeso)
#     531     if(indice!=-1):
#     532
# --> 533         if(int(itens[indice][3]) not in cidadesSelecionadas):
#     534             vRota = ordenar(ordemCidade, cidadesSelecionadas+[int(itens[indice][3])])
#     535         else:
#
# TypeError: list indices must be integers or slices, not float

# %%
list1 = [1,2,5,4,3,6]
list2 = [5,3,7,9]
list(set(list1).intersection(list2))
print(set(list1) - (set(list1)-set(list2)))

# %%
ordenar(range(len(matrizAdjacencia)), [2,1])
# Out:
# [1, 2]

# %%
#vRota=[3]
#vItens=[4,5]


vRota=[x-1 for x in [2,3]]
vItens=[x-1 for x in [1,4]]
solucao(vRota, vItens, matrizAdjacencia, itens, minSpeed, maxSpeed, (maxSpeed-minSpeed)/capacity, maxTime, capacity)
# Out:
# 60.0

# %%
pontos = []
itens = []

#with open('ex4/instances/ex4-n5_1.thop', 'r') as file:  
with open('thop/instances/a280-thop/a280_n1390_uncorr-similar-weights_10_02.thop', 'r') as file:    
    name = file.readline().strip().replace(' ','').split(':')[1]    
    knapsack = file.readline().strip().replace(' ','').split(':')[1]    
    dimension = int(file.readline().strip().replace(' ','').split(':')[1])
    nItens = int(file.readline().strip().replace(' ','').split(':')[1])
    capacity = int(file.readline().strip().replace(' ','').split(':')[1])
    maxTime = int(file.readline().strip().replace(' ','').split(':')[1])
    minSpeed = float(file.readline().strip().replace(' ','').split(':')[1])
    maxSpeed = float(file.readline().strip().replace(' ','').split(':')[1])
    edgeType = file.readline().strip().replace(' ','').split(':')[1]
    pontosSection = True
    for x in file:
        if 'NODE_COORD_SECTION' in x: 
            print(x)
        elif 'ITEMS SECTION' in x: 
            pontosSection = False
            print(x)
        else:
            if(pontosSection):
                pontos.append([float(i) for i in x.split()])
            else:                
                itens.append([float(i) if index!=0 and index!=3 else int(i)-1 for index, i in enumerate(x.split())]+[float(x.split()[1])/float(x.split()[2])]+[False])
                
#print(pontos)
#print(itens)
    
matrizAdjacencia = []
vetorCidadeProxima = {}
itensCidade=[]
for x in pontos:    
    itensCidade.append([])  
    aux = []
    menor = 100000000000
    for y in pontos:
        d = dist(x,y)
        if(d<menor):
            menor=d
            ponto = y
        vetorCidadeProxima[x[0]]=ponto[0]
        aux.append(d)      
    matrizAdjacencia.append(aux)


for x in itens:
    itensCidade[int(x[3])].append(x)
# Out:
# NODE_COORD_SECTION  (INDEX, X, Y):
#
# ITEMS SECTION    (INDEX, PROFIT, WEIGHT, ASSIGNED NODE NUMBER):
#
# [[], [[0, 1.0, 1008.0, 1, 0.000992063492063492, False], [278, 375.0, 1009.0, 1, 0.37165510406342916, False], [556, 283.0, 1005.0, 1, 0.281592039800995, False], [834, 868.0, 1000.0, 1, 0.868, False], [1112, 274.0, 1007.0, 1, 0.27209533267130087, False]], [[1, 896.0, 1006.0, 2, 0.8906560636182903, False], [279, 875.0, 1004.0, 2, 0.8715139442231076, False], [557, 434.0, 1001.0, 2, 0.43356643356643354, False], [835, 203.0, 1006.0, 2, 0.20178926441351888, False], [1113, 64.0, 1009.0, 2, 0.06342913776015857, False]], [[2, 367.0, 1006.0, 3, 0.3648111332007952, False], [280, 299.0, 1006.0, 3, 0.29721669980119286, False], [558, 930.0, 1002.0, 3, 0.9281437125748503, False], [836, 533.0, 1002.0, 3, 0.5319361277445109, False], [1114, 268.0, 1002.0, 3, 0.26746506986027946, False]], [[3, 690.0, 1001.0, 4, 0.6893106893106893, False], [281, 969.0, 1009.0, 4, 0.9603567888999008, False], [559, 154.0, 1000.0, 4, 0.154, False], [837, 137.0, 1001.0, 4, 0.13686313686313686, False], [1115, 230.0, 1001.0, 4, 0.22977022977022976, False]], [[4, 613.0, 1006.0, 5, 0.6093439363817097, False], [282, 215.0, 1005.0, 5, 0.21393034825870647, False], [560, 123.0, 1007.0, 5, 0.1221449851042701, False], [838, 451.0, 1002.0, 5, 0.4500998003992016, False], [1116, 83.0, 1003.0, 5, 0.08275174476570289, False]], [[5, 874.0, 1001.0, 6, 0.8731268731268731, False], [283, 435.0, 1000.0, 6, 0.435, False], [561, 862.0, 1005.0, 6, 0.8577114427860697, False], [839, 155.0, 1004.